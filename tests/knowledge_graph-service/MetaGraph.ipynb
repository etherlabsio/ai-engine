# %%
import networkx as nx
import json as js
import pandas as pd

# %%
user_context_info_df = pd.read_csv("data/prod_user_workspace_channel_contexts.csv")
workspace_customer_info_df = pd.read_csv("data/prod_workspace_id_customers.csv")
markers_instance_info_df = pd.read_csv('data/prod_markers_instance_id.csv')

# %%
user_context_info_df['user_attributes'][5]
# Out:
# '{"id": "b6806dc10a184d829c2568f0c497825d", "name": "Karthik Muralidharan", "email": "karthik@etherlabs.io", "source": "slack", "status": "active", "teamId": "T7ECNFTBK", "avatars": {"image192": "https://avatars.slack-edge.com/2018-03-23/335953803862_c31bdfdc62b7a0825e72_192.png", "imageOriginal": "https://avatars.slack-edge.com/2018-03-23/335953803862_c31bdfdc62b7a0825e72_original.png"}, "deleted": false, "sourceId": "U7FA0ALGL", "createdAt": "2017-10-11T14:04:59.620079695Z", "deletedAt": null, "updatedAt": "2019-08-07T03:53:02.203563224Z", "accessToken": "xoxp-252430537393-253340360564-320311617968-b320c6a53883f92a2d9da5282508f311", "mentionName": "karthik", "workspaceId": "b3614ac518ad4fcc8406263f5f1d2c6a"}'

# %%
uattr  = js.loads(user_context_info_df['user_attributes'][0])

# %%
uattr['avatars'].get('image192')
# Out:
# 'https://avatars.slack-edge.com/2019-06-18/656937253218_4f33486dc068997d264f_192.jpg'

# %%
user_context_info_df['workspace_attributes'][0]
# Out:
# '{"id": "8ed6ea6d11dc4cd099c32ab36a02e959", "bot": {"handle": "ether"}, "url": "heartfulness", "name": "Heartfulness", "source": "slack", "disabled": false, "sourceId": "T06QWU410", "createdAt": "2018-09-29T14:25:11.190796445Z", "deletedAt": null, "providers": null, "updatedAt": "2019-07-27T18:47:45.289225263Z", "accessToken": "xoxp-6846956034-446876960887-446008830197-08f482a43eaf973dcc5a77a49d8a381f"}'

# %%
user_context_info_df['channel_attributes'][0]
# Out:
# '{"id": "a1c582a6-f73f-4a88-9ac5-043947316384", "name": "venkat-only", "roomId": "GJ9CMDDJR", "scopes": null, "source": "slack", "status": "active", "teamId": "T06QWU410", "deleted": false, "members": ["35bcfa72bf81442c8a1a8bbda7733cde", "4e4e933eb77c4e5eada9e1780c51c662"], "contextId": "01DBB3SN6VJAP5WED6NZX7A7TE", "createdAt": "2019-04-29T16:06:36.270103167Z", "deletedAt": null, "updatedAt": "2019-04-29T16:06:36.364683104Z", "visibility": "private", "accessToken": "", "workspaceId": "8ed6ea6d11dc4cd099c32ab36a02e959", "meetingProvider": ""}'

# %%
user_attribute_namespace = ['name', 'email', 'status', 'deleted', \
                        'createdAt', 'deletedAt', 'updatedAt']

user_node_namespace = ['workspaceId']

workspace_attribute_namespace = ['url', 'name', 'source', 'disabled', 'sourceId', "createdAt", "deletedAt", 
                                 "providers", "updatedAt"]

channel_attribute_namespace = ['name', 'roomId', 'scopes', "source", "status", "teamId", "deleted", "createdAt",
                              "deletedAt", "updatedAt", "visibility", "meetingProvider"]
channel_node_namespace = ["contextId", "workspaceId"]

# %%
user_label = {"attribute": "userId"}

workspace_label = {"attribute": "workspaceId"}
channel_label = {"attribute": "channelId"}
context_label = {"attribute": "contextId"}
mind_label = {"attribute": "mindId", "name": ""}
customer_label = {"attribute": "customerId"}
mind_dict = {"01DAAPWR6W051Q9WWQY99JSGFY" : {"name": "generic", "type": "domain"},
             "01DAAQY88QZB19JQZ5PRJFR76Y" : {"name": "Software Engineering", "type": "domain"},
             "01DAAQYN9GBEBC92AYWNXEDP0C" : {"name": "HR", "type": "domain"},
             "01DAATANXNRQA35E6004HB7MBN" : {"name": "Marketing", "type": "domain"},
             "01DAATBC3AK1QWC5NYC5AHV2XZ" : {"name": "Product", "type": "domain"},
             "01DADP74WFV607KNPCB6VVXGTG" : {"name": "AI", "type": "domain"},
             "01DAAYHEKY5F4E02QVRJPTFTXV" : {"name": "Ether Engineering", "type": "custom"}
            }

user_context_rel = {"relation": "belongsTo"}
channel_user_rel = {"relation": "hasMember"}
channel_context_rel = {"relation": "hasContext"}
channel_workspace_rel = {"relation": "belongsTo"}
workspace_customer_rel = {"relation": "belongsTo"}
workspace_user_rel = {"relation": "hasMember"}
customer_user_rel = {"relation": "hasUser"}
context_mind_rel = {"relation": "associatedMind"}

# %%
def prepare_user_nodes(user_info):
    user_node_list = []
    for i in range(len(user_info)):
        uinfo_attr = js.loads(user_info['user_attributes'][i])
        u_attr = {x: uinfo_attr.pop(x, None) for x in user_attribute_namespace}
        u_attr.update(user_label)
#         try:
#             u_attr.update({'avatarImage192': uinfo_attr['avatars'].get('image192')})
#             u_attr.update({'avatarImageOriginal': uinfo_attr['avatars'].get('imageOriginal')})
#         except:
#             u_attr.update({'avatarImage192': "None"})
#             u_attr.update({'avatarImageOriginal': "None"})
        
        user_id = user_info['user_id'][i]
        user_node_list.append((user_id, u_attr))
        
    return user_node_list

def prepare_workspace_nodes(user_info):
    workspace_node_list = []
    for i in range(len(user_info)):
        winfo_attr = js.loads(user_info['workspace_attributes'][i])
        
        w_attr = {x: winfo_attr.pop(x, None) for x in workspace_attribute_namespace}
        w_attr.update(workspace_label)
        w_attr.update({'bot': winfo_attr['bot'].get('handle')})
        workspace_id = user_info['workspace_id'][i]
        workspace_node_list.append((workspace_id, w_attr))
        
    return workspace_node_list

def prepare_channel_nodes(user_info):
    channel_node_list = []
    for i in range(len(user_info)):
        cinfo_attr = js.loads(user_info['channel_attributes'][i])
        
        c_attr = {x: cinfo_attr.pop(x, None) for x in channel_attribute_namespace}
        c_attr.update(channel_label)
        channel_id = user_info['channel_id'][i]
        channel_node_list.append((channel_id, c_attr))
        
    return channel_node_list

def prepare_context_nodes(user_info):
    context_node_list = []
    for i in range(len(user_info)):        
        context_id = user_info['context_id'][i]
        context_node_list.append((context_id, context_label))
        
    return context_node_list

# %%
def prepare_user_edges(user_info):
    user_workspace_edge_list = []
    user_context_edge_list = []
    user_customer_edge_list = []
    context_channel_edge_list = []
    channel_workspace_edge_list = []
    channel_user_edge_list = []
    for i in range(len(user_info)):
        
        user_id = user_info["user_id"][i]
        workspace_id = user_info['workspace_id'][i]
        context_id = user_info['context_id'][i]
        channel_id = user_info['channel_id'][i]
        
        user_workspace_edge_list.append((workspace_id, user_id, workspace_user_rel))
        user_context_edge_list.append((user_id, context_id, user_context_rel))
        context_channel_edge_list.append((channel_id, context_id, channel_context_rel))
        channel_workspace_edge_list.append((channel_id, workspace_id, channel_workspace_rel))
        channel_user_edge_list.append((channel_id, user_id, channel_user_rel))
    
    return user_workspace_edge_list, user_context_edge_list, context_channel_edge_list, channel_workspace_edge_list, channel_user_edge_list

# %%
def workspace_customer_nodes(workspace_info):
    workspace_customer_node_list = []
    for i in range(len(workspace_info)):
        customer_id = workspace_info['customer_id'][i]
        
        workspace_customer_node_list.append((customer_id, customer_label))
    
    return workspace_customer_node_list

def prep_workspace_nodes(workspace_info):
    workspace_node_list = []
    for i in range(len(workspace_info)):
        workspace_id = workspace_info['workspace_id'][i]
        
        workspace_node_list.append((workspace_id, workspace_label))
    
    return workspace_node_list

def workspace_customer_edges(workspace_info):
    workspace_customer_edge_list = []
    for i in range(len(workspace_info)):
        
        workspace_id = workspace_info['workspace_id'][i]
        customer_id = workspace_info['customer_id'][i]
        
        workspace_customer_edge_list.append((workspace_id, customer_id, workspace_customer_rel))
    
    return workspace_customer_edge_list

# %%
def prepare_marker_nodes(marker_info):
    marker_nodes_list = []
    for i in range(len(marker_info)):
        marker_id = marker_info['marker_id'][i]
        
        if marker_info['automatic'][i] == True:
            automatic_marker = True
        else:
            automatic_marker = False
        
        marker_attr = {
            "attribute": "markerId",
            "automaticMarker": automatic_marker,
            "type": marker_info['marker_type'][i],
            "description": marker_info['marker_description'][i],
            "createdAt": marker_info['created_at'][i]
        }
        
        if marker_attr.get("type") is None:
            marker_attr["type"] = ""
        
        
        marker_nodes_list.append((marker_id, marker_attr))
    
    return marker_nodes_list

def marker_user_nodes(marker_info):
    marker_user_node_list = []
    for i in range(len(marker_info)):
        user_id = marker_info['user_id'][i]
        
        marker_user_node_list.append((user_id, user_label))
    
    return marker_user_node_list

def marker_instance_nodes(marker_info):
    marker_instance_node_list = []
    instance_label = {"attribute": "instanceId"}
    for i in range(len(marker_info)):
        instance_id = marker_info['instance_id'][i]
        
        marker_instance_node_list.append((instance_id, instance_label))
    
    return marker_instance_node_list

def marker_user_edges(marker_info):
    marker_user_edge_list = []
    marker_user_rel = {"relation": "createdBy"}
    for i in range(len(marker_info)):
        user_id = marker_info['user_id'][i]
        marker_id = marker_info['marker_id'][i]
        marker_user_edge_list.append((marker_id, user_id, marker_user_rel))
    
    return marker_user_edge_list

def marker_instance_edges(marker_info):
    marker_instance_edge_list = []
    marker_instance_rel = {"relation": "hasMarker"}
    for i in range(len(marker_info)):
        instance_id = marker_info['instance_id'][i]
        marker_id = marker_info['marker_id'][i]
        marker_instance_edge_list.append((instance_id, marker_id, marker_instance_rel))
    
    return marker_instance_edge_list

# %% [markdown]
# ## Add Mind info

# %%
mind_info = pd.read_csv('data/ws-ch-relations-staging2.csv')

# %%
mind_info.keys()
# Out:
# Index(['workspace_name    ', 'workspace_id                        ',
#        'channel_id                          ', 'channel_name           ',
#        'context_id                ', 'mind_id                   ',
#        'customer_id'],
#       dtype='object')

# %%
from copy import deepcopy
def prepare_mind_nodes(mind_info):
    
    mind_node_list = []
    for i in range(len(mind_info)):
        m_label = deepcopy(mind_label)
        
        mind_id = mind_info['mind_id                   '][i]
        current_mind_info = mind_dict[mind_id]
        m_label.update(current_mind_info) 
        mind_node_list.append((mind_id, m_label))
    
    return mind_node_list

def prepare_context_mind_nodes(mind_info):
    context_node_list = []
    context_mind_node_list = []
    for i in range(len(mind_info)):
        context_id = mind_info['context_id                '][i]
        mind_id = mind_info['mind_id                   '][i]
        context_node_list.append((context_id, context_label))
        context_mind_node_list.append((context_id, mind_id, context_mind_rel))
    
    return context_node_list, context_mind_node_list

# %% [markdown]
# ## Build the MetaGraph

# %%
meta_graph.clear()
meta_graph = nx.DiGraph(type="meta")

# %% [markdown]
# ### Add user, workspace, context, channel and customer nodes

# %%
user_nodes = prepare_user_nodes(user_context_info_df)
workspace_nodes = prepare_workspace_nodes(user_context_info_df)
channel_nodes = prepare_channel_nodes(user_context_info_df)
context_nodes = prepare_context_nodes(user_context_info_df)

user_workspace_edge_list, user_context_edge_list, context_channel_edge_list, channel_workspace_edge_list, channel_user_edge_list = prepare_user_edges(user_context_info_df)

# %%
meta_graph.add_nodes_from(user_nodes)
meta_graph.add_nodes_from(workspace_nodes)
meta_graph.add_nodes_from(channel_nodes)
meta_graph.add_nodes_from(context_nodes)

meta_graph.add_edges_from(user_workspace_edge_list)
meta_graph.add_edges_from(user_context_edge_list)
meta_graph.add_edges_from(context_channel_edge_list)
meta_graph.add_edges_from(channel_workspace_edge_list)
meta_graph.add_edges_from(channel_user_edge_list)

# %%
print(meta_graph.number_of_nodes(), meta_graph.number_of_edges())
# Out:
# 1874 7155

# %% [markdown]
# ### Add workspace-> customer edges

# %%
customer_node_list = workspace_customer_nodes(workspace_customer_info_df)
workspace_node_list = prep_workspace_nodes(workspace_customer_info_df)
workspace_customer_edge_list = workspace_customer_edges(workspace_customer_info_df)

# %%
meta_graph.add_nodes_from(customer_node_list)
meta_graph.add_nodes_from(workspace_node_list)
meta_graph.add_edges_from(workspace_customer_edge_list)

# %%
print(meta_graph.number_of_nodes(), meta_graph.number_of_edges())
# Out:
# 1991 7267

# %% [markdown]
# ### Add Marker information

# %%
marker_node_list = prepare_marker_nodes(markers_instance_info_df)
marker_user_node_list = marker_user_nodes(markers_instance_info_df)
marker_instance_node_list = marker_instance_nodes(markers_instance_info_df)

marker_user_edge_list = marker_user_edges(markers_instance_info_df)
marker_instance_edge_list = marker_instance_edges(markers_instance_info_df)

# %%
marker_node_list
# Out:
# [('4d42f4dc-103a-4c8e-99d4-918d8e53f74b',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': 'search things, abstract pull context, immature case is the big one, little transcript but at this level i think',
#    'createdAt': '2019-05-29 20:16:39.268245+00'}),
#  ('2861b468-53ef-49cb-8b83-9d00968fbf3e',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'track holder step',
#    'createdAt': '2019-06-17 08:37:56.251189+00'}),
#  ('2d78d2d7-ed3b-4c79-beab-c1b8da445119',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'personal',
#    'description': 'test personal',
#    'createdAt': '2018-11-20 11:58:50.282338+00'}),
#  ('9aa6f32d-9274-46d8-9258-de1ff1f25752',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Test',
#    'createdAt': '2018-11-03 16:43:06.298779+00'}),
#  ('c7e1299b-6f27-4aa1-83f0-841369213e43',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Test marker',
#    'createdAt': '2018-11-03 14:27:08.747495+00'}),
#  ('cae85ccd-e96d-46c6-afad-0b3bb1017fd7',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'kudos',
#    'description': 'Test',
#    'createdAt': '2018-10-30 09:43:47.554684+00'}),
#  ('cd787f56-435e-42d6-9c0a-6deee0026c1a',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'decision',
#    'description': 'Test',
#    'createdAt': '2018-10-28 15:36:06.862072+00'}),
#  ('dd50f13c-86dc-45ca-9d11-ab4182d678fa',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Potential integration models',
#    'createdAt': '2017-12-01 00:52:02.971138+00'}),
#  ('dd5719a0-6b6d-416d-8c68-87938c3e5b29',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'personal',
#    'description': 'Testing personal markers',
#    'createdAt': '2018-01-07 00:37:09.728557+00'}),
#  ('c1b367d9-6788-499f-9909-9a09e86036d9',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'test',
#    'createdAt': '2018-11-20 15:01:40.532763+00'}),
#  ('aacba9a0-efa0-45dc-a0b1-e1a03d3d6430',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'Steve Jobs, Facebook, Earth, Jamie, communicate both engineering to executives, data wins arguments, earth are helpful for customers, great for steve jobs, executives design to, lose the company, company for right jamie, work gut, informed decision, data at facebook',
#    'createdAt': '2019-06-10 07:35:10.787185+00'}),
#  ('1baf23a9-c1d4-43f9-83d9-2129dc720503',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Backend,Twentieth,Apps,issue or like christmas slide,platform to set the plan,install of the app',
#    'createdAt': '2019-06-19 06:00:36.019357+00'}),
#  ('92f3ff94-d3a9-4f6e-98e9-4cf3fd1615d6',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': "yes I don't you miss we were talking about and I'm just put an example in here is that we could have one big payload just kind of how we did with hit chat right with HTML with not we could have one big payLo and slack it we slide everything in but it's in one message right",
#    'createdAt': '2017-09-18 15:08:52.397817+00'}),
#  ('00365520-b5be-4dbc-82bb-d398a4ecc5ea',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': 'Cool',
#    'createdAt': '2018-09-24 20:56:02.317287+00'}),
#  ('0043a474-24d8-4033-9c4b-27843128072f',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'test marker from Safari',
#    'createdAt': '2017-12-21 06:21:54.206073+00'}),
#  ('45a04e2d-d1b1-467b-92c3-9439c22caf34',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'test topic',
#    'createdAt': '2018-11-20 11:58:37.394677+00'}),
#  ('c83787f0-d387-49a5-8716-7eb97c02003b',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'fish origin, empty space',
#    'createdAt': '2019-05-22 09:39:39.631739+00'}),
#  ('21d475c4-1f6c-48e3-9ab7-c37ce275435d',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Summary',
#    'createdAt': '2018-06-08 02:34:21.424838+00'}),
#  ('e307a77b-88ff-4d42-b924-db71bea6faac',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Vision,Manner,vision and leave that team to move,experience being an engineer typing,core user experience,good user experience',
#    'createdAt': '2019-06-10 08:10:29.699222+00'}),
#  ('bf71a4e7-b54e-4eca-90f8-511b20c7b789',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Desktop,Login,Center,Karthik,wait package version,product or work fine',
#    'createdAt': '2019-06-19 06:05:36.158512+00'}),
#  ('005f0eed-18a4-4991-a5ed-f44d5b58afcf',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'kudos',
#    'description': '@david you should be impressed ',
#    'createdAt': '2018-07-06 13:49:29.675022+00'}),
#  ('005f261e-2b8f-433e-8cbc-eb93a2b8d5da',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'client perf issues',
#    'createdAt': '2017-11-27 06:13:57.565576+00'}),
#  ('0062e318-56d7-4d50-9363-12fed9fa99f5',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'decision',
#    'description': "it has to be a reason at a point and Diamond say okay it's fine for us to make that decision it's not so much about it",
#    'createdAt': '2018-06-13 05:49:53.2087+00'}),
#  ('e0e4a114-5857-4378-a7a1-a9a48c2e2331',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'decision',
#    'description': 'Week of 19th in Taipei',
#    'createdAt': '2018-02-22 03:18:25.83745+00'}),
#  ('410ba6a9-d356-4a35-8ea8-04d985d26408',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "we've got all the integration basically he's got the customers we operations they think to the first three ones so that's a one time yeah one the that's about white thing yeah happens and. ",
#    'createdAt': '2018-11-20 14:48:12.361702+00'}),
#  ('7849de22-d46b-4c70-877f-d5a765905b1b',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Nancy,build that product flawlessly create being impact,half hour interview,product and really guide deep,background in a half hour,customer and your team clients',
#    'createdAt': '2019-06-10 08:12:38.468362+00'}),
#  ('5b35be52-6b50-4e6c-9b08-f6d0791a728f',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'Uber Eats, Drive, Whiteboard, half hour interview, background in a half hour, write down the customer problem, skills and the lead easiest, brighter drive, signs being the market, eye one candidate, focus groups, sickness and clarity',
#    'createdAt': '2019-06-10 08:16:17.994604+00'}),
#  ('93412f9d-e27e-4405-98d5-2e43578df53a',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'kudos',
#    'description': "second question is Josh was awesome can heat trigger these emails himself some way I don't think that's possible that has to be done by developers so I sumus to Josh about setting up a meeting in the next day or two",
#    'createdAt': '2018-07-03 07:13:45.293402+00'}),
#  ('0770e071-1320-440c-a89c-49870dcd4b86',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': 'things price point everything, list on shop attic world',
#    'createdAt': '2018-12-17 08:54:55.466414+00'}),
#  ('0071003f-2181-4ca9-be6c-7f7f9e9443c0',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'kudos',
#    'description': '@trishanth first prod deploy',
#    'createdAt': '2018-10-17 06:02:17.855184+00'}),
#  ('3944f0bb-10e3-4e7e-b72d-44391a9e06f5',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': 'test',
#    'createdAt': '2019-06-24 05:57:30.198563+00'}),
#  ('00890166-3f09-4343-9e36-99a0fcbf1e45',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': ' the application you are going to build in this tutorial looks like the following this is a simple issue tracker application and as you can see if the user interface is split up into 2 sections on top in input form is visible by using the input fields for description severity and ******** to the user is able to enter new issues',
#    'createdAt': '2018-05-26 18:41:00.568601+00'}),
#  ('efaf94a0-81d9-4232-b208-2cdf768f636d',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': 'test',
#    'createdAt': '2018-11-20 11:59:04.612982+00'}),
#  ('85791fbc-c1d8-4ed7-9b9f-a964a3ba6164',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': 'app store',
#    'createdAt': '2019-05-29 20:17:28.854459+00'}),
#  ('3068f29f-9e9c-4ac6-8d8b-bd79e0e06ba4',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'the Cold War,The Chinese Tech Giants,Cold War,the White House,the Network Services,Stephen,Steven,Politico,Google,Molly,Juggernaut,Machinery,Empower,great wall street journal story,ben is it constant friends,serious oh there great day,people who buy those smartphones,video much faster or download,download a video much faster,faster or download a song,download a song much faster,machinery on a factory floor',
#    'createdAt': '2019-05-29 08:57:44.506519+00'}),
#  ('e0d71074-6c2f-4f14-ba0c-af6009e58d0d',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Boater,Dolby,Karthik,free anal sex,kind of walk,invite karthik,morning with dolby',
#    'createdAt': '2019-05-29 20:06:36.766478+00'}),
#  ('009f097a-1604-468e-b8c6-960ee55fe5af',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "Understand slack then I think by the time they're ready he'll be ready to engage them in on Northamer this guy knows Janet anyway what's his name Brahm so Dom sub between Rahman and Trisha and they can find 10 but I'll get them sent to Anil and we can kind of support them to the back and start his main goal one of the main goals does but each of these partnerships that we have people over starting to engage directly OK cool I think that's it to the sink this is Nijil's laptop mandate such a it's a disaster back I think that last week I told I told you I'd like that I ordered because the last bit of it before last and then Amazon and then I was upside down you know they tried to deliver and sad I told her they go to",
#    'createdAt': '2018-05-13 12:09:48.263355+00'}),
#  ('00a71302-61f6-427a-a2d8-e2bc97416583',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "is the act start dynamic before react for to the static after and you that data apps there's only think different page where using the same we can different from an scale an navigation might made actually l p in. ",
#    'createdAt': '2018-11-05 10:51:41.964945+00'}),
#  ('00ab01d1-2cb6-4030-88a2-f787932cb7d0',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'I think this is there is one configuration file in the configuration files I think I am not sure the file name but I have seen a scenario where we have all these notifications to be sent via shopmatic I can we can play store status I will check and update your',
#    'createdAt': '2018-06-28 04:37:19.910174+00'}),
#  ('f43f2436-3636-43c0-9451-251c5fb82925',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': " yeah we've got some explaining where we are in the progress but I've got some ice done turned stuff that we're continuing to work through been on a couple of causes Qualcomm trying to Traverse that network is just open heart surgery but it looks like a good same issue with yours",
#    'createdAt': '2018-01-18 21:19:15.119763+00'}),
#  ('f862827a-8407-4db5-988f-f94f4e9dd7de',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': 'test recording',
#    'createdAt': '2018-11-20 12:01:28.081678+00'}),
#  ('925f35f1-294a-469b-b2e1-c84e1620586c',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Uber Eats,Drive,Whiteboard,half hour interview,background in a half hour,write down the customer problem,skills and the lead easiest,brighter drive,signs being the market,eye one candidate,dive into the data,focus groups',
#    'createdAt': '2019-06-10 08:15:00.021545+00'}),
#  ('68e57ac1-c0a7-460b-9126-3e75defe0811',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': 'study of how many customers we do have for the subscription, put in the terms of service but we have to move',
#    'createdAt': '2018-12-17 09:11:24.273937+00'}),
#  ('00b0d79c-e391-428d-ac28-aa1ddc19c837',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'kudos',
#    'description': 'JKLJ ',
#    'createdAt': '2018-08-01 18:23:07.254424+00'}),
#  ('00b3f79f-ea4c-42f9-b10a-0ddd301e5cde',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'decision',
#    'description': 'Start with markers next, then playback and then SDK integration.',
#    'createdAt': '2018-08-31 06:50:58.121425+00'}),
#  ('3c205eb7-bfac-4539-8a48-b07b660296fa',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'test',
#    'createdAt': '2018-11-20 11:58:40.045512+00'}),
#  ('00b5ec8a-ba8b-4ede-9252-def0dd359f20',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'server side transcription',
#    'createdAt': '2018-04-23 05:41:03.385065+00'}),
#  ('00be40a6-ea14-4274-a6d7-a0f6fde78cd1',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Vamshi update',
#    'createdAt': '2018-10-10 06:19:13.663772+00'}),
#  ('9cac3f18-29d2-4037-9f41-5999a30d5064',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': 'test delorean',
#    'createdAt': '2018-11-20 11:59:29.204019+00'}),
#  ('d6a0cd58-bc8b-4ffa-9b56-a598df3db69d',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Javascript,earlier our long term projects,innovation in your company check,fate and other features function,figure out the best trailer,high level questions,big patient parts',
#    'createdAt': '2019-05-29 08:46:44.317265+00'}),
#  ('186f57b8-cd0f-4c01-a95a-2d88ad3c327d',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': 'paused',
#    'createdAt': '2019-05-29 09:19:35.527343+00'}),
#  ('00d79a44-a1ba-443a-aa0a-28c39a6677c4',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'New things to learn',
#    'createdAt': '2018-10-20 05:04:36.475845+00'}),
#  ('7b064556-cbc5-44a3-a7b6-01223a515a81',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'delorean',
#    'createdAt': '2018-11-20 11:59:35.907929+00'}),
#  ('00e1a3c1-d6d1-43dc-a057-bc3c17ad413b',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': " show the price difference comes after that is hundred and eleven dollar and that too as a satellite we have replica instance created but not configured in any of the configuration files so we will talk to the developers and search and it is not reader if it is not needed will get rid of that particular application that automatically save the cost it will be the same cost what has been running before only things we need to enable multi AC on the primary and backup table currently we don't have backup for the ready set",
#    'createdAt': '2018-07-05 07:37:02.244743+00'}),
#  ('00f0ab89-e0ad-481f-9088-1bc02a7d3d08',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': ' now we can also for example do simple things like let him know that he needs to join this meeting right away and what that that creates an FIR that you can',
#    'createdAt': '2017-12-14 16:01:24.390725+00'}),
#  ('3dd52891-0b31-4e88-adc9-9e14fa6ef6dd',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': 'OK can we take an action item to follow up on this place',
#    'createdAt': '2018-11-20 15:02:49.867721+00'}),
#  ('cee0d7ac-4686-4e3c-b79f-ad9a9fd98f3c',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Pros,Apple,Mercury,G-Force,Windows,phones can get oled burning,prefer using windows laptops,india launched this studio laptop,kind of cool a bunch,studio laptop lineup,studio laptops razors,better performance,invidious announcement,bad some phones,mercury white',
#    'createdAt': '2019-05-29 09:33:03.447954+00'}),
#  ('3b065c36-4ec2-42d7-9cb9-1c2e98a31bb4',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Desktop,Lambda,start looking a socket,land and meeting versus,auto desktop deploy,pretty much working fine staging',
#    'createdAt': '2019-06-19 06:15:35.760541+00'}),
#  ('2397691c-2d6b-4516-8393-dce5c413db2d',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'event',
#    'description': 'recording_resumed',
#    'createdAt': '2019-06-17 11:10:20.476719+00'}),
#  ('14bab181-dfaf-4d0a-9576-59f85dad4bd5',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'personal',
#    'description': 'test personal recording',
#    'createdAt': '2018-11-20 12:01:51.992181+00'}),
#  ('00fb7da5-cd1d-41e7-93b9-96296ea51147',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': ' not required I think it is required should be on the now we should it last date so first half we should talk about the postfix the hotfix deployments',
#    'createdAt': '2018-05-30 07:32:38.22005+00'}),
#  ('01284e13-895c-46ca-8659-14dbadd72249',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': " variable to come to a reasonable business agreement and guiding that's a no brainer I think we'll do it at given where we are the second one which is which is a bigger one is is the VC investment in right now and and and and and",
#    'createdAt': '2018-02-01 14:39:34.43746+00'}),
#  ('012aa841-ec3d-47f6-a5eb-1112e0ae8b24',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'so I am not sure I totally different conversation that are not definitely the hour hour Sarai so maybe is which colour has I get to have some conversation I think that should be a good benchmark',
#    'createdAt': '2018-07-24 16:37:32.306958+00'}),
#  ('de1d7b3f-28b2-4d43-ae08-c7195c21e03d',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'test marker topic',
#    'createdAt': '2018-08-03 10:21:31.822417+00'}),
#  ('92d6c0ab-b028-41a8-9bcc-ab9308a04091',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'fine what just focus',
#    'createdAt': '2019-06-10 07:53:59.513919+00'}),
#  ('eef0b780-c92b-411c-9bb8-17d8b35b831e',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'guys update,call nineteen',
#    'createdAt': '2019-06-10 08:23:59.555451+00'}),
#  ('e7a2707f-f93e-470c-9d68-9df5d84e8e7c',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'event',
#    'description': 'recording_paused',
#    'createdAt': '2019-06-19 06:14:43.270039+00'}),
#  ('1d1bc90f-5517-47c9-81f9-0ffce43656ec',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'test this',
#    'createdAt': '2017-12-12 13:01:30.615109+00'}),
#  ('014027e0-74a8-4ed2-a3c7-b2c2254d37c4',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': "yeah yeah yeah yeah my mom there's a new topic in a decision",
#    'createdAt': '2017-09-18 15:19:27.781949+00'}),
#  ('a9e33697-be68-40fc-87d8-265a7fe51a35',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'decision',
#    'description': 'He wont be a good fit. We can drop him. His basics are not good when it comes to IOS development.',
#    'createdAt': '2019-01-24 07:22:46.907561+00'}),
#  ('f35d93ee-24e4-44d5-afdd-beafed3ba585',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': 'Keywords, Types of keywords & clustering keywords by types, and then naming them into entities. ',
#    'createdAt': '2018-07-19 06:27:51.845017+00'}),
#  ('876013a0-c93b-4cf3-bb89-8704b858594a',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Netflix,include a full size team,well built,universal better materials minor,great hundred percent,true innovative laptop technology,share camera footage,built pretty well as',
#    'createdAt': '2019-05-29 09:55:23.000328+00'}),
#  ('ad06af73-cb1a-46e6-9b31-062a18ce6929',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'action',
#    'description': 'take an action. ',
#    'createdAt': '2018-11-20 12:04:30.644944+00'}),
#  ('48ab2fc6-e8b4-4a28-8a1f-44804f980e56',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'Hartford, Check Hartford, core fee, baking powder',
#    'createdAt': '2019-09-09 07:32:32.287065+00'}),
#  ('4404c9c8-4a64-4c06-b1cc-825858387fde',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Sage,Emma,load balance,deployment server percent,single core classes,latest ml flowcode to save,consider the resemble,dependent sage maker,main model server,resemble added this time',
#    'createdAt': '2019-05-29 09:59:23.024927+00'}),
#  ('93f2bcc5-3796-4475-aced-6e39677d550c',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': " and I will chat about that earlier or yesterday last night they all runs together now logical and what they're attempting and wanting to do right in the email Freight forget about dates for a minute but just the phasing in the logic behind it there's the other ******** which is a lot of creative stuff in it and I think that's probably how we should call it",
#    'createdAt': '2018-04-11 02:49:17.741966+00'}),
#  ('977b786d-a26e-4ffb-8703-84e46178da3d',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Linux 2 Lambda,Como and C C++,today the lambda runtime api,spend almost a full hour,announcements a couple weeks,application dependencies libraries',
#    'createdAt': '2019-06-06 05:53:20.921251+00'}),
#  ('0155f218-13e5-4e9a-bf15-49e2978fc177',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'kudos',
#    'description': 'my guess is wrong she just check the text for the kudos marker when High School',
#    'createdAt': '2018-01-24 05:30:39.012383+00'}),
#  ('01626ccf-b459-40e6-a363-9da0055cfcf7',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'which means the user ID is going to party creative ideas. I will use case is going to different for every hour every person in every car and especially for guess the song used in Association even by doing a such that they almost at most get all this year result date format call only',
#    'createdAt': '2018-09-24 06:42:10.134924+00'}),
#  ('016325af-71f9-48c1-bd4e-496baa643a42',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "we should be thanks thanks anyway so I can sprint review meeting so so anyway going to I am going to discuss from each and every point then we're going to write of it ok then",
#    'createdAt': '2018-08-24 05:56:19.063751+00'}),
#  ('18ed91a6-36a2-45a3-b752-5c639b9f0dff',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'temp1',
#    'createdAt': '2018-08-03 10:24:37.578682+00'}),
#  ('a3a93cba-bd40-4e58-9c1a-5d2e5c313f0a',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'University, Paul, boys early bad allergies, count why boys early bad, generators to count why boys, water or high speed internet, time to install power laurel, errors on the university professor',
#    'createdAt': '2019-05-29 14:02:17.062564+00'}),
#  ('edcf7676-a5bb-446a-8f34-1d0bc94c52ff',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'action',
#    'description': "Do your video as you normally would tall good and ether will continually monitor what you're saying and start to you know, show them in the iPad in your timeline as and when it detects us something important to be discussed. Like for example, I can say a John can you take an action item to follow up on this and you know, ether will not lie detect that but also start to you know ping John to pay attention to this discussion that's ongoing like these types of interactions are supremely important as the distributed in a price starts to expand more and more and for people to feel more and more that they need to be part of a you know an ecosystem.",
#    'createdAt': '2019-04-23 17:26:25.219084+00'}),
#  ('0174e777-3cca-4d64-a3e9-1ac6fe848a85',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': '@karthik, @vamshi Can you please check with @ankur on the ICR branch merge etc',
#    'createdAt': '2018-09-17 06:09:26.609845+00'}),
#  ('ac25c514-fe20-481f-a99b-71e78485f111',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'test',
#    'createdAt': '2018-11-20 12:04:20.74667+00'}),
#  ('01837b65-e45c-434f-b330-37a705fc3b64',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': '5+1 override here',
#    'createdAt': '2018-01-26 09:13:33.870937+00'}),
#  ('0192a2a1-278e-4c4a-bc55-aab68c67c80a',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Test',
#    'createdAt': '2018-01-24 15:01:32.506119+00'}),
#  ('0199d488-54bc-4dfa-9deb-78c7b5188762',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': " let's begin by talking about what it is all about and how we are Reinventing Enterprise collaboration",
#    'createdAt': '2017-11-16 07:31:55.541636+00'}),
#  ('d75ea89e-90a9-4da2-88c3-3cb4f24474ba',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'event',
#    'description': 'recording_paused',
#    'createdAt': '2019-08-05 07:22:59.230181+00'}),
#  ('01a3d369-c3b6-4299-8d2e-43fb505369a2',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': '@sai - pay attewntion to',
#    'createdAt': '2017-09-15 17:18:42.916227+00'}),
#  ('2db803bd-9e91-44b4-bfe9-e3020e110426',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'action',
#    'description': "Great, you get that question a lot. So what are they looking for? So what we're looking for is the exact thing that we just talked about those nine skills. And the easiest way to break. This down is to structure your answer into the skills that we just talked about. Right? So first what I would suggest is go to the Whiteboard, right and then write down the customer problem customer needs that you see in your mind. So there's going to be more than one right and for and there's going to be there might be more than one customer right? There might be like, you know for Uber certainly there's no Rider driving. There's two sides me the market there. What are the customer problems? Right? What are their needs? What are the customers have to say? What does the what a qualitative research saying what did focus groups say what the sales say? What does support say what is the feedback that you're hearing customers? And then secondarily, what's the data that you see right so dive into the data and make sure that you really truly understand.What's the problem now in this case? If you just don't know what that is, you're going to have to make a substance, right? So you'll have to say like icing the customer feedback said XYZ or on if it's a question about a product that the company that you're interviewing yet. You're not going to know right? So you're going to have to ask follow-up questions. Like what does the data say? What is focus group saying what is Court saying about their the product that the customer needs are so after you go to the board and write down the problems. You'll want to write down like three or four different problems that you're trying to solve and pick one of them in the most important thing we're looking for is why right like you're going to have to make assumptions around like I said, but you're going to have to say like I'm going after this problem. It seems like the most impact for both our customer in your business in the main objectives that we're going in. So that's the third piece Raven. What are the objectives that you're trying to solve right? Are you trying to solve for engagement are going to start so for more user through you?. ",
#    'createdAt': '2019-06-10 09:41:26.002484+00'}),
#  ('f0f9b31a-cdc0-4284-b692-66ffe7d9953a',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'decision',
#    'description': "They have this channel called the interviews Channel within within eater. Right and we're talking to candidates all the time right all the time. And the way we do it is we just you know, let's say that lets say I'm a candidate and you're kind of the person who's interviewing me. I see a we send them a guest link and it just shows a video. It doesn't show all this coal markers and any of that and that is on your side, you're like tagging and marking and things all the time and then the interviews over and then the next person I say I think this was like a new put your decision at the end of the call and the other person's is the next person who's in the panel comes up and says, you know, so how was the candidate right and you often have to say well as and there's any thought and I think it was a little bit weak on this and so on and so forth now he can just go look at the spot called Parts get a full understanding and pick up the interview literally where it was left off the last. Same right. And so we call this like the panelists application right like The Ether panel application. So it's like a and it's a continuous thing. And then now you can go back and when there's a new person coming into your team. You say you want to know how we do interviews. Just go watch these five ten things, right? Yeah sort of.",
#    'createdAt': '2019-02-07 17:04:37.005802+00'}),
#  ('01c50d08-d24b-4b1d-ad7f-bc263bcd85a7',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'decision',
#    'description': "OK so how do I go about doing that so let's say we decide to do that how how do I go about doing it what should we do",
#    'createdAt': '2018-01-11 05:13:28.518147+00'}),
#  ('cb6421ff-68fd-4d7d-b74a-3f14b844b4c7',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'personal',
#    'description': 'personal',
#    'createdAt': '2018-11-20 12:05:35.164224+00'}),
#  ('01c788ad-e660-49e2-8bd9-d3149c9a2894',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': 'marker',
#    'createdAt': '2017-12-11 18:45:41.506367+00'}),
#  ('f401b850-365a-4f51-8fe9-4fb8eab78f0e',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': '@ashwini does this work?',
#    'createdAt': '2017-10-11 08:47:35.541783+00'}),
#  ('ebfd1d55-370f-4f53-8de6-fad5a3eafbc9',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Trump,intelligence in investigation education,sixteen quarter,campaign a spread,department at the sense,long and extend,state said the team',
#    'createdAt': '2019-05-29 10:24:42.604104+00'}),
#  ('07fd577a-635c-4cf5-bf69-0f94c13f75f8',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'Maneuvers, Farm, twenty day Harvest, started inside, early in the northern climates, start your tomatoes and peppers early, good harvest, warmer climates, start a lot, lot of your seeds',
#    'createdAt': '2019-09-05 14:34:41.673437+00'}),
#  ('ba4ea493-0af8-45be-aeef-fb8a80c92d7f',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Partners in Channel,Professional Services,Top Line,Vonage,Smart,RingCentral,Patrick,professional services smart video application development,smart interviewing applications click,bring this intelligent persistence experience,vonage or board blue jeans,pretty reasonable top,custom smart persistent video,ooh and krish a couple',
#    'createdAt': '2019-05-29 15:41:26.281221+00'}),
#  ('a191f25f-0a88-4f76-b306-a1a42143e157',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'facebook right is quick,quick and that slack',
#    'createdAt': '2019-05-29 10:29:42.70446+00'}),
#  ('944ac90c-0c67-4823-889d-9f952a62e87a',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "This Together going to have to make a choice I might put this view in myself and especially talking with Sai just looking at the realism and when things are going to happen and I don't think looking is another one but it's not going to be a functional feature that you're going to get a whole lot of success with and so because you don't want to do that if you don't have a mobile app there's a lot of work with notifications",
#    'createdAt': '2018-04-19 03:31:33.64326+00'}),
#  ('80ce9b3d-09c5-4069-a218-20c736ed9155',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'i just plain a lucky on like not see all gonna wow could last one. ',
#    'createdAt': '2018-11-20 12:09:18.535437+00'}),
#  ('01d4b632-1d84-4a6d-a953-8fcbcab3d2e2',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'decision',
#    'description': ' just fill it out when you both maybe just take it like it filling it out whatever you know just dumped this is scratch pad anyway just put whatever you think is there and then we will decide like will think about how which ones we take for September and which ones you put off right things like that',
#    'createdAt': '2018-09-02 11:47:09.604442+00'}),
#  ('ec3a1920-50e4-4c4c-893e-ed2089e9d72c',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': 'Thinking machines: https://www.youtube.com/watch?v=IbrTkUE4YHs&feature=youtu.be',
#    'createdAt': '2018-07-19 06:42:40.098032+00'}),
#  ('3a6d9285-c5cf-4668-829f-c6f6f4215787',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'ink has got higher relative, incubate and sqs, sqs has that pull, process is infinite',
#    'createdAt': '2019-05-29 10:29:13.412951+00'}),
#  ('b013b8d4-3615-4b97-88e4-0f2faa8f9db8',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Test-DeLorean',
#    'createdAt': '2019-05-29 12:02:50.47027+00'}),
#  ('a9887393-7e5f-44a4-ba93-09778c59e82f',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': 'overall goal product, particular product in the ways, people that have a domain expertise in certain, right problem right measures place',
#    'createdAt': '2019-06-10 09:51:59.695426+00'}),
#  ('94962a72-f89e-4545-bd4f-529a9d8b1ff2',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'check for the email',
#    'createdAt': '2018-09-27 06:10:16.477289+00'}),
#  ('f6b29bf7-6d81-45da-916a-8025910eab34',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': '@cullen the audio level seems okay from my Ipad',
#    'createdAt': '2019-05-15 14:06:07.548184+00'}),
#  ('01e3f535-fc59-494b-add7-807935d9fb04',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': 'Home shows all your work, aggregates all your notifications across all products (mentions, comments, etc). ',
#    'createdAt': '2017-09-13 17:30:10.511347+00'}),
#  ('01f95bd7-3139-4145-a69f-2eadca9462b5',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Samar onboarding',
#    'createdAt': '2018-03-14 03:02:08.247559+00'}),
#  ('020f5ef4-a4a9-4578-a4fe-2b07dbd4cefc',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "this week we're wrapping up Spring tornado should deploy next week within 28 includes Park search which will Deploy on Pro got wet so we can test it on and then export CSV",
#    'createdAt': '2018-08-16 02:51:41.13884+00'}),
#  ('021380c9-fd29-4e78-8141-0f2c9d18a1ea',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'one more',
#    'createdAt': '2018-06-20 06:55:42.947143+00'}),
#  ('4f3a930a-646a-4f31-85a9-7f5dc3f37f59',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'event',
#    'description': 'recording_paused',
#    'createdAt': '2019-08-05 07:24:17.706323+00'}),
#  ('18bfbe8b-c32e-4986-abab-2eb1ead4c5e4',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "So what I'll do is I'll stick to this one. I will play around with this structure alone because I was thinking that encode a big I remember you told me but I forgot. Okay. So so what I'll do is I will stick to this one and I'll just play around with this for for I don't I don't know whether I can compare it with the existing model, but I will play around with this and meantime, maybe can you just just see if you can fix it. If you face any problem we can you can debug it together tomorrow. Yeah.",
#    'createdAt': '2019-01-08 08:24:31.399206+00'}),
#  ('951d7995-ebf6-41c9-ae49-3b19c49dbf7f',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': '<<Start>>',
#    'createdAt': '2018-08-23 16:07:42.313293+00'}),
#  ('953693e5-9f49-4111-9a78-e96f46648c5b',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': 'so right now will talk about how the delorean pipeline works with respect to any conductor meeting and push Back to Future',
#    'createdAt': '2018-05-07 07:31:10.986765+00'}),
#  ('021ff722-36c5-4c6f-b70b-6fe6643b022b',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Generic ChannelMind ',
#    'createdAt': '2018-08-07 16:24:02.42692+00'}),
#  ('3c64d60d-3660-4744-afd5-9f49fb3d5cc6',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'check context,weight age,mask the graph,language model,specific domain',
#    'createdAt': '2019-05-29 12:06:50.390228+00'}),
#  ('0237701b-ff6e-4a11-821e-fd65fddc0c71',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': '@trishanth - If the ECS/Terraform work is going to take a few more days, maybe you can complete the keywords changes and go back to it. Also did we have any further insight into the the ID related issue with terraform that we ran into last week?',
#    'createdAt': '2018-07-02 14:54:28.987023+00'}),
#  ('0243ba7e-39b8-46db-a3f7-64ce877cea16',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': ' usually it will be the last one to leave the meeting right so I guess that could be a way to detect as well whether it a recorder left before others other active participants',
#    'createdAt': '2018-01-25 06:39:55.604892+00'}),
#  ('4ab66bbc-8c4f-4e13-95f2-b19cc1609f9b',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "As many as possible and we have given ourselves. Let's say three weeks or maybe four weeks and then one more week for deployment. Okay, if we are going to work on wall reliefs items. Okay, unless there's an emergency or some requests that monster me.",
#    'createdAt': '2019-04-06 16:03:14.159247+00'}),
#  ('0247b787-205e-4c94-9e95-7fcc61729196',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'decision',
#    'description': ' so we have an experiment in so nice and fancy',
#    'createdAt': '2018-01-11 05:26:38.786253+00'}),
#  ('f2a7ed85-ec17-4a7d-952c-c42e39693af4',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'keyboard onboard,fish origin,individual elements,half design,empty space',
#    'createdAt': '2019-05-22 09:40:09.734349+00'}),
#  ('02527b53-535e-495c-a8e4-dabd5447a7a4',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': '@ashiwini need to get a better internet ',
#    'createdAt': '2017-11-28 05:31:52.914127+00'}),
#  ('02565047-8393-4bbe-996a-3a0e902c7705',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Speech processing',
#    'createdAt': '2018-09-09 08:51:23.367754+00'}),
#  ('e17fdbfd-c28d-47f9-9d17-b4318459ff3d',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'kudos',
#    'description': " got it excellent that's good good job guys together",
#    'createdAt': '2018-07-19 16:32:07.998926+00'}),
#  ('e7294d6d-ba29-43b3-96e5-dd02feeb1045',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'end points that the clients will use to submit audio file as input along with summary data so that we can process the transcription asynchronously in stored in the database and Amit events of crossing at FIFA 17 September 17 so that end point is completed now with respect to ETA 2.2 there are certain change is being made to how the meeting and endpoint interacts with the rest of the stuff Anitha platform so we need to figure out how to tie the specific transcript that gets captured from the recording to a specific meeting you know how to do it we just need to know I just need to discuss one she has to where to place that Court so I need to work on that part right now',
#    'createdAt': '2018-08-03 12:05:16.789598+00'}),
#  ('f366aa8e-25eb-47bf-80d3-67bd5f6fb143',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Missing automarker',
#    'createdAt': '2018-01-19 05:36:02.682051+00'}),
#  ('ffde23a1-24ac-4660-8d6b-9ab7f9ea452e',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Automarker issue on the top of the timeline',
#    'createdAt': '2018-01-19 05:33:06.015052+00'}),
#  ('cd6d9f32-9a45-4327-bc7b-61d6dbe682e1',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Lauren,Watson,Java,trouble of car and human internal,markers times public experience,tomorrow have role collects reality',
#    'createdAt': '2019-06-19 07:07:30.882118+00'}),
#  ('d5b1f6cb-4289-4b39-9c6c-456f87dc6cdc',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Top Line,Dolby Vonage,Bridge Zoom,Dead on Arrival,Audio,Partners,Nina,Ether,audio bridge zoom blue jeans vonage,phone number pound pass code,month on paid media,business development partnership work,integrate into blue jeans calls,blue jeans ether meet,kind of route call parts',
#    'createdAt': '2019-05-29 20:16:47.388791+00'}),
#  ('954c1fed-5e2e-41a2-8506-2d7eaa0753c7',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': " what you can do tonight see all along a fairly flexible anyway right so the idea was not you know definitely have Expectations where would like to work with like you to work on things that are not a mechanical parts so that you have more flexibility with your time has been Idea LOL LOL so I will be with you in the sense that you know you decide how much you want to work and how much you can work and you know if you do have time if you busy for a few weeks just give me a heads up saying I'm going to be busy for the Furious right whatever and then if things come back up you can take backup if that you know that's what you like to do I am ok with doing that now",
#    'createdAt': '2018-09-05 16:03:00.774261+00'}),
#  ('9560add0-2e87-4455-8b39-5960f884a884',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'kudos',
#    'description': " I'm happy to tested as soon as much as as much as possible I might even try yeah yeah not I've got a board meeting on Saturday that one that bought for this business that uses like we won't be able to turn around by Saturday but I'll have to give it a try for that for the next one yeah awesome yeah it's very small at the moment but it'll be",
#    'createdAt': '2017-12-14 02:57:40.987682+00'}),
#  ('025d6719-bd78-4065-bc62-a096a9ae60e4',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "it's should have call you i'm how i good reading to video yeah the video working i don't see you one we hear i see your point so one yeah hey yes i able we're to see my myself and earlier. ",
#    'createdAt': '2018-11-12 08:57:55.529762+00'}),
#  ('026c79a2-28b2-41f2-bfed-84fec0c0a47b',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': '@ashwini is not coming back to blore',
#    'createdAt': '2017-11-15 05:06:44.897391+00'}),
#  ('02775b29-1d5e-4452-904d-40a121cf805e',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': " the output of know where you and I want to leave that meeting right just to make sure that you and I keep staring at that and we get it they're ******** you know what we're talking about is where they are so I'll work through some of that today testing so I don't get a bunch of clients go on and let it run",
#    'createdAt': '2017-12-12 14:00:53.675992+00'}),
#  ('fc3ebc18-2c40-429e-93b3-f25c2a3c243f',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'kudos',
#    'description': "Sitting guiding the discussion there and see what he says because that's the closest and fastest path for us to Revenant. And now the downside is says go it's awesome. I got this customers whatever. We're just going to need to hire more Engineers to do some of the custom development on top of the platform, but that's that's a good problem to have because we're chasing the era.",
#    'createdAt': '2019-05-29 15:01:30.392839+00'}),
#  ('49826652-6aec-4dd3-a44a-4d0ac32c1f24',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Chrome,Arrow,professor doing the required tv technology,recommendation components position arrow,chrome reach human level,bit i kind really hear',
#    'createdAt': '2019-06-19 07:12:30.924393+00'}),
#  ('956addd1-0327-4d8f-96c1-807ed8b9de56',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'after is done with the next few things so will not think through then how much effort you wanna put into all of that right in from your ex perspective but my guesses will just keep them so that the trade off that we have to make is he eventually need to go start working on the SDK iOS SDK which is very different from is a completely different type of work because we need to package it differently expose period very differently is very different from a nap doing User experience stuff so my guess is he going to keep the User experience exclusively u know very very low key and just get the capability and but literally just Kanna focus on the SDK',
#    'createdAt': '2018-06-04 14:28:02.39759+00'}),
#  ('02a6c107-3ce6-4957-9a0a-76971130b4ed',
#   {'attribute': 'markerId',
# ...
#    'description': " part of the Google as well and then the column is basically talks about having how many campaigns we are running in a particular category subcategory for that matter right column into 5 columns E5 2660 3rd October month on month number of campaign we are running in plan for that for that particular month and then similarly if you go through the next search category which is non brand I'll give example of non veg category and the rest of them for the it is easier for everyone to understand what buckets of the category for thunderbird campaign and then how many campaigns we are running month on month and probably and we can also deep down under the number of Aamir amount that is pending on these doors Patil category and the efficiency in terms of believe that we're getting from this particular category subcategory month on month",
#    'createdAt': '2018-04-11 09:24:56.493237+00'}),
#  ('1390eec9-e494-4bed-afc6-685c51a140c1',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'kudos',
#    'description': ' good job',
#    'createdAt': '2017-12-11 11:27:43.64748+00'}),
#  ('53804566-5fe4-44e6-b477-72c5d84d27db',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'site general manager talks, website application product year, email distribution list, sense stay stakeholders, product yet certainly people finish, lots other people convert, help us generate insights',
#    'createdAt': '2019-05-30 18:34:32.135797+00'}),
#  ('9eb824a3-6a15-40c4-b73e-03ecee4b4e7e',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "Let You saw and slack right. I just put that on I U. S. And well, don't worry about the time for a second. But when I creating right, Firstly, incredibly easy to create markers. I I think on I S that experience of being able to like and speak the item becomes what's well, but we're I'm creating the market. The rest to the team should know that I am actually not in the conference right for those use like that, right we get the which is great. But if there is some signaling that we can do to make that to domain that it'd be nice we can think that ticket can think about what we do then, but that is one thing that I thought to be useful and we the like. We.",
#    'createdAt': '2018-09-27 06:39:23.804951+00'}),
#  ('1e2848bd-82c1-49df-a3f4-613d56d58988',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'text development partner, true partnership, custom model',
#    'createdAt': '2019-05-23 16:35:20.832073+00'}),
#  ('1391ba50-4f77-4c11-ae7b-dc6e06e75f99',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'new test mrker',
#    'createdAt': '2017-12-12 12:49:50.908005+00'}),
#  ('1395a3dd-e594-4d0d-aa45-d7ea276d4606',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'functions of different of the public has changed but its not added to this display already all the fun and easy dress in August and syntax for easy',
#    'createdAt': '2018-09-26 05:24:56.391516+00'}),
#  ('139a624d-0f8c-4287-a1f0-b45205553d93',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Netflix',
#    'createdAt': '2018-08-07 15:20:34.566494+00'}),
#  ('13a4baad-b2db-422a-a015-fe1141bbf09e',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': 'Project Plan for S2T activity',
#    'createdAt': '2018-07-05 04:26:56.373772+00'}),
#  ('13a8e2ba-5cf4-498a-b6f5-486fd40cfcc6',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'Archer. ',
#    'createdAt': '2018-09-25 11:41:17.291578+00'}),
#  ('13cf2cc2-21b2-4e95-adb1-d83ea1141de8',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Video quality assessment',
#    'createdAt': '2017-11-15 09:23:59.073497+00'}),
#  ('90a6756f-8691-4062-876b-53a15594e34d',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Organization,Facebook,Brand,Ambitions,Cartier,scale justjust crew general,building a high fashion brand,personal brand level facebook,difference between a personal facebook,answer is for business purposes,strategic planning process,best of a bad situation,acts human,matter how big or small',
#    'createdAt': '2019-05-30 18:20:19.341878+00'}),
#  ('9ee33cf5-2d5b-462b-a999-82606c8bc324',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': ' FYI',
#    'createdAt': '2018-10-08 18:53:53.489328+00'}),
#  ('9f0decb4-4996-4520-84b9-b84930c8617a',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': 'test fyi marker',
#    'createdAt': '2017-11-02 21:14:11.150552+00'}),
#  ('13e5fb04-63ee-40a2-a523-c0064d657dc3',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'React Native audio levels',
#    'createdAt': '2017-12-20 06:08:54.457027+00'}),
#  ('13e98389-3eae-48e8-9468-83fe60cc6c48',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': 'there are few english words :P',
#    'createdAt': '2018-09-25 05:48:45.500334+00'}),
#  ('13ed82ad-7c5d-4d40-b5c0-661c4fa73eb5',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'kudos',
#    'description': 'yeah awesome so',
#    'createdAt': '2018-07-06 14:07:50.559459+00'}),
#  ('13f14c89-7046-4097-95b7-2476b29382af',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'action',
#    'description': 'you should check with everybody on the tomorrow',
#    'createdAt': '2017-09-16 15:56:49.640054+00'}),
#  ('140a5cdd-ed76-46a3-9494-ea1a8476454e',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': " yes and then Taipei I don't think anyone would be meaningful for you unless it was an issue a question so you can always use in church and also go out to link you to the right person have any questions about the Tibetan right now is a bit",
#    'createdAt': '2018-07-02 07:22:09.350272+00'}),
#  ('467d78b0-7ad0-444e-8a03-91f6d6253964',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'topic',
#    'description': 'Screen Sharing ',
#    'createdAt': '2017-10-23 05:31:59.116748+00'}),
#  ('140f1b7c-3374-447a-a5e7-d26c6e4d2d5f',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "on request a demo oven in action in unreleased fever from was the day of course now we have that found it hear it in the studio if the Vivo x21 Anitha Nair exists Snapdragon 660 660 3 200 million power battery and 6.3 inch 1080 p oled display for the crazy optical fingerprint sensor under Ne Suna do we have in a fresher connect your work we have no choice but to test the limit for their question ok quick refresher and how is what you cannot be entire original video for the fallen down the basic read this is a small optical sensor on need for gas oven oven display listen to it officer is mosambi the size of a string in MVC application server literally mean it's Dio light shining apply to reflect office use finger and sensor reading reflection of your finger acidifying a person fb.co possible innovations today just because it out of technology work so we can think about is quotations with touch id to perform a serious",
#    'createdAt': '2018-09-07 10:09:30.047908+00'}),
#  ('1412518c-d9c3-44a9-8130-e6a688370259',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'kudos',
#    'description': "8 minutes and it's needed by there I'll see you later awesome dependency and here",
#    'createdAt': '2018-01-22 09:45:22.673077+00'}),
#  ('1415f771-8157-42a6-b83e-47e73f55ce8c',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': 'Testing how the keyboard works on iOS and why is it so jumpy. I think the keyboard lags behind sometimes and then it becomes a problem for the writer ',
#    'createdAt': '2018-11-14 07:38:11.092414+00'}),
#  ('14213808-4c33-4347-801f-b3a71d7a2c76',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'action',
#    'description': ' whatever it takes we should do that now rather than long hours trying to debug in production when something goes wrong',
#    'createdAt': '2018-01-11 05:23:39.706051+00'}),
#  ('9911b572-20c8-4de3-880a-5f025e29754c',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': 'test',
#    'createdAt': '2017-10-26 22:33:12.114008+00'}),
#  ('f54468f8-2558-418a-ab83-c75ae0301fbe',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'action',
#    'description': '@cullen wash your hat',
#    'createdAt': '2017-10-26 15:39:12.191513+00'}),
#  ('a7203c1e-7603-4cae-ba9a-4b8477997952',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'decision',
#    'description': "Vision where do you live at right? So first off? I don't see my CMO in here if he happens to be in here. I sure I'll be I'm sure I'll be looking for work later because you guys can look me up. So so I say it's under the direct Commerce team at Sony we sell all the electronics TVs laptops cameras - PlayStation that's from the out of a different division and we support both online and offline channels. Sony is is a wholesaler retailer right traditional wholesaler that's been moving into the Realty retail business and and actually my history. I've also when I was at Nike was the same as the wholesaler or retailer. So my first interactions with the CMO was I got this email and it said, you know important email and it's a basically I need ten numbers from you an hour an hour ago.And I produce those numbers and some of them are positive. Some of them weren't and the CMO chose which numbers made them look good had the press conference and we kind of we kind of went for that right and you know, so that's how it started that that's not necessarily great cycle to be in in terms of how to communicate to a CMO when I was at Nike the people that were very very creative not data focused and so I would say pretty pictures always help to do the telling of the story at Sony it's more engineers and people who have maybe more of a data background. So just in the genetically they're engineered to life data and want more data and so numbers can work there. I would say though as long as you're telling that positive story in terms of the CMO is hearing what they want to hear it almost doesn't matter what format you give it to them. They're going to be happy. It turns out it becomes. ",
#    'createdAt': '2019-05-30 18:10:33.764927+00'}),
#  ('4f3fbd50-4d03-4ee6-a937-ba8e8e8552a6',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': 'Late on the first install you would have got an error ones. So what happens is I do a roll back roll back. So you go to an older version of the board because you face the difficulty in the first wave, but in that version also, there are some issues.',
#    'createdAt': '2019-01-29 06:35:37.266875+00'}),
#  ('24e9bfaa-966b-4fe0-998c-d289cd11f93f',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'decision',
#    'description': "The New York Times, I'm Michael LaBarbera. It's Wednesday, June 19th. Here's what you need to know today. On Tuesday President Trump's acting defense secretary Patrick Shanley stepped down after the president withdrew Shanahan's nomination could permanently fill the position the decision followed a background investigation Shanahan by the FBI, including allegations of domestic violence inside his family in one episode. Shanahan's ex-wife accused him of punching her a claim. He denies in another episode. Shanahan's teenage son beat his mother with a baseball bat and action that Shanahan at one point defended as self-defense by his son, but has since called unjustifiable.",
#    'createdAt': '2019-06-19 12:31:55.274836+00'}),
#  ('14295b31-5f4f-4e8b-9d97-14e30edf5d72',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "15% silver 15% on top if we continue to get paid for the same level as we have as it's highlighted in this this is a head count I con trampa plan in the expenses sheet",
#    'createdAt': '2018-07-19 03:36:14.606732+00'}),
#  ('142b13a2-ae3b-4764-b946-1c4d33b287dd',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'kudos',
#    'description': " and you can go back to the call and view it so I'll show it later but essentially what it means like if I say something like a great job on the on solving the ******** on creating a new ******** for whatever you working hours overtime with ****** properly webpage will be able to take that part of the conversation transcribed it and it'll send it to the back and until figure out okay this belongs to a good as marker and Tag and poor time like you think about it like a lot of conversations happen and lot of people have different gana market it can get more info more information about overall team productivity and stuff so you can do things like and integrations you can have hooks that subscribe to this type event types and",
#    'createdAt': '2018-02-16 18:36:07.670025+00'}),
#  ('143a6b2b-c7d3-44cc-83c2-e2d0b6b1abd6',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'fyi',
#    'description': 'Able to hear Vamshi in post call',
#    'createdAt': '2018-09-12 11:01:25.843948+00'}),
#  ('8ec78c86-98d0-4c00-bed4-7bc5a41384be',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Java Ruby PHP,EV S,Fortune,Amazon,Customs,Cloud,Micro,Trusted,launch your servers big machines,pull out reports every month,twelve or thirteen regions',
#    'createdAt': '2019-06-10 12:50:57.197546+00'}),
#  ('51190704-507f-45bc-95b8-42e9b7e82811',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'chapter',
#    'description': 'Super Rad,Apple,Journey,Tuscany,Earth,Alexa,Google,Patrick,super rad machine learning,partner with the smoothest taste,vertical as opposed to shallow,voice flapping blockchains in unbelievable,blockchains in unbelievable technology,top of alexa and google,built on top of alexa,create rod session',
#    'createdAt': '2019-05-30 18:30:09.575195+00'}),
#  ('2207a093-43d5-47bf-9232-b43b4d6fbbe0',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'kudos',
#    'description': "yeah i don't much about the language model one day should kind of maybe i'll seen you and you can explain to be better you on yeah i do need that guy that would be awesome yeah i'll believe that yeah good go looking. ",
#    'createdAt': '2018-11-20 05:50:47.640364+00'}),
#  ('143e6653-c1ff-4800-9d47-33b81b65e9be',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'topic',
#    'description': 'what are we talking about next',
#    'createdAt': '2017-09-15 03:02:00.635629+00'}),
#  ('14580822-b83e-4627-863e-9f6bad646a3d',
#   {'attribute': 'markerId',
#    'automaticMarker': True,
#    'type': 'fyi',
#    'description': "for the longest this time get up is all about storing source code and sharing it i'll with the rest of the world all your colleagues create come any which is in the process of being quite if taking a huge step in different by related direction get have actions allowed the developers to not just code on the platform but also run it we're not talking about a new cloud drive of this year for instead about something more to flexible i for the developers who want to that development development work plus where is that understanding notifications of building a full continuous integration and deliberately pipeline. ",
#    'createdAt': '2018-10-17 17:19:40.843396+00'}),
#  ('e0b2db80-cf79-4dac-b19f-49ca1cc35628',
#   {'attribute': 'markerId',
#    'automaticMarker': False,
#    'type': 'personal',
#    'description': 'test personal',
#    'createdAt': '2017-10-27 06:54:44.017701+00'}),
#  ...]

# %%
meta_graph.add_nodes_from(marker_node_list)
meta_graph.add_nodes_from(marker_user_node_list)
meta_graph.add_nodes_from(marker_instance_node_list)

meta_graph.add_edges_from(marker_user_edge_list)
meta_graph.add_edges_from(marker_instance_edge_list)

# %%
print(meta_graph.number_of_nodes(), meta_graph.number_of_edges())
# Out:
# 32313 59755

# %%
meta_graph["8d6db5f7-d9b7-4c54-ba38-fe710ffcaf3f"]
# Out:
# AtlasView({'01DBB3SNV7ZWSB8FNW2448RF49': {'relation': 'belongsTo'}, '01DBB3SN8CSNZ3Y25PAFQM5059': {'relation': 'belongsTo'}, '01DBB3SNN9BS4JZ1G4TER7YXNZ': {'relation': 'belongsTo'}, '01DBB3SPGT34NG93ZHVS08J2Q9': {'relation': 'belongsTo'}, '01DBB3SNVBQXVQ7MKE9JH796BV': {'relation': 'belongsTo'}, '01DBB3SPH6XKEPFSHS9K8EVXPV': {'relation': 'belongsTo'}, '01DBB3SNEZGZBPQB17GG6SW9PX': {'relation': 'belongsTo'}, '01DBB3SNSKT8DQXNCS8M6PBJJJ': {'relation': 'belongsTo'}, '01DBB3SNYC0Q8P238G69HMSWMM': {'relation': 'belongsTo'}, '01DBB3SP5N6PH88VWBHJCXNG3B': {'relation': 'belongsTo'}, '01DBB3SNM3VC7KJ960V2F29FH9': {'relation': 'belongsTo'}, '01DBB3SQ6PR502SX3D4S4G2518': {'relation': 'belongsTo'}, '01DBB3SP385R67YAWJWXV6YHQW': {'relation': 'belongsTo'}, '01DBB3SNVF5MTFMMZR1F3W13KE': {'relation': 'belongsTo'}, '01DBB3SN99AVJ8ZWJDQ57X9TGX': {'relation': 'belongsTo'}, '01DBB3SPPDNJX40G2QCA74D3KQ': {'relation': 'belongsTo'}, '01DBB3SNQZ4JH09ECV1G4F2GJW': {'relation': 'belongsTo'}, '01DBB3SPEKEH02GC8M
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 7 columns):
# workspace_name                          212 non-null object
# workspace_id                            212 non-null object
# channel_id                              212 non-null object
# channel_name                            212 non-null object
# context_id                              212 non-null object
# mind_id                                 212 non-null object
# customer_id                             212 non-null object
# dtypes: object(7)
# memory usage: 11.7+ KB

# %%
mind_node_list = prepare_mind_nodes(mind_info)
context_node_list, context_mind_node_list = prepare_context_mind_nodes(mind_info)

# %%
mind_node_list
# Out:
# [('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAYHEKY5F4E02QVRJPTFTXV',
#   {'attribute': 'mindId', 'name': 'Ether Engineering', 'type': 'custom'}),
#  ('01DAAYHEKY5F4E02QVRJPTFTXV',
#   {'attribute': 'mindId', 'name': 'Ether Engineering', 'type': 'custom'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAATBC3AK1QWC5NYC5AHV2XZ',
#   {'attribute': 'mindId', 'name': 'Product', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQYN9GBEBC92AYWNXEDP0C',
#   {'attribute': 'mindId', 'name': 'HR', 'type': 'domain'}),
#  ('01DAATANXNRQA35E6004HB7MBN',
#   {'attribute': 'mindId', 'name': 'Marketing', 'type': 'domain'}),
#  ('01DAATBC3AK1QWC5NYC5AHV2XZ',
#   {'attribute': 'mindId', 'name': 'Product', 'type': 'domain'}),
#  ('01DADP74WFV607KNPCB6VVXGTG',
#   {'attribute': 'mindId', 'name': 'AI', 'type': 'domain'}),
#  ('01DAAQYN9GBEBC92AYWNXEDP0C',
#   {'attribute': 'mindId', 'name': 'HR', 'type': 'domain'}),
#  ('01DAAQYN9GBEBC92AYWNXEDP0C',
#   {'attribute': 'mindId', 'name': 'HR', 'type': 'domain'}),
#  ('01DAATBC3AK1QWC5NYC5AHV2XZ',
#   {'attribute': 'mindId', 'name': 'Product', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAATANXNRQA35E6004HB7MBN',
#   {'attribute': 'mindId', 'name': 'Marketing', 'type': 'domain'}),
#  ('01DADP74WFV607KNPCB6VVXGTG',
#   {'attribute': 'mindId', 'name': 'AI', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAATANXNRQA35E6004HB7MBN',
#   {'attribute': 'mindId', 'name': 'Marketing', 'type': 'domain'}),
#  ('01DADP74WFV607KNPCB6VVXGTG',
#   {'attribute': 'mindId', 'name': 'AI', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAATBC3AK1QWC5NYC5AHV2XZ',
#   {'attribute': 'mindId', 'name': 'Product', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAATBC3AK1QWC5NYC5AHV2XZ',
#   {'attribute': 'mindId', 'name': 'Product', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAATBC3AK1QWC5NYC5AHV2XZ',
#   {'attribute': 'mindId', 'name': 'Product', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAATANXNRQA35E6004HB7MBN',
#   {'attribute': 'mindId', 'name': 'Marketing', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAATBC3AK1QWC5NYC5AHV2XZ',
#   {'attribute': 'mindId', 'name': 'Product', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DADP74WFV607KNPCB6VVXGTG',
#   {'attribute': 'mindId', 'name': 'AI', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQYN9GBEBC92AYWNXEDP0C',
#   {'attribute': 'mindId', 'name': 'HR', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQYN9GBEBC92AYWNXEDP0C',
#   {'attribute': 'mindId', 'name': 'HR', 'type': 'domain'}),
#  ('01DAATANXNRQA35E6004HB7MBN',
#   {'attribute': 'mindId', 'name': 'Marketing', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DADP74WFV607KNPCB6VVXGTG',
#   {'attribute': 'mindId', 'name': 'AI', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DADP74WFV607KNPCB6VVXGTG',
#   {'attribute': 'mindId', 'name': 'AI', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'}),
#  ('01DAAQY88QZB19JQZ5PRJFR76Y',
#   {'attribute': 'mindId', 'name': 'Software Engineering', 'type': 'domain'})]

# %%
context_node_list
# Out:
# [('01DB02YDWG35JVE0ZGPN7RT2NA', {'attribute': 'contextId'}),
#  ('01DB02ZNE0JAPZNCA8HC6JQMMV', {'attribute': 'contextId'}),
#  ('01DB0363PCX23BC2Q8WVS3RM6G', {'attribute': 'contextId'}),
#  ('01DB8DEW01CDEG2XPR6KFAFS51', {'attribute': 'contextId'}),
#  ('01DB8DEW0CP9HSS7T0N1JQZJ0W', {'attribute': 'contextId'}),
#  ('01DB8DEW0G1Z3VY22QEFJTSZAE', {'attribute': 'contextId'}),
#  ('01DB8DEW0KVHDQJ33HRKBSKK56', {'attribute': 'contextId'}),
#  ('01DB8DEW0VT6DJ9ZGN6H4TEYJ4', {'attribute': 'contextId'}),
#  ('01DB8DEW0YFYK0ZBP2Q3XR2YT1', {'attribute': 'contextId'}),
#  ('01DB9ZQ51FN04D4CMQCJNXVZKK', {'attribute': 'contextId'}),
#  ('01DBA0EE9EXTR61ZA24EEKRN0Q', {'attribute': 'contextId'}),
#  ('01DBA22RV85W128Y2JF22B4Z1S', {'attribute': 'contextId'}),
#  ('01DBAE7D1ZGV9RENYBGBZ0QBHX', {'attribute': 'contextId'}),
#  ('01DBAEDVZHEFP8070K8FY6HWQ3', {'attribute': 'contextId'}),
#  ('01DBAJ4X1FVG5VZZMAX43XPBSB', {'attribute': 'contextId'}),
#  ('01DBAYZW5WE5DWFN4TT95VZHMM', {'attribute': 'contextId'}),
#  ('01DBC7M83A63QJ7MBMK0E46ZMA', {'attribute': 'contextId'}),
#  ('01DBCEQ3J8S4GSSZ9QTPPHAJF0', {'attribute': 'contextId'}),
#  ('01DBCERN0MJFS8GV90GBWAFCXW', {'attribute': 'contextId'}),
#  ('01DBCEZH0D34Y47W19VNCZZ8M6', {'attribute': 'contextId'}),
#  ('01DBCMZE3R6C3P7C3THHNBDH2A', {'attribute': 'contextId'}),
#  ('01DBCSA1TS5XH4PDXSKREZV1WZ', {'attribute': 'contextId'}),
#  ('01DBCSBAXK1CDNTBR5YGH36NAZ', {'attribute': 'contextId'}),
#  ('01DBCSC6VT62C2QVXRQEWG97RW', {'attribute': 'contextId'}),
#  ('01DBCSDNBBHTKW122XN4J7TWE6', {'attribute': 'contextId'}),
#  ('01DBCSGJACKS03CP9XY69XBNXK', {'attribute': 'contextId'}),
#  ('01DBD208794QC6PWV6W0WVZNV3', {'attribute': 'contextId'}),
#  ('01DBDR0C8VCQS8MA7VDQHSM8G5', {'attribute': 'contextId'}),
#  ('01DBDR2NCF2NANT1R9N5MK4JA7', {'attribute': 'contextId'}),
#  ('01DBFRC7D52J39CGTQV2TH0T29', {'attribute': 'contextId'}),
#  ('01DBFSESYTAC094DV34C5YEXR6', {'attribute': 'contextId'}),
#  ('01DBFSX09M0JY237XCRW74VKPS', {'attribute': 'contextId'}),
#  ('01DBFVDREV0DBWR7F4EBABWMY1', {'attribute': 'contextId'}),
#  ('01DBFVHN480PD6REKKE37NTMTD', {'attribute': 'contextId'}),
#  ('01DBFVV716KC9078AMDSDVRW0S', {'attribute': 'contextId'}),
#  ('01DBHSP8GESEJWSZJ8X8FNFYWW', {'attribute': 'contextId'}),
#  ('01DBJ2GXFHT4YPQH36341NY59F', {'attribute': 'contextId'}),
#  ('01DBJ6KNH9BRKZ46M0PQSH2JXN', {'attribute': 'contextId'}),
#  ('01DBMEAFF2A7FFZXT8D0W5NEPS', {'attribute': 'contextId'}),
#  ('01DBMHYNS9ZVFAPDJW18Z7AHN0', {'attribute': 'contextId'}),
#  ('01DBMJ8TZENATRMFAJ0FBWX1GH', {'attribute': 'contextId'}),
#  ('01DBQBH91MS25RS9N7MA5671GY', {'attribute': 'contextId'}),
#  ('01DBQMD285NK14CMXWMB25NXVB', {'attribute': 'contextId'}),
#  ('01DBVTP36MNS3FC9W09ZB2FT6N', {'attribute': 'contextId'}),
#  ('01DBWHNNDVAX81F4WZT1HV36ZF', {'attribute': 'contextId'}),
#  ('01DC40FHWC3HDDWWEQ44TA7D8B', {'attribute': 'contextId'}),
#  ('01DC4VZ8RXRS4A7ADK15KN0VNV', {'attribute': 'contextId'}),
#  ('01DC4YESMC6129KPHBEGNVF1V9', {'attribute': 'contextId'}),
#  ('01DC78726GS9C1P80SM949X1M1', {'attribute': 'contextId'}),
#  ('01DCH5X2PTNAJDXGMKT1TBGKWS', {'attribute': 'contextId'}),
#  ('01DCRBR2NCA8NEG6EEJV5Y373R', {'attribute': 'contextId'}),
#  ('01DCYQCZMAD45JVADMNZRG5PFD', {'attribute': 'contextId'}),
#  ('01DCYQMNM190AQHX4MG2SAV293', {'attribute': 'contextId'}),
#  ('01DCYQN21WCW57ATAH4A2WG8JS', {'attribute': 'contextId'}),
#  ('01DCYR57H9TSEJJACTXJE2S5YK', {'attribute': 'contextId'}),
#  ('01DD0KRKBADVRR9DY2NKJHZSA3', {'attribute': 'contextId'}),
#  ('01DD0VW2P4685WBBVZ1D6MVBGW', {'attribute': 'contextId'}),
#  ('01DD5AMC1EES2M6A1FZ50EZ8G6', {'attribute': 'contextId'}),
#  ('01DDBGDVNHKTPS34RDKCR06JMF', {'attribute': 'contextId'}),
#  ('01DDG0SQQK4M9JZ8C0JES96SG7', {'attribute': 'contextId'}),
#  ('01DDGT7B4AJVXZV4TETJXK9AT1', {'attribute': 'contextId'}),
#  ('01DDJ3RS1QXAG90FQ3GCA42WZT', {'attribute': 'contextId'}),
#  ('01DDJ426Y6C0HCV8SCPZDB0MS7', {'attribute': 'contextId'}),
#  ('01DDJE9EMNWKTPJFNNYD74XQKQ', {'attribute': 'contextId'}),
#  ('01DDJEEGHJDNGXCFQKXCK65CFH', {'attribute': 'contextId'}),
#  ('01DDMKZ72EYHEXD8R0N0TNX942', {'attribute': 'contextId'}),
#  ('01DDMZT8BC46S4RY55F4NK0A3E', {'attribute': 'contextId'}),
#  ('01DDQ2A5CK4EVQZXKS0KSJMQXN', {'attribute': 'contextId'}),
#  ('01DDT0CNV7675PW75M454KXJKA', {'attribute': 'contextId'}),
#  ('01DDT57S352GJ8WDJ9PJKWJW1P', {'attribute': 'contextId'}),
#  ('01DDT583A187AH7GN05AQZMEZP', {'attribute': 'contextId'}),
#  ('01DDV481WDBFPAB17C687A9PSN', {'attribute': 'contextId'}),
#  ('01DDWCQKY7EA078JBYG1XYCF8M', {'attribute': 'contextId'}),
#  ('01DE97DSM5M99205SQMMWADY93', {'attribute': 'contextId'}),
#  ('01DE97N3RCJN9E6GYP4E5CQJSB', {'attribute': 'contextId'}),
#  ('01DE97RBY7AA4S2NTT7R4ZND5P', {'attribute': 'contextId'}),
#  ('01DE49W4F8J818TW53JYT8QHC7', {'attribute': 'contextId'}),
#  ('01DE6KPEXR7CRBZ80WFAFSGVGE', {'attribute': 'contextId'}),
#  ('01DE6M0KN0G86HQ5ECDG9H10DH', {'attribute': 'contextId'}),
#  ('01DE2VN3D3FVYQC5XCVVX956JJ', {'attribute': 'contextId'}),
#  ('01DE43XEMGG3VZT4T26T8DNE36', {'attribute': 'contextId'}),
#  ('01DE46RWDV3K8FG26TM0GGCH44', {'attribute': 'contextId'}),
#  ('01DE6N9WYC2YB82C2MM6YYRYRG', {'attribute': 'contextId'}),
#  ('01DE4ASPMVGYM7A9AV7CFVZ2GV', {'attribute': 'contextId'}),
#  ('01DE4AV3AM2QV8D0CMN1S61VEP', {'attribute': 'contextId'}),
#  ('01DE4AW5CX7SC6QK1H2VJWQC0F', {'attribute': 'contextId'}),
#  ('01DE4AX4P18E9PGA12X849QYDY', {'attribute': 'contextId'}),
#  ('01DE4AXT0MEZN8FWF9BV21VQHY', {'attribute': 'contextId'}),
#  ('01DE6NEBTCWEDX7AD6W7EYJCC1', {'attribute': 'contextId'}),
#  ('01DE4CJRGNGB5RHV7RDW829J3J', {'attribute': 'contextId'}),
#  ('01DE6NAWYQTF0QFJHTSVT2YEHW', {'attribute': 'contextId'}),
#  ('01DE999NGG431XE2ZTE5YBZJ65', {'attribute': 'contextId'}),
#  ('01DE6NH8E9HDZ5F0WZVHDE48WN', {'attribute': 'contextId'}),
#  ('01DE6NKN22WPBNGRGXNACQY0HQ', {'attribute': 'contextId'}),
#  ('01DE6NN1MQBXP2VQXC3NPGMV4X', {'attribute': 'contextId'}),
#  ('01DE6P5N8YGKADTMP25MRMWKEK', {'attribute': 'contextId'}),
#  ('01DE7VJYQQ2FQC8VMKFFGTDEPB', {'attribute': 'contextId'}),
#  ('01DE7W8XP8B35PAGWMFX3TMQGW', {'attribute': 'contextId'}),
#  ('01DEBXEJFS65ATSDGHQAMB6170', {'attribute': 'contextId'}),
#  ('01DE9756GPK8EX12B6VMN312NB', {'attribute': 'contextId'}),
#  ('01DE9FQ034VS59TJG3AXZS49YM', {'attribute': 'contextId'}),
#  ('01DE9G06DW2895EXZH8QC0DM6Q', {'attribute': 'contextId'}),
#  ('01DE9JS509HQXARGCA2VRDSKG6', {'attribute': 'contextId'}),
#  ('01DE9K9BA8BK7N88BYW8QGMPVF', {'attribute': 'contextId'}),
#  ('01DEBG7Y7MRYZZ0XBQ49VARYVY', {'attribute': 'contextId'}),
#  ('01DEBKCNPXK9P6NC586A7WDC93', {'attribute': 'contextId'}),
#  ('01DEBTEAJ8SXMVTBR6PNDYCH9B', {'attribute': 'contextId'}),
#  ('01DEBTW2KJWF7X2PDDWDPWX0VN', {'attribute': 'contextId'}),
#  ('01DEBVY65NXJS5BB47NV35R1EC', {'attribute': 'contextId'}),
#  ('01DEBWRYYBDPX5GQT0BMAC54RS', {'attribute': 'contextId'}),
#  ('01DED1FA8BWGXZ0WR4GW4ZPD8Q', {'attribute': 'contextId'}),
#  ('01DEEDVPVCKY505AA5RYYDM1V3', {'attribute': 'contextId'}),
#  ('01DEEXCCRETSM9Z4VT3CD60Z16', {'attribute': 'contextId'}),
#  ('01DEFER6DDZHNSMKJPR4959PZB', {'attribute': 'contextId'}),
#  ('01DEFEV4JQDV3FY8QW2EZF776D', {'attribute': 'contextId'}),
#  ('01DB8DEW0QXPFZWEY3XZVQCSMY', {'attribute': 'contextId'}),
#  ('01DEPC0YAH9HECS8CFQ9WE7KF1', {'attribute': 'contextId'}),
#  ('01DERME8YAQ43PPXKA5T52NETH', {'attribute': 'contextId'}),
#  ('01DE474BV13WKAFPP3QH8S4M4R', {'attribute': 'contextId'}),
#  ('01DEY2Q5XGFVRY74AACPE5VGTN', {'attribute': 'contextId'}),
#  ('01DEYDA2ZB42JVBXHRDCZG7WR1', {'attribute': 'contextId'}),
#  ('01DEYDD29RSZGESKGNNAG7ERFT', {'attribute': 'contextId'}),
#  ('01DEYE4A9HVDPCJV1Y5BR05655', {'attribute': 'contextId'}),
#  ('01DEYF8GK03HJEMFW8999B8YNH', {'attribute': 'contextId'}),
#  ('01DF33JHRSXM8TGAQJJ65HH8DS', {'attribute': 'contextId'}),
#  ('01DF83PAA1KP272SFSFEMKTN70', {'attribute': 'contextId'}),
#  ('01DF86PXFA6E04H4542DA98GRS', {'attribute': 'contextId'}),
#  ('01DF86X9RW22BF80GCT3T8N984', {'attribute': 'contextId'}),
#  ('01DF86XPXHS3FVJ8EJ1MH4Y7Y8', {'attribute': 'contextId'}),
#  ('01DF8M11RBDKQ0KQ9N17RYW8AA', {'attribute': 'contextId'}),
#  ('01DFG14WM93GEXJJJY1KPHXK2Y', {'attribute': 'contextId'}),
#  ('01DFG1A6NBM1DHADZM4QQ3R0K5', {'attribute': 'contextId'}),
#  ('01DFJCFR4NDGVZQGNZWHA823VK', {'attribute': 'contextId'}),
#  ('01DFJF8ZGNT1XZPHEYP6ED7RC7', {'attribute': 'contextId'}),
#  ('01DFNVF7GEHJ0NW8AVS2Z0922F', {'attribute': 'contextId'}),
#  ('01DFZAHHNS9JF6BNWD586V4J6N', {'attribute': 'contextId'}),
#  ('01DFZT6MNWS1FJ1TGYBZ7X2C1Q', {'attribute': 'contextId'}),
#  ('01DFZTTN6BHR94AJGBSDGMCDB3', {'attribute': 'contextId'}),
#  ('01DG4TEF5K3Q5H054CXJ2QH2B9', {'attribute': 'contextId'}),
#  ('01DG4ZM1VQT9MPF6GVZDA8NXTY', {'attribute': 'contextId'}),
#  ('01DG5170WE7Z27NSQE8S9JQHEZ', {'attribute': 'contextId'}),
#  ('01DG51KHNSXNTDJZJEJWDR3X2B', {'attribute': 'contextId'}),
#  ('01DG52G4RK01Q8PNGN97F7BJXW', {'attribute': 'contextId'}),
#  ('01DG53D1MR820D0QCE62QED94Z', {'attribute': 'contextId'}),
#  ('01DG59MDRKP8CV0KH3EKZ1VQ2W', {'attribute': 'contextId'}),
#  ('01DG59QRE1FGR7Q7HH0JSAZD16', {'attribute': 'contextId'}),
#  ('01DG5ERQEEQR6R5SP4829DBY21', {'attribute': 'contextId'}),
#  ('01DGC9HKEDNZ1PZ6PG7D6N38D8', {'attribute': 'contextId'}),
#  ('01DGC9HZM0DS78N7FH019YY5QJ', {'attribute': 'contextId'}),
#  ('01DGC9HV3XF7QSQCNK3FC142ZF', {'attribute': 'contextId'}),
#  ('01DGCBH124F7RKZ8AXVPV3V2BH', {'attribute': 'contextId'}),
#  ('01DGCH5MVKTEM3NKSX66M57ZKT', {'attribute': 'contextId'}),
#  ('01DGF3VH586Z5NCXEZF9C5SKNX', {'attribute': 'contextId'}),
#  ('01DGF8YW4ZJCKG20TXXGA8YN33', {'attribute': 'contextId'}),
#  ('01DGF8ZH4TGYS3FNGVR5HH0RA9', {'attribute': 'contextId'}),
#  ('01DGFE0E8N0PQ02KBH8GC583T2', {'attribute': 'contextId'}),
#  ('01DGFH58EGP0MBPKS5NX9GEWMT', {'attribute': 'contextId'}),
#  ('01DGHNECKC4R8VC169YGJ9DJQ9', {'attribute': 'contextId'}),
#  ('01DGHNG79CRQH2C964XM6XYERS', {'attribute': 'contextId'}),
#  ('01DGJJBTDJTVZE1GVRB2F68KAX', {'attribute': 'contextId'}),
#  ('01DH3MD9S7WZR8SG6KJK8ZDZQD', {'attribute': 'contextId'}),
#  ('01DH464J92CVYWCP9AVYWYJXGF', {'attribute': 'contextId'}),
#  ('01DH6M0RY8XF7YARXYZC3AA240', {'attribute': 'contextId'}),
#  ('01DH8TKK1ED44YVMMPSVDDH3WW', {'attribute': 'contextId'}),
#  ('01DHGAK4EHGY7GR4WCF29ZYAJ4', {'attribute': 'contextId'}),
#  ('01DHGPD2MDCCHG6EDQAX48J93D', {'attribute': 'contextId'}),
#  ('01DHJYT3ZJ8TSS3EGRG88FGCEK', {'attribute': 'contextId'}),
#  ('01DHP4MQKRC9H8WR96JZ13SGX7', {'attribute': 'contextId'}),
#  ('01DHR0C3QX80XPNYE2EK8QA8N7', {'attribute': 'contextId'}),
#  ('01DHRS2NYNTZZPTXGMZ5NP3PFC', {'attribute': 'contextId'}),
#  ('01DHTX7N17DZ337MNHJNH36WKD', {'attribute': 'contextId'}),
#  ('01DHVDKMVJ4Q2F6QV5Y0X7TRGV', {'attribute': 'contextId'}),
#  ('01DJ268E1THX846505PZ6F8MJ9', {'attribute': 'contextId'}),
#  ('01DJ26ATDJ6660T4W8MN6PHZAP', {'attribute': 'contextId'}),
#  ('01DJ26G72ZTX4RNMSM0D15W8RR', {'attribute': 'contextId'}),
#  ('01DJ2VD5PW5PY5T31ET4BKDN5M', {'attribute': 'contextId'}),
#  ('01DJ38PKT7F708AEHNMHZHANXM', {'attribute': 'contextId'}),
#  ('01DJ3B2W3FT9QNEG2Y460Q86EC', {'attribute': 'contextId'}),
#  ('01DJ4T6X8HYHYTF04C4C2NN4FS', {'attribute': 'contextId'}),
#  ('01DJ6DFRFG8P50ZP2R73GEHXTN', {'attribute': 'contextId'}),
#  ('01DJ7BEP074VRYR9QYNBX8439X', {'attribute': 'contextId'}),
#  ('01DJMK74VFS7ATDTZANK4N30PS', {'attribute': 'contextId'}),
#  ('01DJMK83DHFSMGY7DFG6NF9FT3', {'attribute': 'contextId'}),
#  ('01DK30ZWDGZAC0DW1NXPSTPAT6', {'attribute': 'contextId'}),
#  ('01DH8TGPTMHC1K1B6SFSG3GPF4', {'attribute': 'contextId'}),
#  ('01DK93472HB185122H0EMG75P9', {'attribute': 'contextId'}),
#  ('01DKBPS4M7SRZEDR5WH0MT0C5B', {'attribute': 'contextId'}),
#  ('01DKV9FCE9PQ4SH322FWJY2087', {'attribute': 'contextId'}),
#  ('01DKXSZ7NDW7X70721W2JZ5P83', {'attribute': 'contextId'}),
#  ('01DKVE90YRKTZFQA3G4FRXQV9Z', {'attribute': 'contextId'}),
#  ('01DKZYT4F4ZK8HJG470FSXS812', {'attribute': 'contextId'}),
#  ('01DM025YZBHZ2627055M5050J9', {'attribute': 'contextId'}),
#  ('01DM035H2AEY5DVSK6DF967KDK', {'attribute': 'contextId'}),
#  ('01DM03NCQ5F4J6KK66T9KDSCAZ', {'attribute': 'contextId'}),
#  ('01DM03WNAYK95RCTG0TJT6CY6T', {'attribute': 'contextId'}),
#  ('01DM03XPP8Q70MWJZPHBQHD47Z', {'attribute': 'contextId'}),
#  ('01DM04MJRZBXT5DJP3GDA0HFX8', {'attribute': 'contextId'}),
#  ('01DM04N1N8GPDAWVKTMR47Z9ZA', {'attribute': 'contextId'}),
#  ('01DM04NJP2Y71BJSCTNCZDZDZC', {'attribute': 'contextId'}),
#  ('01DM0JEK8F71W1PMCA506G4WQW', {'attribute': 'contextId'}),
#  ('01DM0JF410KKPSQCRC47KKW35S', {'attribute': 'contextId'}),
#  ('01DM0JGA1XJSK3M5HB8ZMS18SZ', {'attribute': 'contextId'}),
#  ('01DM0JTW5PBG3HTDY49EVC0VHH', {'attribute': 'contextId'}),
#  ('01DM0VW6YBJQE27HV6VB2V6S8K', {'attribute': 'contextId'}),
#  ('01DM0W421K7DSBTPTVY0N9DWZR', {'attribute': 'contextId'}),
#  ('01DM2Q60M6B503QKW6S6X1WGM8', {'attribute': 'contextId'}),
#  ('01DM8N3R06449184V0GCZ4QJYS', {'attribute': 'contextId'}),
#  ('01DM8N9T7QHVWN4G367DW2CBBP', {'attribute': 'contextId'}),
#  ('01DMAMWV9V16YYFC38A6TZDJQ7', {'attribute': 'contextId'}),
#  ('01DMCGTKEVBE4B956NSHWJTQBM', {'attribute': 'contextId'}),
#  ('01DMDP9YAYWEAMCAQ20XZG6HS8', {'attribute': 'contextId'}),
#  ('01DMKEYBKNVZ317Z6W1AW0BN4M', {'attribute': 'contextId'})]

# %%
meta_graph.add_nodes_from(mind_node_list)
meta_graph.add_nodes_from(context_node_list)
meta_graph.add_edges_from((context_mind_node_list))

# %%
print(meta_graph.number_of_nodes(), meta_graph.number_of_edges())
# Out:
# 32531 59967

# %%
user_workspace_dict = {}
workspace_customer_dict = {}
for i in range(len(user_context_info_df)):
    user_id = user_context_info_df['user_id'][i]
    workspace_id = user_context_info_df['workspace_id'][i]
    user_workspace_dict[user_id] = workspace_id

# %%
for i in range(len(workspace_customer_info_df)):
    workspace_id = workspace_customer_info_df['workspace_id'][i]
    customer_id = workspace_customer_info_df['customer_id'][i]
    workspace_customer_dict[workspace_id] = customer_id

# %%
user_customer_dict = {}
for user, workspace in user_workspace_dict.items():
    if workspace in workspace_customer_dict.keys():
        user_customer_dict[user] = workspace_customer_dict[workspace]

# %%
customer_user_rel = {"relation": "hasUser"}
for user, customer in user_customer_dict.items():
    meta_graph.add_edge(customer, user, relation="hasUser")

# %%
for u, c in user_customer_dict.items():
    if '01D9S30B7X910Q033A105BE77J' == c:
        print(u)
# Out:
# 35bcfa72-bf81-442c-8a1a-8bbda7733cde
# 8d6db5f7-d9b7-4c54-ba38-fe710ffcaf3f
# 622258ac-a854-43f5-a772-324bf6c2ebeb
# 8fff81b5-b2f1-4aa5-ad67-405f3e8127f3
# b782dae5-06de-4b7a-bc7d-789a1ad005e5
# b6806dc1-0a18-4d82-9c25-68f0c497825d
# 933183fb-4652-4292-9647-84b26b6f1403
# d6b3ef10-7f14-4877-b3eb-6b34e228fb44
# 510d6e98-21c3-4953-9d49-ea27a7593c24
# 838d0ce8-d294-493d-8439-5ce008ffd162
# ce40846a-c104-4414-992f-a1dd1d03390e
# 677eebaa-85bf-4e6c-8bdc-9992572e6b0d
# c2c32799-0ba8-4240-b122-3a80dd071a7e
# 5c06fd33-432d-44e0-8cdf-71ba1a8eef3d
# bcc49827-e601-4828-b39c-6c50f860acaf
# cb273f0a-0bb5-4f51-ae77-d1c6dd8ab104
# 4b7109ed-cad9-4ada-abd3-90b7b7e6c0b9
# 86c02666-38c2-4ae2-a68e-5fd3ef8298ee
# 02e3666b-0c47-4b48-b5e0-fc8c892bcb0b
# 612459cf-b7c9-4fdf-9f94-8e18bb86514d
# 75bdf310-110b-4b8f-ab88-b16fafce920e
# 67e68184-8a79-4a84-8113-fb8169c965a8
# b494fa7f-dace-4bb9-beab-32e1724442b3
# e036d3a4-7068-4e9a-a9ff-2b37ed858a5e
# 1d5aec30-d4c3-499f-8424-edccb0927284
# f7b75512-f161-4c7b-936f-1e0fbae76c2e
# 7459c31a-2c44-42df-97ea-0d819375e8f5
# 5e354a1e-5ac6-487b-b0e2-a8cc3fb88167
# fc57db55-7614-4a05-97db-c3ee4e7be693
# 188b7b69-56d8-4b6c-b54a-5870cfe8fab5
# 136ce73f-d56b-4c60-b5ef-128a114a3da2
# 8ca4116c-2aa0-4a0d-baa9-df30b11b60b6
# a312793f-69ac-4cff-8d53-f3536d04163d
# 9ce71ab0-403f-47c0-8411-9abc5b4ab4a3
# 5e025858-d34b-4e5c-9a2e-3e7c3f33e7c2
# b2e330a6-7fa2-457a-b95d-ca8870befc3e
# 915b3ed6-b6db-4eb0-940a-b7ff75cda015
# fb5b8417-4250-459f-a852-d8d8717532e2
# 2cc5d0e7-9aeb-4df4-9d52-ff1ed607b4ee
# 6a6de08c-2cdf-42bc-96e7-dbe6a3b10e52
# 263ad8c0-a52b-407b-94ac-9712ac0b14cb
# 0d4b9c82-0c25-47e8-9e0a-56d54c07d0ed
# 645b3b61-15e2-4e18-b24c-e429117ed7ac
# 4b43984d-1d07-48b3-8c4a-bb38e7ac75c0
# 3aa83f48-a2e6-49d5-9c9b-cdabf5e86677
# 56decbbb-30d9-44ff-883f-b062cf52700b
# 2a8232f7-1ede-4d32-9257-66fcce42a007
# 6e26d6b8-b897-4d5a-b644-fd053fc8088e
# 1dce81ef-3e78-4255-9507-8da03210a535
# 9127a388-28bc-4171-9c3c-531bb2510aac

# %%
meta_graph['01D9S30B7X910Q033A105BE77J']
# Out:
# AtlasView({'35bcfa72-bf81-442c-8a1a-8bbda7733cde': {'relation': 'hasUser'}, '8d6db5f7-d9b7-4c54-ba38-fe710ffcaf3f': {'relation': 'hasUser'}, '622258ac-a854-43f5-a772-324bf6c2ebeb': {'relation': 'hasUser'}, '8fff81b5-b2f1-4aa5-ad67-405f3e8127f3': {'relation': 'hasUser'}, 'b782dae5-06de-4b7a-bc7d-789a1ad005e5': {'relation': 'hasUser'}, 'b6806dc1-0a18-4d82-9c25-68f0c497825d': {'relation': 'hasUser'}, '933183fb-4652-4292-9647-84b26b6f1403': {'relation': 'hasUser'}, 'd6b3ef10-7f14-4877-b3eb-6b34e228fb44': {'relation': 'hasUser'}, '510d6e98-21c3-4953-9d49-ea27a7593c24': {'relation': 'hasUser'}, '838d0ce8-d294-493d-8439-5ce008ffd162': {'relation': 'hasUser'}, 'ce40846a-c104-4414-992f-a1dd1d03390e': {'relation': 'hasUser'}, '677eebaa-85bf-4e6c-8bdc-9992572e6b0d': {'relation': 'hasUser'}, 'c2c32799-0ba8-4240-b122-3a80dd071a7e': {'relation': 'hasUser'}, '5c06fd33-432d-44e0-8cdf-71ba1a8eef3d': {'relation': 'hasUser'}, 'bcc49827-e601-4828-b39c-6c50f860acaf': {'relation': 'hasUser'}, 'cb273f0a-0bb5-4f51-ae77-d1c6dd8ab104': {'relation': 'hasUser'}, '4b7109ed-cad9-4ada-abd3-90b7b7e6c0b9': {'relation': 'hasUser'}, '86c02666-38c2-4ae2-a68e-5fd3ef8298ee': {'relation': 'hasUser'}, '02e3666b-0c47-4b48-b5e0-fc8c892bcb0b': {'relation': 'hasUser'}, '612459cf-b7c9-4fdf-9f94-8e18bb86514d': {'relation': 'hasUser'}, '75bdf310-110b-4b8f-ab88-b16fafce920e': {'relation': 'hasUser'}, '67e68184-8a79-4a84-8113-fb8169c965a8': {'relation': 'hasUser'}, 'b494fa7f-dace-4bb9-beab-32e1724442b3': {'relation': 'hasUser'}, 'e036d3a4-7068-4e9a-a9ff-2b37ed858a5e': {'relation': 'hasUser'}, '1d5aec30-d4c3-499f-8424-edccb0927284': {'relation': 'hasUser'}, 'f7b75512-f161-4c7b-936f-1e0fbae76c2e': {'relation': 'hasUser'}, '7459c31a-2c44-42df-97ea-0d819375e8f5': {'relation': 'hasUser'}, '5e354a1e-5ac6-487b-b0e2-a8cc3fb88167': {'relation': 'hasUser'}, 'fc57db55-7614-4a05-97db-c3ee4e7be693': {'relation': 'hasUser'}, '188b7b69-56d8-4b6c-b54a-5870cfe8fab5': {'relation': 'hasUser'}, '136ce73f-d56b-4c60-b5ef-128a114a3da2': {'relation': 'hasUser'}, '8ca4116c-2aa0-4a0d-baa9-df30b11b60b6': {'relation': 'hasUser'}, 'a312793f-69ac-4cff-8d53-f3536d04163d': {'relation': 'hasUser'}, '9ce71ab0-403f-47c0-8411-9abc5b4ab4a3': {'relation': 'hasUser'}, '5e025858-d34b-4e5c-9a2e-3e7c3f33e7c2': {'relation': 'hasUser'}, 'b2e330a6-7fa2-457a-b95d-ca8870befc3e': {'relation': 'hasUser'}, '915b3ed6-b6db-4eb0-940a-b7ff75cda015': {'relation': 'hasUser'}, '406bb5d4-d2ba-4155-91b9-cb765a8e2c5e': {'relation': 'hasUser'}, 'f1c4d3b4-e69e-4032-b353-d31e805b6524': {'relation': 'hasUser'}, '0a8cae5b-55ad-419a-afb8-a7580bea0451': {'relation': 'hasUser'}, '4ce45ec9-bcce-411b-8ba7-c3b49a08df88': {'relation': 'hasUser'}, '75a5b4a8-825d-496c-9f7b-f15334c676cc': {'relation': 'hasUser'}, '93c271c4-9594-4ed4-ba3e-cde3ecf4c4a4': {'relation': 'hasUser'}, '9eae6964-ffc6-4a31-8796-8feb2f45dd0a': {'relation': 'hasUser'}, '34ce4018-7bce-4eb0-9e86-0c432006b0e6': {'relation': 'hasUser'}, '403fe472-f955-4836-b348-54a089a63879': {'relation': 'hasUser'}, '9ebc0e0b-d6b9-4d48-b890-b8c784575e2c': {'relation': 'hasUser'}, '6e53e922-4435-4174-94b7-a131b2c59d84': {'relation': 'hasUser'}, 'a1b1d218-09e9-4dfe-aad9-597b6806faa9': {'relation': 'hasUser'}, '5133e0a6-f1af-484c-8d83-7378a3885175': {'relation': 'hasUser'}, '5cf8a75c-c4e8-49a5-aef4-b2c8631bc3dc': {'relation': 'hasUser'}, 'c9b982da-82b4-4091-8b71-74ebdce9b2f0': {'relation': 'hasUser'}, '07288b5c-4c8d-4401-b42e-2b82f1dc3735': {'relation': 'hasUser'}, 'b37c8356-0984-4e6e-badb-37ca885ddc6d': {'relation': 'hasUser'}, 'ab51e3d0-0118-4a5a-86a0-786b930eb2db': {'relation': 'hasUser'}, '5c9fa5bf-186f-40cd-968a-c64967f010e6': {'relation': 'hasUser'}, 'b28a311e-4a5f-45e0-b15b-5088845ea156': {'relation': 'hasUser'}, 'f0c80aad-50d9-430a-b84d-79626b6034ec': {'relation': 'hasUser'}, 'd92aa8cb-d472-43ba-874c-54aed4a82113': {'relation': 'hasUser'}, '9c4b8fc8-db71-4509-ba29-55c01999b14b': {'relation': 'hasUser'}, '6aadd40b-b073-4de1-a46c-e2ca91423754': {'relation': 'hasUser'}, 'be0b5de2-1610-415e-899d ...

# %%
print(meta_graph.number_of_nodes(), meta_graph.number_of_edges())
# Out:
# 32531 60632

# %% [markdown]
# ## Save Graph to pickle

# %%
nx.write_gpickle(meta_graph, "meta_graph_prod.pickle")

# %%
for n, attr in meta_graph.nodes.data():
    if attr['attribute'] == "userId":
        print(meta_graph[n])
# Out:
# {'8ed6ea6d-11dc-4cd0-99c3-2ab36a02e959': {'relation': 'belongsTo'}, '01DBB3SN6VJAP5WED6NZX7A7TE': {'relation': 'belongsTo'}, '01DBB3SP2KWP78QRSB3SDBZ0MJ': {'relation': 'belongsTo'}, '01DBB3SNJ8PZ091C71ES8NQP1F': {'relation': 'belongsTo'}, '01DBB3SQCEA1Z0KA6NHRH3Z5QW': {'relation': 'belongsTo'}, '01DBB3SN2ZA8GY2X7QGS1PF4K4': {'relation': 'belongsTo'}, '01DBB3SN6AJC8VE0C0GV7SF9GB': {'relation': 'belongsTo'}, '01DBB3SN23WZMNK9TZXRKPGW61': {'relation': 'belongsTo'}, '01DBB3SN7BDZ43A5X7DHWJV2EC': {'relation': 'belongsTo'}, '01DFTM2QMK9TC897FNXGJEJS0C': {'relation': 'belongsTo'}, '01DGKV3K34QRSD3V1GKDT05P3H': {'relation': 'belongsTo'}, '01DGP5R740PHT717XSXDEN8Z9X': {'relation': 'belongsTo'}, '01DME6G0HXQKK9WNGZZZ3JF5JB': {'relation': 'belongsTo'}, 'a1c582a6-f73f-4a88-9ac5-043947316384': {'relation': 'memberOf'}, 'ac6699b6-51ef-46c2-b5d7-43e262a0702e': {'relation': 'memberOf'}, 'c7fa43e9-395e-49e0-8bc2-28e29736f5b6': {'relation': 'memberOf'}, '4e6976d7-135c-440b-a6a9-e1fcf4429a3a': {'relation': 'memberOf'}, 'aa223761-4855-48c4-89b2-272469dc5cea': {'relation': 'memberOf'}, 'c5ddd269-aa26-4500-baba-d0d27295dafd': {'relation': 'memberOf'}, '33081080-fb90-43bf-a01d-e414d1bc9e0b': {'relation': 'memberOf'}, 'eb4c7afa-ae3e-4005-aac7-92a4e84259e4': {'relation': 'memberOf'}, '49814e8e-dd77-4c4e-a95c-a6237e6a005d': {'relation': 'memberOf'}, '70c5f0c0-e22e-45a1-a5eb-1ee080f73343': {'relation': 'memberOf'}, '3a5b9df1-5905-4cbb-a981-34f9bfd51f5c': {'relation': 'memberOf'}, '70b548e4-e1be-4f71-8392-108df056bb73': {'relation': 'memberOf'}}
# {'f62d19b0-e9a8-41f7-97d9-3233b2d2390a': {'relation': 'belongsTo'}, '01DBB3SNV7ZWSB8FNW2448RF49': {'relation': 'belongsTo'}, '01DBB3SN8CSNZ3Y25PAFQM5059': {'relation': 'belongsTo'}, '01DBB3SNN9BS4JZ1G4TER7YXNZ': {'relation': 'belongsTo'}, '01DBB3SPGT34NG93ZHVS08J2Q9': {'relation': 'belongsTo'}, '01DBB3SNVBQXVQ7MKE9JH796BV': {'relation': 'belongsTo'}, '01DBB3SPH6XKEPFSHS9K8EVXPV': {'relation': 'belongsTo'}, '01DBB3SNEZGZBPQB17GG6SW9PX': {'relation': 'belongsTo'}, '01DBB3SNSKT8DQXNCS8M6PBJJJ': {'relation': 'belongsTo'}, '01DBB3SNYC0Q8P238G69HMSWMM': {'relation': 'belongsTo'}, '01DBB3SP5N6PH88VWBH
{'relation': 'belongsTo'}, '06044743-299b-4a56-b736-3dc893d6b4a4': {'relation': 'memberOf'}, '38750fd6-07b3-48b2-b1b0-798ef5736e8b': {'relation': 'memberOf'}, '69ea751d-68fb-41e2-b692-ee05d9f577e7': {'relation': 'memberOf'}, '799cb5f0-39b0-4c7a-9b1d-4dfdd1f63fd8': {'relation': 'memberOf'}, 'bf505f4e-ca08-4239-b94a-8aa2dc70460f': {'relation': 'memberOf'}, 'dc4c5ad6-93a6-48cb-951e-2fe86396ba34': {'relation': 'memberOf'}, 'e73d9544-b14b-4f9f-b1a9-cf17c69913e9': {'relation': 'memberOf'}, '7c9c4653-bf1a-428e-b406-d959cff4807b': {'relation': 'memberOf'}, '9dd5d830-fc4b-434c-8988-991274c8e43c': {'relation': 'memberOf'}, '7f686599-fa08-466e-87a3-4212b92a0e37': {'relation': 'memberOf'}, 'cfccb0f1-ee77-4445-b4c3-c76d1b08046a': {'relation': 'memberOf'}, '6f0de149-b035-4c2c-b259-9ef13ff1b04e': {'relation': 'memberOf'}}
# {'b3614ac5-18ad-4fcc-8406-263f5f1d2c6a': {'relation': 'belongsTo'}, '01DBB3SNTSS2F985VDYW9NZ7XJ': {'relation': 'belongsTo'}, '01DBB3SPKB8J0KSP2XVZ8RS8BQ': {'relation': 'belongsTo'}, '06044743-299b-4a56-b736-3dc893d6b4a4': {'relation': 'memberOf'}, '7acb2b64-3c55-40b2-8dd4-239d6480c032': {'relation': 'memberOf'}}
# {'6e379895-431f-4439-8522-1e561447ba5c': {'relation': 'belongsTo'}, '01DBB3SPQH1S3P6G820WV14Z52': {'relation': 'belongsTo'}, '01DBB3SPXGBT910T51X3P4R3N7': {'relation': 'belongsTo'}, '01DBB3SNCMFNDMKMBFR0CF4N0F': {'relation': 'belongsTo'}, '01158f32-cbe8-4eae-8bdc-a553b3a12f31': {'relation': 'memberOf'}, '745e0987-d2a6-44e4-b216-4e214a710a9b': {'relation': 'memberOf'}, 'f60effdb-1174-4658-9593-4a27073b0ddb': {'relation': 'memberOf'}}
# {'9b85b25d-912c-48c2-94d9-34107d13a5a0': {'relation': 'belongsTo'}, '01DBB3SPM31H6T73A8E50TANEV': {'relation': 'belongsTo'}, '028061f0-3bc7-4af2-9daa-b94c6c9a501c': {'relation': 'memberOf'}}
# {'9b85b25d-912c-48c2-94d9-34107d13a5a0': {'relation': 'belongsTo'}, '01DBB3SPM31H6T73A8E50TANEV': {'relation': 'belongsTo'}, '028061f0-3bc7-4af2-9daa-b94c6c9a501c': {'relation': 'memberOf'}}
# {'9b85b25d-912c-48c2-94d9-34107d13a5a0': {'relation': 'belongsTo'}, '01DBB3SPM31H6T73A8E50TANEV': {'relation': 'belongsTo'}, '028061f0-3bc7-4af2-9daa-b94c6c9a501c': {'relation': 'memberOf'}}
# {'9b85b25d-912c-48c2-94d9-34107d13a5a0': {'relation': 'belongsTo'}, '01DBB3SPM31H6T73A8E50TANEV': {'relation': 'belongsTo'}, '028061f0-3bc7-4af2-9daa-b94c6c9a501c': {'relation': 'memberOf'}}
# {'9b85b25d-912c-48c2-94d9-34107d13a5a0': {'relation': 'belongsTo'}, '01DBB3SPM31H6T73A8E50TANEV': {'relation': 'belongsTo'}, '028061f0-3bc7-4af2-9daa-b94c6c9a501c': {'relation': 'memberOf'}}
# {'9b85b25d-912c-48c2-94d9-34107d13a5a0': {'relation': 'belongsTo'}, '01DBB3SPM31H6T73A8E50TANEV': {'relation': 'belongsTo'}, '028061f0-3bc7-4af2-9daa-b94c6c9a501c': {'relation': 'memberOf'}}
# {'b3614ac5-18ad-4fcc-8406-263f5f1d2c6a': {'relation': 'belongsTo'}, '01DBB3SNTSS2F985VDYW9NZ7XJ': {'relation': 'belongsTo'}, '01DBB3SQ9PP9T7GGRCJYSCBR7F': {'relation': 'belongsTo'}, '01DBB3SPWJ0WR3CWCBZK1X1FQY': {'relation': 'belongsTo'}, '01DBBJQ517QHQNYZJKRXGP6QXW': {'relation': 'belongsTo'}, '06044743-299b-4a56-b736-3dc893d6b4a4': {'relation': 'memberOf'}, 'fe45c21e-3a68-4f97-a64c-75c235f3dc28': {'relation': 'memberOf'
e115c1': {'relation': 'memberOf'}, '5544938c-f6d6-423c-8b4c-dc5c90afc097': {'relation': 'memberOf'}, '595cea67-cf68-486d-ab1e-9511f48cf1aa': {'relation': 'memberOf'}, '88ee7dd1-f5e8-4df3-b9e9-2cfcf3a6e109': {'relation': 'memberOf'}, '898068b8-3c18-44c0-9aa0-f6135edd8f44': {'relation': 'memberOf'}, 'ad425895-308e-4d0f-b2f4-b1cd3c81b927': {'relation': 'memberOf'}, 'b4b6c021-e607-4069-b8c0-6f7f20811503': {'relation': 'memberOf'}, 'bb46b569-4b39-4a85-8190-6c7d0051bb95': {'relation': 'memberOf'}, 'e8151ac9-48c8-4b37-90c7-3b7ec1c66f21': {'relation': 'memberOf'}, 'fa039cac-7ff8-4316-b9b8-f080eed1a05b': {'relation': 'memberOf'}, '3a67226f-70ae-473e-8c2e-c922da1407e9': {'relation': 'memberOf'}, '04578751-8263-46c3-bc72-d726521f1fe6': {'relation': 'memberOf'}, '12500093-77a7-4b7a-a240-4737da4f99d8': {'relation': 'memberOf'}, '95caa247-7b89-458d-aca4-05a32589dda3': {'relation': 'memberOf'}, '08422160-7e50-4e95-9715-e6f2f47dc4dc': {'relation': 'memberOf'}, '56bdc1ea-ab41-4bef-8b1b-57d76308ef8d': {'relation': 'memberOf'}, 'db53b8bb-dda8-427b-bcbf-82959e924efb': {'relation': 'memberOf'}, '5ea16f6e-8f97-4320-acf4-99fe202d1ed6': {'relation': 'memberOf'}, '5ef6b59e-3a85-48b9-8be7-bd34dbc2c252': {'relation': 'memberOf'}, '58b9122b-aa57-424c-8a2c-dfab0d5fb7db': {'relation': 'memberOf'}, 'd80c5439-f7d0-4f7b-a7b7-80ea4c35b57d': {'relation': 'memberOf'}, 'dc99ed1a-a999-48e0-9cc2-27de198ad744': {'relation': 'memberOf'}, '3b896198-b4df-44e9-aab1-1b880b1efa9f': {'relation': 'memberOf'}, '1c82a83f-ca1e-4c75-9d06-99f7c6d65bbd': {'relation': 'memberOf'}, 'a551e212-730a-4b20-84eb-c178732e92b0': {'relation': 'memberOf'}, '1121f977-ce4c-4c1d-9605-6e752dab233b': {'relation': 'memberOf'}, '77d66122-6ecf-4721-8e97-dd056a301fe5': {'relation': 'memberOf'}, '7c70c52a-a6d5-4735-929e-8ca00131dce7': {'relation': 'memberOf'}, 'cb598d95-18e3-47be-8613-6e3ec7c2be15': {'relation': 'memberOf'}, '511e2705-dc53-45d4-a6df-778cb4317b07': {'relation': 'memberOf'}}
# {'f62d19b0-e9a8-41f7-97d9-3233b2d2390a': {'relation': 'belongsTo'}, '01DBB3SP3DZZJK93TQ9GXYPP5N': {'relation': 'belongsTo'}, '01DBB3SN91FT26NCAFM96C3BXX': {'relation': 'belongsTo'}, '01DBB3SNYC0Q8P238G69HMSWMM': {'relation': 'belongsTo'}, '01DBB3SNM3VC7KJ960V2F29FH9': {'relation': 'belongsTo'}, '01DBB3SP385R67YAWJWXV6YHQW': {'relation': 'belongsTo'}, '01DBB3SNR8RTJ143WCPXEJFE1F': {'relation': 'belong
{'relation': 'memberOf'}}
# {'b3614ac5-18ad-4fcc-8406-263f5f1d2c6a': {'relation': 'belongsTo'}, '01DBB3SNTSS2F985VDYW9NZ7XJ': {'relation': 'belongsTo'}, '01DBB3SPW69JKE6DAC1B1TKM0K': {'relation': 'belongsTo'}, '06044743-299b-4a56-b736-3dc893d6b4a4': {'relation': 'memberOf'}, '38750fd6-07b3-48b2-b1b0-798ef5736e8b': {'relation': 'memberOf'}}
# {'b3614ac5-18ad-4fcc-8406-263f5f1d2c6a': {'relation': 'belongsTo'}, '01DBB3SNTSS2F985VDYW9NZ7XJ': {'relation': 'belongsTo'}, '01DBB3SN5VT5AWB40CXDQAVJRG': {'relation': 'belongsTo'}, '06044743-299b-4a56-b736-3dc893d6b4a4': {'relation': 'memberOf'}, '54de3022-1277-43cd-b592-0bd083836ebf': {'relation': 'memberOf'}}
# {'b3614ac5-18ad-4fcc-8406-263f5f1d2c6a': {'relation': 'belongsTo'}, '01DBB3SNTSS2F985VDYW9NZ7XJ': {'relation': 'belongsTo'}, '01DBB3SQ3DAA7KSTYBMAPHKKMR': {'relation': 'belongsTo'}, '06044743-299b-4a56-b736-3dc893d6b4a4': {'relation': 'memberOf'}, '9d2471d9-1632-4d4a-b7a9-a2cfee79f9cf': {'relation': 'memberOf'}}
# {'b3614ac5-18ad-4fcc-8406-263f5f1d2c6a': {'relation': 'belongsTo'}, '01DBB3SNTSS2F985VDYW9NZ7XJ': {'relation': 'belongsTo'}, '01DBB3SNXR590XK96T6Y0QFZMY': {'relation': 'belongsTo'}, '06044743-299b-4a56-b736-3dc893d6b4a4': {'relation': 'memberOf'}, '799cb5f0-39b0-4c7a-9b1d-4dfdd1f63fd8': {'relation': 'memberOf'}}
# ...
# {'e4694371-2986-4dcc-9183-68520af0b91a': {'relation': 'belongsTo'}, '01DK8X72AMEGNAR7RVWS617STN': {'relation': 'belongsTo'}, '01DMN2XMTZYRTWZVK7EHK97NAS': {'relation': 'belongsTo'}, 'ad9db55d-3d88-4770-975d-8bcfb4d9e8ae': {'relation': 'memberOf'}, 'e994dbff-70c6-425e-b091-5f8b32c6689e': {'relation': 'memberOf'}}
# {'e4694371-2986-4dcc-9183-68520af0b91a': {'relation': 'belongsTo'}, '01DK8X72AMEGNAR7RVWS617STN': {'relation': 'belongsTo'}, '01DMN2XMTZYRTWZVK7EHK97NAS': {'relation': 'belongsTo'}, 'ad9db55d-3d88-4770-975d-8bcfb4d9e8ae': {'relation': 'memberOf'}, 'e994dbff-70c6-425e-b091-5f8b32c6689e': {'relation': 'memberOf'}}
# {'e4694371-2986-4dcc-9183-68520af0b91a': {'relation': 'belongsTo'}, '01DK8X72AMEGNAR7RVWS617STN': {'relation': 'belongsTo'}, '01DKV9BPQCWB7122XZZZMYK89R': {'relation': 'belongsTo'}, '01DMN2XMTZYRTWZVK7EHK97NAS': {'relation': 'belongsTo'}, '01DMJHTEDYQJY5TMD0GNMA5522': {'relation': 'belongsTo'}, 'ad9db55d-3d88-4770-975d-8bcfb4d9e8ae': {'relation': 'memberOf'}, 'e32afef1-57da-4e6f-b30a-38c1d458818d': {'relation': 'memberOf'}, 'e994dbff-70c6-425e-b091-5f8b32c6689e': {'relation': 'memberOf'}, '5b932504-7cd7-41a0-97b8-3d82b1c0d69f': {'relation': 'memberOf'}}
# {'e4694371-2986-4dcc-9183-68520af0b91a': {'relation': 'belongsTo'}, '01DK8X72AMEGNAR7RVWS617STN': {'relation': 'belongsTo'}, '01DKV9BPQCWB7122XZZZMYK89R': {'relation': 'belongsTo'}, '01DMN2XMTZYRTWZVK7EHK97NAS': {'relation': 'belongsTo'}, '01DMJHTEDYQJY5TMD0GNMA5522': {'relation': 'belongsTo'}, 'ad9db55d-3d88-4770-975d-8bcfb4d9e8ae': {'relation': 'memberOf'}, 'e32afef1-57da-4e6f-b30a-38c1d458818d': {'relation': 'memberOf'}, 'e994dbff-70c6-425e-b091-5f8b32c6689e': {'relation': 'memberOf'}, '5b932504-7cd7-41a0-97b8-3d82b1c0d69f': {'relation': 'memberOf'}}
# {'e4694371-2986-4dcc-9183-68520af0b91a': {'relation': 'belongsTo'}, '01DK8X72AMEGNAR7RVWS617STN': {'relation': 'belongsTo'}, '01DKV9BPQCWB7122XZZZMYK89R': {'relation': 'belongsTo'}, '01DMN2XMTZYRTWZVK7EHK97NAS': {'relation': 'belongsTo'}, 'ad9db55d-3d88-4770-975d-8bcfb4d9e8ae': {'relation': 'memberOf'}, 'e32afef1-57da-4e6f-b30a-38c1d458818d': {'relation': 'memberOf'}, 'e994dbff-70c6-425e-b091-5f8b32c6689e': {'relation': 'memberOf'}}
# {'e4694371-2986-4dcc-9183-68520af0b91a': {'relation': 'belongsTo'}, '01DK8X72AMEGNAR7RVWS617STN': {'relation': 'belongsTo'}, '01DMN2XMTZYRTWZVK7EHK97NAS': {'relation': 'belongsTo'}, 'ad9db55d-3d88-4770-975d-8bcfb4d9e8ae': {'relation': 'memberOf'}, 'e994dbff-70c6-425e-b091-5f8b32c6689e': {'relation': 'memberOf'}}
# {'3d2a1020-7f8f-4660-847d-cf5f43539eab': {'relation': 'belongsTo'}, '01DKHTJ7P058X1FPCFV2XSRD7N': {'relation': 'belongsTo'}, '24594fb9-2468-41a5-b3bd-2605b53c412d': {'relation': 'memberOf'}}
# {'3d2a1020-7f8f-4660-847d-cf5f43539eab': {'relation': 'belongsTo'}, '01DKHTJ7P058X1FPCFV2XSRD7N': {'relation': 'belongsTo'}, '01DKHW3J5WNQQ1JR1T76DVKCAB': {'relation': 'belongsTo'}, '24594fb9-2468-41a5-b3bd-2605b53c412d': {'relation': 'memberOf'}, '112a18b7-aae3-4ae5-b6e7-c75d59858dce': {'relation': 'memberOf'}}
# {'4d43b748-c30b-42f8-bd4a-ef5d682ed6c8': {'relation': 'belongsTo'}, '01DMEKEFQG2J81YK81JASTNPMC': {'relation': 'belongsTo'}, '01DMEKEQABK83NZBHSDH65F1S6': {'relation': 'belongsTo'}, '01DMHRN19DANQ4A34K0D7DA1X4': {'relation': 'belongsTo'}, '021933c8-a648-47e1-8fb3-11fec8ed531c': {'relation': 'memberOf'}, '9ceff4c4-d4e5-4d15-a8a7-7fb27657df01': {'relation': 'memberOf'}, '25fa83d2-2aed-41ef-80bf-8dd9b982b926': {'relation': 'memberOf'}}
# {'3342d127-0eca-4a4a-9904-c67c0975e0ca': {'relation': 'belongsTo'}, '01DKRP3DAMEBSZ4QDFJJB8SV3K': {'relation': 'belongsTo'}, '01DKRP6H1FNMKP3XHQ65XYP27P': {'relation': 'belongsTo'}, '01DKVJSAFGH2QHDY321JTTQ7T5': {'relation': 'belongsTo'}, '01DKVJWSS6CFMCMC75S78XYRDK': {'relation': 'belongsTo'}, '73c7f5b4-1f4e-4192-9479-40a8eb9cbba1': {'relation': 'memberOf'}, 'af60eb82-2bcc-4c0f-87a7-aa325b1861c6': {'relation': 'memberOf'}, '8178e1e8-03d9-4131-a63c-8add4bf6be87': {'relation': 'memberOf'}, '5e1b167f-d4c6-467a-97f6-27239d7e3586': {'relation': 'memberOf'}}
# {'8ed6ea6d-11dc-4cd0-99c3-2ab36a02e959': {'relation': 'belongsTo'}, '01DBB3SN2ZA8GY2X7QGS1PF4K4': {'relation': 'belongsTo'}, 'aa223761-4855-48c4-89b2-272469dc5cea': {'relation': 'memberOf'}}
# {'3342d127-0eca-4a4a-9904-c67c0975e0ca': {'relation': 'belongsTo'}, '01DKRP6H1FNMKP3XHQ65XYP27P': {'relation': 'belongsTo'}, '01DKVJSAFGH2QHDY321JTTQ7T5': {'relation': 'belongsTo'}, 'af60eb82-2bcc-4c0f-87a7-aa325b1861c6': {'relation': 'memberOf'}, '8178e1e8-03d9-4131-a63c-8add4bf6be87': {'relation': 'memberOf'}}
# {'b3614ac5-18ad-4fcc-8406-263f5f1d2c6a': {'relation': 'belongsTo'}, '01DHV8EHEJPG1KVJGYW65DPCJG': {'relation': 'belongsTo'}, '9d69e583-7580-4890-8c96-b3870578344e': {'relation': 'memberOf'}}
# {'2847cbb9-aed8-477c-b46c-6cb995c62a96': {'relation': 'belongsTo'}, '01DMC7Y43YN8FZF8AG4BEYM9Z3': {'relation': 'belongsTo'}, '01DMBZ7YPSJGVVSS52E8H3HGE3': {'relation': 'belongsTo'}, '75ab547f-e983-4b50-83b7-44d0f4dcd27b': {'relation': 'memberOf'}, '3497cac8-3b5e-489d-b474-9d1d9c953dab': {'relation': 'memberOf'}}
# {'4d43b748-c30b-42f8-bd4a-ef5d682ed6c8': {'relation': 'belongsTo'}, '01DMEKEQABK83NZBHSDH65F1S6': {'relation': 'belongsTo'}, '01DMEKEFQG2J81YK81JASTNPMC': {'relation': 'belongsTo'}, '01DMHRN19DANQ4A34K0D7DA1X4': {'relation': 'belongsTo'}, '9ceff4c4-d4e5-4d15-a8a7-7fb27657df01': {'relation': 'memberOf'}, '021933c8-a648-47e1-8fb3-11fec8ed531c': {'relation': 'memberOf'}, '25fa83d2-2aed-41ef-80bf-8dd9b982b926': {'relation': 'memberOf'}}
# {'685affbb-42de-4a3f-8435-ac7b6f1b070b': {'relation': 'belongsTo'}, '01DHQZXY31NV8R4T4PPZGBZN6G': {'relation': 'belongsTo'}, '01DKH32CFW4A99WX70PFYT4FYB': {'relation': 'belongsTo'}, '5a8dee86-05df-44a3-b5eb-dd04f4ee5390': {'relation': 'memberOf'}, '80a72015-fbf3-4add-9abc-c248ca609b1d': {'relation': 'memberOf'}}
# {'d4ae4e47-530c-4800-8353-ce0ad6e6ce18': {'relation': 'belongsTo'}, '01DMEJ9R4SQSXEM7QDYY30R36K': {'relation': 'belongsTo'}, '01DMEJ17HEY989FH7XB87SKKNZ': {'relation': 'belongsTo'}, 'e91525b2-7869-48ca-906b-c3c932772264': {'relation': 'memberOf'}, 'b14eb41f-0376-4f4e-967a-cc63628c2766': {'relation': 'memberOf'}}
# {'2847cbb9-aed8-477c-b46c-6cb995c62a96': {'relation': 'belongsTo'}, '01DMBZ7YPSJGVVSS52E8H3HGE3': {'relation': 'belongsTo'}, '3497cac8-3b5e-489d-b474-9d1d9c953dab': {'relation': 'memberOf'}}
# {'2847cbb9-aed8-477c-b46c-6cb995c62a96': {'relation': 'belongsTo'}, '01DMBZ7YPSJGVVSS52E8H3HGE3': {'relation': 'belongsTo'}, '3497cac8-3b5e-489d-b474-9d1d9c953dab': {'relation': 'memberOf'}}
# {'2847cbb9-aed8-477c-b46c-6cb995c62a96': {'relation': 'belongsTo'}, '01DMBZ7YPSJGVVSS52E8H3HGE3': {'relation': 'belongsTo'}, '3497cac8-3b5e-489d-b474-9d1d9c953dab': {'relation': 'memberOf'}}
# {'2847cbb9-aed8-477c-b46c-6cb995c62a96': {'relation': 'belongsTo'}, '01DMBZ7YPSJGVVSS52E8H3HGE3': {'relation': 'belongsTo'}, '3497cac8-3b5e-489d-b474-9d1d9c953dab': {'relation': 'memberOf'}}
# {'b3614ac5-18ad-4fcc-8406-263f5f1d2c6a': {'relation': 'belongsTo'}, '01DMB1FZ11PD7K09QYN23NHYKT': {'relation': 'belongsTo'}, '7a17c30c-b539-4f8a-a55a-71a18bf3d8ce': {'relation': 'memberOf'}}
# {'b3614ac5-18ad-4fcc-8406-263f5f1d2c6a': {'relation': 'belongsTo'}, '01DMB1FZ11PD7K09QYN23NHYKT': {'relation': 'belongsTo'}, '7a17c30c-b539-4f8a-a55a-71a18bf3d8ce': {'relation': 'memberOf'}}
# {'2847cbb9-aed8-477c-b46c-6cb995c62a96': {'relation': 'belongsTo'}, '01DMBZ7YPSJGVVSS52E8H3HGE3': {'relation': 'belongsTo'}, '3497cac8-3b5e-489d-b474-9d1d9c953dab': {'relation': 'memberOf'}}
# {'2847cbb9-aed8-477c-b46c-6cb995c62a96': {'relation': 'belongsTo'}, '01DMBZ7YPSJGVVSS52E8H3HGE3': {'relation': 'belongsTo'}, '3497cac8-3b5e-489d-b474-9d1d9c953dab': {'relation': 'memberOf'}}
# {'2847cbb9-aed8-477c-b46c-6cb995c62a96': {'relation': 'belongsTo'}, '01DMBZ7YPSJGVVSS52E8H3HGE3': {'relation': 'belongsTo'}, '3497cac8-3b5e-489d-b474-9d1d9c953dab': {'relation': 'memberOf'}}
# {'2847cbb9-aed8-477c-b46c-6cb995c62a96': {'relation': 'belongsTo'}, '01DMBZ7YPSJGVVSS52E8H3HGE3': {'relation': 'belongsTo'}, '3497cac8-3b5e-489d-b474-9d1d9c953dab': {'relation': 'memberOf'}}
# {'d4ae4e47-530c-4800-8353-ce0ad6e6ce18': {'relation': 'belongsTo'}, '01DMEJ17HEY989FH7XB87SKKNZ': {'relation': 'belongsTo'}, '01DMEJ9R4SQSXEM7QDYY30R36K': {'relation': 'belongsTo'}, 'b14eb41f-0376-4f4e-967a-cc63628c2766': {'relation': 'memberOf'}, 'e91525b2-7869-48ca-906b-c3c932772264': {'relation': 'memberOf'}}
# {'d4ae4e47-530c-4800-8353-ce0ad6e6ce18': {'relation': 'belongsTo'}, '01DMEJ17HEY989FH7XB87SKKNZ': {'relation': 'belongsTo'}, '01DMEJ9R4SQSXEM7QDYY30R36K': {'relation': 'belongsTo'}, 'b14eb41f-0376-4f4e-967a-cc63628c2766': {'relation': 'memberOf'}, 'e91525b2-7869-48ca-906b-c3c932772264': {'relation': 'memberOf'}}
# {'d4ae4e47-530c-4800-8353-ce0ad6e6ce18': {'relation': 'belongsTo'}, '01DMEJ9R4SQSXEM7QDYY30R36K': {'relation': 'belongsTo'}, '01DMEJ17HEY989FH7XB87SKKNZ': {'relation': 'belongsTo'}, 'e91525b2-7869-48ca-906b-c3c932772264': {'relation': 'memberOf'}, 'b14eb41f-0376-4f4e-967a-cc63628c2766': {'relation': 'memberOf'}}
# {'4d43b748-c30b-42f8-bd4a-ef5d682ed6c8': {'relation': 'belongsTo'}, '01DMEKEFQG2J81YK81JASTNPMC': {'relation': 'belongsTo'}, '021933c8-a648-47e1-8fb3-11fec8ed531c': {'relation': 'memberOf'}}
# {'4d43b748-c30b-42f8-bd4a-ef5d682ed6c8': {'relation': 'belongsTo'}, '01DMEKEFQG2J81YK81JASTNPMC': {'relation': 'belongsTo'}, '01DMEKEQABK83NZBHSDH65F1S6': {'relation': 'belongsTo'}, '01DMHRN19DANQ4A34K0D7DA1X4': {'relation': 'belongsTo'}, '021933c8-a648-47e1-8fb3-11fec8ed531c': {'relation': 'memberOf'}, '9ceff4c4-d4e5-4d15-a8a7-7fb27657df01': {'relation': 'memberOf'}, '25fa83d2-2aed-41ef-80bf-8dd9b982b926': {'relation': 'memberOf'}}
# {'4d43b748-c30b-42f8-bd4a-ef5d682ed6c8': {'relation': 'belongsTo'}, '01DMEKEFQG2J81YK81JASTNPMC': {'relation': 'belongsTo'}, '01DMEKEQABK83NZBHSDH65F1S6': {'relation': 'belongsTo'}, '01DMHRN19DANQ4A34K0D7DA1X4': {'relation': 'belongsTo'}, '021933c8-a648-47e1-8fb3-11fec8ed531c': {'relation': 'memberOf'}, '9ceff4c4-d4e5-4d15-a8a7-7fb27657df01': {'relation': 'memberOf'}, '25fa83d2-2aed-41ef-80bf-8dd9b982b926': {'relation': 'memberOf'}}
# {'4d43b748-c30b-42f8-bd4a-ef5d682ed6c8': {'relation': 'belongsTo'}, '01DMEKEFQG2J81YK81JASTNPMC': {'relation': 'belongsTo'}, '01DMEKEQABK83NZBHSDH65F1S6': {'relation': 'belongsTo'}, '01DMHRN19DANQ4A34K0D7DA1X4': {'relation': 'belongsTo'}, '021933c8-a648-47e1-8fb3-11fec8ed531c': {'relation': 'memberOf'}, '9ceff4c4-d4e5-4d15-a8a7-7fb27657df01': {'relation': 'memberOf'}, '25fa83d2-2aed-41ef-80bf-8dd9b982b926': {'relation': 'memberOf'}}
# {'be325532-aa88-4efe-bbb5-c9b1b33702b5': {'relation': 'belongsTo'}, '01DMEMTNZZ9T2ZJYREPXCDVMW7': {'relation': 'belongsTo'}, 'dfa245c5-b1e8-4e74-9e0e-ffa612be3a54': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMAMVW3ZFMTYHASC69KBN3HB': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, 'd2e52c9f-c9b0-4e07-8b70-d1e6dbad3165': {'relation': 'memberOf'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMAMVW3ZFMTYHASC69KBN3HB': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, 'd2e52c9f-c9b0-4e07-8b70-d1e6dbad3165': {'relation': 'memberOf'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMAMVW3ZFMTYHASC69KBN3HB': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, 'd2e52c9f-c9b0-4e07-8b70-d1e6dbad3165': {'relation': 'memberOf'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMAMVW3ZFMTYHASC69KBN3HB': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, 'd2e52c9f-c9b0-4e07-8b70-d1e6dbad3165': {'relation': 'memberOf'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMAMVW3ZFMTYHASC69KBN3HB': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, 'd2e52c9f-c9b0-4e07-8b70-d1e6dbad3165': {'relation': 'memberOf'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMAMVW3ZFMTYHASC69KBN3HB': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, 'd2e52c9f-c9b0-4e07-8b70-d1e6dbad3165': {'relation': 'memberOf'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMAMVW3ZFMTYHASC69KBN3HB': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, 'd2e52c9f-c9b0-4e07-8b70-d1e6dbad3165': {'relation': 'memberOf'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'4d43b748-c30b-42f8-bd4a-ef5d682ed6c8': {'relation': 'belongsTo'}, '01DMEKEFQG2J81YK81JASTNPMC': {'relation': 'belongsTo'}, '01DMEKEQABK83NZBHSDH65F1S6': {'relation': 'belongsTo'}, '01DMHRN19DANQ4A34K0D7DA1X4': {'relation': 'belongsTo'}, '021933c8-a648-47e1-8fb3-11fec8ed531c': {'relation': 'memberOf'}, '9ceff4c4-d4e5-4d15-a8a7-7fb27657df01': {'relation': 'memberOf'}, '25fa83d2-2aed-41ef-80bf-8dd9b982b926': {'relation': 'memberOf'}}
# {'4d43b748-c30b-42f8-bd4a-ef5d682ed6c8': {'relation': 'belongsTo'}, '01DMEKEFQG2J81YK81JASTNPMC': {'relation': 'belongsTo'}, '01DMEKEQABK83NZBHSDH65F1S6': {'relation': 'belongsTo'}, '01DMHRN19DANQ4A34K0D7DA1X4': {'relation': 'belongsTo'}, '021933c8-a648-47e1-8fb3-11fec8ed531c': {'relation': 'memberOf'}, '9ceff4c4-d4e5-4d15-a8a7-7fb27657df01': {'relation': 'memberOf'}, '25fa83d2-2aed-41ef-80bf-8dd9b982b926': {'relation': 'memberOf'}}
# {'cb8438a4-06fa-450b-b7be-f128bbc7027e': {'relation': 'belongsTo'}, '01DMJ9C7MQB096GMS94X4RERS4': {'relation': 'belongsTo'}, '01DMJ9WR8VQPZ2NDAD2TD316W0': {'relation': 'belongsTo'}, 'dad7b3aa-8cc3-4c57-8761-2e93f78b9368': {'relation': 'memberOf'}, 'bb358091-ae2b-43f9-b8ae-576c4a89f364': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMJ1JRAAV71TWB2S3QMP5A7R': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, 'a9737c71-0dfd-45cc-b120-2a2bc0d9f947': {'relation': 'memberOf'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'75e0ef60-399f-41e2-897a-59e6119020a3': {'relation': 'belongsTo'}, '01DMT52XQ0HBYAQ6G6RF21311F': {'relation': 'belongsTo'}, '0333db7b-ac36-4ca7-aa65-6d1bd82367fd': {'relation': 'memberOf'}}
# {'75e0ef60-399f-41e2-897a-59e6119020a3': {'relation': 'belongsTo'}, '01DMT52XQ0HBYAQ6G6RF21311F': {'relation': 'belongsTo'}, '0333db7b-ac36-4ca7-aa65-6d1bd82367fd': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# {'08120f6c-bba9-4465-97cc-5fab13f6a1c8': {'relation': 'belongsTo'}, '01DMJ1F0RPC6NS4E0R401GC24N': {'relation': 'belongsTo'}, '9d82901b-8226-49c0-ab28-55dc1dee8b1a': {'relation': 'memberOf'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-177-ca826705bcef> in <module>
#       1 for n, attr in meta_graph.nodes.data():
# ----> 2     if attr['attribute'] == "userId":
#       3         print(meta_graph[n])
#
# KeyError: 'attribute'

# %%
for n1, n2, attr in meta_graph.edges.data():
    if attr['relation'] == "createdBy":
        print(meta_graph[n1])
# Out:
# {'b782dae5-06de-4b7a-bc7d-789a1ad005e5': {'relation': 'createdBy'}, 'fffc929e-0844-4a6b-8fbf-e15b04b59ebc': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, 'ee944a72-60c3-41f3-9525-885f68fd0338': {'relation': 'createdIn'}}
# {'75bdf310-110b-4b8f-ab88-b16fafce920e': {'relation': 'createdBy'}, 'a68bc584-69a8-441e-8192-176d3a42d1a0': {'relation': 'createdIn'}}
# {'e8653826-bf7f-4257-9cd1-43f5f89e1804': {'relation': 'createdBy'}, 'cdc9a444-3a49-4a85-92e6-e9fcd6aad0a6': {'relation': 'createdIn'}}
# {'b1c1ae7b-d346-40e5-9d4f-b6e03e36fe80': {'relation': 'createdBy'}, '3d233395-dc96-4b94-beb0-50ad6a599b5e': {'relation': 'createdIn'}}
# {'5318e532-354b-4362-93bf-b737bff54fcf': {'relation': 'createdBy'}, '3fa39cd0-7e8b-4ca7-bf0d-8017410c26bd': {'relation': 'createdIn'}}
# {'6240db37-4857-4fba-b13f-b0978ea7c8c2': {'relation': 'createdBy'}, '2a59f45b-0ab0-47ff-8a09-dc2d412e1f46': {'relation': 'createdIn'}}
# {'8d6db5f7-d9b7-4c54-ba38-fe710ffcaf3f': {'relation': 'createdBy'},
{'relation': 'createdIn'}}
# {'b782dae5-06de-4b7a-bc7d-789a1ad005e5': {'relation': 'createdBy'}, '4ec641b4-871a-4633-8721-61d692bde77e': {'relation': 'createdIn'}}
# {'23b90532-3546-4f31-aea6-d057489a7158': {'relation': 'createdBy'}, '1525bcc2-0f0d-47bd-897a-5d56bc5bd50e': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, 'c850931b-fff5-43d3-a5a0-cef2dc530baf': {'relation': 'createdIn'}}
# {'8d6db5f7-d9b7-4c54-ba38-fe710ffcaf3f': {'relation': 'createdBy'}, 'f90f63e2-46fd-4f73-9f40-6d05aa24ab18': {'relation': 'createdIn'}}
# {'8d6db5f7-d9b7-4c54-ba38-fe710ffcaf3f': {'relation': 'createdBy'}, '7f1acb31-042f-4484-9722-b7666b120435': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '7f1acb31-042f-4484-9722-b7666b120435': {'relation': 'createdIn'}}
# {'23b90532-3546-4f31-aea6-d057489a7158': {'relation': 'createdBy'}, '00ef8c5e-e134-4701-995b-5502a5fcb827': {'relation': 'createdIn'}}
# {'a95bd146-6f94-4276-b4ac-839f9eb9386b': {'relation': 'createdBy'}, '074885b0-ab17-4556-9fc0-183b5e6cb9ef': {'relation': 'createdIn'}}
# {'75bdf310-110b-4b8f-ab88-b16fafce920e': {'relation': 'createdBy'}, '5b9c106f-4932-4343-95da-2d98aa2c3c37': {'relation': 'createdIn'}}
# {'6582d196-ccbf-4634-b97f-2f9b90f7923f': {'relation': 'createdBy'}, '1f95cf66-0c36-4885-a8b6-043ee4c0536a': {'relation': 'createdIn'}}
# {'4d96eedf-d77f-4bed-a278-0a5cd758617c': {'relation': 'createdBy'}, '572197cf-0837-484e-8d9e-8d0ce8db03f8': {'relation': 'createdIn'}}
# {'182bbd1d-4616-4682-a254-55485b24b9d3': {'relation': 'createdBy'}, '4ec641b4-871a-4633-8721-61d692bde77e': {'relation': 'createdIn'}}
# {'2c944512-17a0-4912-9a16-6a3408da807c': {'relation': 'createdBy'}, '7bcb3e8a-cc44-4811-a834-232da53b85c5': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '7bcb3e8a-cc44-4811-a834-232da53b85c5': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, 'fffc929e-0844-4a6b-8fbf-e15b04b59ebc': {'relation': 'createdIn'}}
# {'2c944512-17a0-4912-9a16-6a3408da807c': {'relation': 'createdBy'}, '7bcb3e8a-cc44-4811-a834-232da53b85c5': {'relation': 'createdIn'}}
# {'8d6db5f7-d9b7-4c54-ba38-fe710ffcaf3f': {'relation': 'createdBy'}, 'bdcc282f-c3a8-4018-93bd-97d3890a0f61': {'relation': 'createdIn'}}
# {'84fbaa66-a247-4ea2-9ae0-53f3a2e519d6': {'relation': 'createdBy'}, 'c2ee1dae-f689-4ffb-b8e3-3a7535c2fd81': {'relation': 'createdIn'}}
# {'eaf52a7b-c09f-4119-975c-e05cc490f8b5': {'relation': 'createdBy'}, 'b6eaebbf-3130-4351-8f7d-7cb1a5444cd3': {'relation': 'createdIn'}}
# {'6d15b577-2ad1-49c0-bad6-484f338787e2': {'relation': 'createdBy'}, 'cd668d6f-5d30-4aa5-bd34-85d1d26c3917': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '073c6a4c-2a65-4063-bb55-5d9ee7f85a29': {'relation': 'createdIn'}}
# {'612459cf-b7c9-4fdf-9f94-8e18bb86514d': {'relation': 'createdBy'}, '02e8adb4-6ac8-4d6a-946d-3f47145eb0a0': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '073c6a4c-2a65-4063-bb55-5d9ee7f85a29': {'relation': 'createdIn'}}
# {'936e3738-e9ab-4d0e-baa0-7bbdec89b6b0': {'relation': 'createdBy'}, 'afe2a1cd-9701-46ef-af5d-0ce07c43f410': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '073c6a4c-2a65-4063-bb55-5d9ee7f85a29': {'relation': 'createdIn'}}
# {'8d6db5f7-d9b7-4c54-ba38-fe710ffcaf3f': {'relation': 'createdBy'}, 'c6990dd8-b08e-4224-a5c0-5ff1b90988f8': {'relation': 'createdIn'}}
# {'8fff81b5-b2f1-4aa5-ad67-405f3e8127f3': {'relation': 'createdBy'}, '36cc3be8-f5ac-4f30-af95-90dec34e7145': {'relation': 'createdIn'}}
# {'d6b3ef10-7f14-4877-b3eb-6b34e228fb44': {'relation': 'createdBy'}, 'bf926026-4900-428f-950a-82c96c220f19': {'relation': 'createdIn'}}
# {'5713ced8-b031-4679-84af-91dbc01da792': {'relation': 'createdBy'}, 'e5e9538a-8a03-4a25-87c1-e79face9f471': {'relation': 'createdIn'}}
# {'612459cf-b7c9-4fdf-9f94-8e18bb86514d': {'relation': 'createdBy'}, 'f488236c-6053-4021-8d86-22ee238d3ca4': {'relation': 'createdIn'}}
# {'b782dae5-06de-4b7a-bc7d-789a1ad005e5': {'relation': 'createdBy'}, '77319e69-d4fc-4320-b927-eb605a3882c5': {'relation': 'createdIn'}}
# {'b782dae5-06de-4b7a-bc7d-789a1ad005e5': {'relation': 'createdBy'}, '77319e69-d4fc-4320-b927-eb605a3882c5': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, 'e12960d5-a64c-4529-8bc2-7d23725fca8f': {'relation': 'createdIn'}}
# {'b4a57b25-de68-446c-ac99-0f856d3fe4d5': {'relation': 'createdBy'}, '25557357-ee89-412b-8c16-e1e95b33006b': {'relation': 'createdIn'}}
# {'b782dae5-06de-4b7a-bc7d-789a1ad005e5': {'relation': 'createdBy'},
{'relation': 'createdIn'}}
# {'2c944512-17a0-4912-9a16-6a3408da807c': {'relation': 'createdBy'}, '003d5f63-d23b-43cf-93bf-3119539d9661': {'relation': 'createdIn'}}
# {'7d41ab4a-8780-4ebe-aea5-7cc3b9e5b19c': {'relation': 'createdBy'}, '5fb78e23-afc6-4c1c-8322-bdeb3bff2918': {'relation': 'createdIn'}}
# {'936e3738-e9ab-4d0e-baa0-7bbdec89b6b0': {'relation': 'createdBy'}, '48b7f188-e0ce-49c5-9b79-e935b92f2957': {'relation': 'createdIn'}}
# {'65bb8395-2fb5-4409-a4bb-59bb707f1375': {'relation': 'createdBy'}, 'a6b87a38-2cd8-4d5e-866b-d237cd765a09': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '48b7f188-e0ce-49c5-9b79-e935b92f2957': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '48b7f188-e0ce-49c5-9b79-e935b92f2957': {'relation': 'createdIn'}}
# {'2c944512-17a0-4912-9a16-6a3408da807c': {'relation': 'createdBy'}, 'd40a5bf7-5d96-4fdf-b59d-33f3626bf984': {'relation': 'createdIn'}}
# {'1c3e01c6-2da4-4ec9-afe9-1632ba1f6a6b': {'relation': 'createdBy'}, 'f7af063e-5f29-44ba-bb6a-1d569caa280f': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '48b7f188-e0ce-49c5-9b79-e935b92f2957': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '48b7f188-e0ce-49c5-9b79-e935b92f2957': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '93620605-53bc-4103-b7dc-66cc2ce9a78c': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '80cf8272-25f8-4d35-bd71-cffdc8a6cb4e': {'relation': 'createdIn'}}
# {'2c944512-17a0-4912-9a16-6a3408da807c': {'relation': 'createdBy'}, '003d5f63-d23b-43cf-93bf-3119539d9661': {'relation': 'createdIn'}}
# {'2c944512-17a0-4912-9a16-6a3408da807c': {'relation': 'createdBy'}, 'f40a8c9e-8001-41ef-a9ab-3f151acf2115': {'relation': 'createdIn'}}
# {'1411c002-0644-419a-9130-468f8863e1b7': {'relation': 'createdBy'}, '50393164-189d-4645-a791-e9e6c7e5bad1': {'relation': 'createdIn'}}
# {'1c3e01c6-2da4-4ec9-afe9-1632ba1f6a6b': {'relation': 'createdBy'}, 'f7af063e-5f29-44ba-bb6a-1d569caa280f': {'relation': 'createdIn'}}
# {'2c944512-17a0-4912-9a16-6a3408da807c': {'relation': 'createdBy'}, '003d5f63-d23b-43cf-93bf-3119539d9661': {'relation': 'createdIn'}}
# {'1c3e01c6-2da4-4ec9-afe9-1632ba1f6a6b': {'relation': 'createdBy'}, 'f7af063e-5f29-44ba-bb6a-1d569caa280f': {'relation': 'createdIn'}}
# {'1c3e01c6-2da4-4ec9-afe9-1632ba1f6a6b': {'relation': 'createdBy'}, '0edcb4c7-9186-4d97-9681-7e9f638b824f': {'relation': 'createdIn'}}
# {'1c3e01c6-2da4-4ec9-afe9-1632ba1f6a6b': {'relation': 'createdBy'}, '0edcb4c7-9186-4d97-9681-7e9f638b824f': {'relation': 'createdIn'}}
# {'2c944512-17a0-4912-9a16-6a3408da807c': {'relation': 'createdBy'}, 'f40a8c9e-8001-41ef-a9ab-3f151acf2115': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, '48b7f188-e0ce-49c5-9b79-e935b92f2957': {'relation': 'createdIn'}}
# {'c66797a9-2e6d-46ad-9573-926e57f7dac3': {'relation': 'createdBy'}, '065e1788-7749-4f6a-9dbc-e154b4b8b8d4': {'relation': 'createdIn'}}
# {'1c3e01c6-2da4-4ec9-afe9-1632ba1f6a6b': {'relation': 'createdBy'}, '686a2208-7609-41ab-8834-b91cbc1cc773': {'relation': 'createdIn'}}
# {'716067a6-0a1a-4034-abc4-9a12ecafb39b': {'relation': 'createdBy'}, 'd40a5bf7-5d96-4fdf-b59d-33f3626bf984': {'relation': 'createdIn'}}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
meta_graph.nodes['b782dae5-06de-4b7a-bc7d-789a1ad005e5']
# Out:
# {'name': 'Cullen',
#  'email': 'cullen@etherlabs.io',
#  'source': 'slack',
#  'status': 'active',
#  'deleted': False,
#  'sourceId': 'U7ETWDU6N',
#  'createdAt': '2017-10-11T14:08:27.854963073Z',
#  'deletedAt': 'None',
#  'updatedAt': '2019-09-09T13:34:30.126088275Z',
#  'accessToken': 'xoxp-252430537393-252948470226-287109598679-b09d3ee1e50596a674b7d7ec3ced6fe4',
#  'mentionName': 'cullen',
#  'teamId': 'T7ECNFTBK',
#  'attribute': 'userId',
#  'avatarImage192': 'https://secure.gravatar.com/avatar/128c4b93aeee478a3fbc00b2f3753ea9.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2F80588%2Fimg%2Favatars%2Fava_0021-192.png',
#  'avatarImageOriginal': 'https://secure.gravatar.com/avatar/128c4b93aeee478a3fbc00b2f3753ea9.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2F7fa9%2Fimg%2Favatars%2Fava_0021-512.png'}

# %%
import pydgraph
import numpy as np
import json as js
from boto3 import client as bclient
from botocore.client import Config

# %%
from scipy.spatial.distance import cosine

# %%
url = "111.93.155.194:9080"

# %%
def to_json(data, filename):
    with open(filename + ".json", "w", encoding="utf-8") as f_:
        js.dump(data, f_, ensure_ascii=False, indent=4)

def read_json(json_file):
    with open(json_file) as f_:
        meeting = js.load(f_)
    return meeting

# %%
client_stub = pydgraph.DgraphClientStub(url)
client = pydgraph.DgraphClient(client_stub)

# %%
def perform_query(query, variables):
    txn = client.txn()
    try:
        res = client.txn(read_only=True).query(query, variables=variables)
        response = js.loads(res.json)

        return response
    finally:
        # Clean up. Calling this after txn.commit() is a no-op and hence safe.
        txn.discard()

# %%
user_kw_query = """
query userKw($n: string, $t: int) {
    userKw(func: eq(email, $n)) {
        uid
        xid
        name
        mentionName
        ~hasMember{
            name
        }
        ~authoredBy (first: $t) {
            hasKeywords {
                values
            }
        }
    }
}
"""

# %%
variables = {"$n": "shashank@etherlabs.io", "$t": "5"}
user_kw_resp = perform_query(query=user_kw_query, variables=variables)

# %%
user_kw_resp
# Out:
# {'userKw': [{'uid': '0xcfc87',
#    'xid': 'e034c7a6-0681-40ba-b7b2-b78de2a2cc3d',
#    'name': 'Shashank',
#    'mentionName': 'shashank',
#    '~authoredBy': [{'hasKeywords': [{'values': ['CSV ether ready',
#         'transportation app']}]},
#     {'hasKeywords': [{'values': ['animation to switched',
#         'HTTP libraries',
#         'HTTP',
#         'real change white code',
#         'second time',
#         'offline mode',
#         'images just renders',
#         'app remember',
#         'catch data',
#         'jump offline',
#         'choose is random']}]},
#     {'hasKeywords': [{'values': ['great examples',
#         'Lambda',
#         'modern application',
#         'Lambda functions',
#         'lot of different Lambda functions']}]},
#     {'hasKeywords': [{'values': ['real change',
#         'web component',
#         'app Remember',
#         'HTTP libraries',
#         'second time round',
#         'start the app',
#         'footer colleagues javascript',
#         'couple of differences',
#         'chose is a random',
#         'Stitches the same styling',
#         'web app',
#         'HTTP',
#         'Switched Off',
#         'working hard',
#         'deploy by cash',
#         'offline mode',
#         'core complex pieces',
#         'switch up online']}]}]},
#   {'uid': '0xd1f7f',
#    'xid': 'be748cf6-d983-4ac1-8854-97fdc98c056d',
#    'name': 'Shashank',
#    'mentionName': 'shashank',
#    '~authoredBy': [{'hasKeywords': [{'values': ['preference relations',
#         'variables by refer',
#         'ends the NI belong',
#         'training and test',
#         'architecture like work',
#         'carry on context',
#         'idea of generous people model touch',
#         'force Neural network work',
#         'computer vision',
#         'best architecture',
#         'precise conditioning',
#         'context the more precise',
#         'brilliant variable',
#         'increase over time',
#         'start out the intuition',
#         'bunch variables',
#         'building impression lot',
#         'kind of architecture that allows']}]},
#     {'hasKeywords': [{'values': ['Late forties',
#         'complete my thoughts accuracy',
#         'opposite politics',
#         'life districts']}]},
#     {'hasKeywords': [{'values': ['restaurant type',
#         'Old Hitler',
#         'cases grammatical Construction',
#         'expansion of space',
#         'data is Old Hitler',
#         'programmable sentence',
#         'return your son',
#         'Down Below',
#         'false positives',
#         'Genome']}]},
#     {'hasKeywords': [{'values': ['restaurant out fine',
#         'model and then fine',
#         'wrapped set team',
#         'data at the heart',
#         'send me support',
#         'heart of every field']}]}]}]}

# %%
def format_response(resp):
    user_id_dict = {}
    user_kw_dict = {}
    for info in resp["userKw"]:
        try:
            user_id = info["xid"]
            user_name = info["name"]

            user_id_dict.update({
                user_id: user_name
            })

            keyword_object = info["~authoredBy"]
            user_kw_list = []
            for obj in keyword_object:
                kw = obj["hasKeywords"]
                user_kw_list.extend([words for words in kw[0]["values"]])

            user_kw_dict.update({
                user_id: user_kw_list
            })
        except Exception:
            continue
    
    return user_kw_dict, user_id_dict

# %%
user_kw_dict, user_id_dict = format_response(resp=user_kw_resp)

# %%
user_kw_dict
# Out:
# {'e034c7a6-0681-40ba-b7b2-b78de2a2cc3d': ['CSV ether ready',
#   'transportation app',
#   'animation to switched',
#   'HTTP libraries',
#   'HTTP',
#   'real change white code',
#   'second time',
#   'offline mode',
#   'images just renders',
#   'app remember',
#   'catch data',
#   'jump offline',
#   'choose is random',
#   'great examples',
#   'Lambda',
#   'modern application',
#   'Lambda functions',
#   'lot of different Lambda functions',
#   'real change',
#   'web component',
#   'app Remember',
#   'HTTP libraries',
#   'second time round',
#   'start the app',
#   'footer colleagues javascript',
#   'couple of differences',
#   'chose is a random',
#   'Stitches the same styling',
#   'web app',
#   'HTTP',
#   'Switched Off',
#   'working hard',
#   'deploy by cash',
#   'offline mode',
#   'core complex pieces',
#   'switch up online'],
#  'be748cf6-d983-4ac1-8854-97fdc98c056d': ['preference relations',
#   'variables by refer',
#   'ends the NI belong',
#   'training and test',
#   'architecture like work',
#   'carry on context',
#   'idea of generous people model touch',
#   'force Neural network work',
#   'computer vision',
#   'best architecture',
#   'precise conditioning',
#   'context the more precise',
#   'brilliant variable',
#   'increase over time',
#   'start out the intuition',
#   'bunch variables',
#   'building impression lot',
#   'kind of architecture that allows',
#   'Late forties',
#   'complete my thoughts accuracy',
#   'opposite politics',
#   'life districts',
#   'restaurant type',
#   'Old Hitler',
#   'cases grammatical Construction',
#   'expansion of space',
#   'data is Old Hitler',
#   'programmable sentence',
#   'return your son',
#   'Down Below',
#   'false positives',
#   'Genome',
#   'restaurant out fine',
#   'model and then fine',
#   'wrapped set team',
#   'data at the heart',
#   'send me support',
#   'heart of every field']}

# %%
ref_user_kw_query = """
query userKw($t: int) {
    userKw(func: type("User")) {
        uid
        xid
        name
        mentionName
        ~hasMember{
            name
        }
        ~authoredBy (first: $t) {
            hasKeywords {
                values
            }
        }
    }
}
"""

# %%
var = {"$t": "5"}
ref_user_kw_resp = perform_query(query=ref_user_kw_query, variables=var)

# %%
ref_user_kw_resp
# Out:
# {'userKw': [{'uid': '0xa633a',
#    'xid': '18b15cf4-bcc7-4b0a-8d46-8a05421188c7',
#    'name': 'F1 Testing',
#    'mentionName': 'f1'},
#   {'uid': '0xa6387',
#    'xid': '3a23aba9-7d04-4451-927c-684c1673496e',
#    'name': 'Franklin Ferdinand',
#    'mentionName': 'franklin',
#    '~authoredBy': [{'hasKeywords': [{'values': ['Keys']}]},
#     {'hasKeywords': [{'values': ['nothingto Those people', 'Theo', 'Over']}]},
#     {'hasKeywords': [{'values': ['marks Jira',
#         'civil rights Isis',
#         'open project',
#         'climate changes',
#         'climate nats',
#         'lot of salt',
#         'smooth change',
#         'wait Meetings',
#         'speak aloud',
#         'feel ability',
#         'Redis',
#         'Isis',
#         'ability to speak aloud']}]},
#     {'hasKeywords': [{'values': ['process refund',
#         'process purchase',
#         'basic role',
#         'great function',
#         'leave a default option create role',
#         'create our two lambda channel',
#         'AWS Console',
#         'basic lambda',
#         'Lambda dot',
#         'guys called the process']}]}]},
#   {'uid': '0xa66d5',
#    'xid': '60d2ea6b-ed8c-4826-9c8c-024202a4148d',
#    '~authoredBy': [{'hasKeywords': [{'values': ['selling the starter',
#         'enable you to pull',
#         'Starter Kicks',
#         'pull out the features advantages',
#         'key selling point sheet']}]},
#     {'hasKeywords': [{'values': ['AWS free tier',
#         'Lambda function',
#         'AWS Lambda',
#         'learn more about AWS Lambda visit',
#         'clicks in the AWS Management console']}]},
#     {'hasKeywords': [{'values': ['point you find guilt',
#         'truth transparency',
#         'course your incredible expertise',
#         'American public',
#         'butt Alana attention',
#         'high cholesterol',
#         'American',
#         'Downplay Saturday afternoon',
#         'incredible expertise',
#         'Sarah P butt Alana attention',
#         'great at all suspicious',
#         'find guilt',
#         'powerful the American public']}]},
#     {'hasKeywords': [{'values': ['raise that busy',
#         'land and expand philosophy']}]},
#     {'hasKeywords': [{'values': ['higher the upselling',
#         'room but more meetings',
#         'email and call volume',
#         'churn and business objectives',
#         'bit more places',
#         'reps found three months',
#         'person meetings',
#         'bonus structure',
#         'aggressive meeting',
#         'are going to sell',
#         'customer success managers',
#         'Cool',
#         'people who are',
#         'people they talk',
#         'group we decrease',
#         'talk to your customers',
#         'people want to send money',
#         'earn as much money',
#         'jump the gun',
#         'Comple',
#         'promise you the better relationship']}]}]},
#   {'uid': '0xa66e2',
#    'xid': 'fe225c6e-c422-4f3f-b154-c24e34d7ecd1',
#    'name': 'Karthik M',
#    'mentionName': 'karthik'},
#   {'uid': '0xa66e4',
#    'xid': 'ecdbeaf4-7875-4a3a-aece-bf497db1a59c',
#    'name': 'ether_staging2',
#    'mentionName': 'ether_staging2'},
#   {'uid': '0xa66ed',
#    'xid': 'c4eb7144-f0da-47af-aa78-f269d1954468',
#    'name': 'Nisha',
#    'mentionName': 'nisha'},
#   {'uid': '0xa66ee',
#    'xid': '1ca96e95-bd1f-49f1-9b21-872b0e1730f8',
#    'name': 'Ether S2',
#    'mentionName': 'ether-s2'},
#   {'uid': '0xa66f0',
#    'xid': 'e5ebe035-b4b9-4d9b-a20f-5a4e56019f3a',
#    'name': '',
#    'mentionName': 'krishnadn'},
#   {'uid': '0xa66f2',
#    'xid': 'ea22ce0e-7297-494f-9645-724cf55721db',
#    'name': 'ETHER',
#    'mentionName': 'ether'},
#   {'uid': '0xa66f3',
#    'xid': '014d5f2a-e12e-4927-914d-78db18343e9d',
#    'name': 'Mark T800',
#    'mentionName': 'mark_t800'},
#   {'uid': '0xa875c', 'xid': '82613070-63d0-40ac-b68b-ef925462333d'},
#   {'uid': '0xa8d5f',
#    'xid': '88d0d047-a734-487d-bab0-d93bf5c1a317',
#    '~authoredBy': [{'hasKeywords': [{'values': ['meet spake meetings Efficient control']}]},
#     {'hasKeywords': [{'values': ['health substance']}]},
#     {'hasKeywords': [{'values': ['Django are definitely agriculture']}]},
#     {'hasKeywords': [{'values': ['sonic device',
#         'digital marketing',
#         'websites to connect with current perspective customers',
#         'marketing efforts',
#         'celebrity digital channels',
#         'search engines',
#         'social media demand']}]}]},
#   {'uid': '0xa8ded',
#    'xid': 'd15801f3-c8d1-4b93-8bca-ddcba68784fb',
#    'name': 'E Man Labs',
#    'mentionName': 'labs.etherman'},
#   {'uid': '0xa8df1',
#    'xid': 'f032cee8-d1e8-4622-870f-d3a236a5839f',
#    'name': 'Frank Lin',
#    'mentionName': 'franklin',
#    '~hasMember': [{'name': 'Test Run'}]},
#   {'uid': '0xa8df9',
#    'xid': '1459d910-4b0f-403c-97e4-c47b56f0d3ce',
#    'name': 'ETH-BJN',
#    'mentionName': 'eth_bjn'},
#   {'uid': '0xab125',
#    'xid': 'ed2a9481-7685-462d-b051-31ee80190eee',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth',
#    '~hasMember': [{'name': 'new-ws3'}]},
#   {'uid': '0xab153',
#    'xid': 'a96059bd-ddde-4836-bce3-8d7d695ab2da',
#    'name': 'F1 Testing',
#    'mentionName': 'f1',
#    '~hasMember': [{'name': 'frank-test-26july'}]},
#   {'uid': '0xab536',
#    'xid': 'c5f04edf-90fc-4b95-a783-fe8300af67f5',
#    'name': 'Ether S2',
#    'mentionName': 'ether-s2'},
#   {'uid': '0xab538',
#    'xid': '0943dbb5-c8ef-420a-be88-5bf9eaa59354',
#    'name': 'Vamshi Krishna',
#    'mentionName': 'vamshi'},
#   {'uid': '0xad78b',
#    'xid': 'f8c41d60-1a1b-45ca-b12d-de05a04e8d71',
#    '~authoredBy': [{'hasKeywords': [{'values': ['couple simple tasks',
#         'write tests',
#         'Test Kitchen']}]},
#     {'hasKeywords': [{'values': ['Mary',
#         'monitor connection',
#         'personal strengths',
#         'Amazon ec2',
#         'Service',
#         'eminent services',
#         'HTML',
#         'Amazon',
#         'Apache',
#         'web server open']}]}]},
#   {'uid': '0xad7fc', 'xid': '059c4283-0db0-4c59-9072-2455f9a15a66'},
#   {'uid': '0xad862',
#    'xid': '6250f80d-7d2c-4b97-b341-f48e1e8b626e',
#    'name': 'F3 Testing',
#    'mentionName': 'f3'},
#   {'uid': '0xada2f',
#    'xid': '86e50471-6e96-4527-a595-6e8581a62163',
#    '~authoredBy': [{'hasKeywords': [{'values': ['mornings to be specific pay drink ranking',
#         'engineering related cures',
#         'key phrases',
#         'specific pay drink ranking',
#         'graft based mornings',
#         'engineering general',
#         'edges with his implementation',
#         'buy us the grab',
#         'Model three idea',
#         'specific man',
#         'language model',
#         'jet context',
#         'meeting in an engineering general']}]}]},
#   {'uid': '0xadc1a',
#    'xid': '877324b4-37cc-4884-8d4e-fd0e7996d9ae',
#    'name': 'Luke T-800',
#    'mentionName': 'luke.test800'},
#   {'uid': '0xadc20',
#    'xid': '42a0ee1f-2796-4dd6-baaf-a578bad7550f',
#    'name': 'deep',
#    'mentionName': 'deep',
#    '~hasMember': [{'name': 'Frank-Test-2Aug'}]},
#   {'uid': '0xadc28',
#    'xid': 'cc5fdcd2-6c87-456e-bb60-cf8de61d3d89',
#    'name': 'Franklin',
#    'mentionName': 'franklin'},
#   {'uid': '0xadc29',
#    'xid': '8932c93e-2d8a-4bf7-a07f-223670d14a92',
#    'name': 'Mithun',
#    'mentionName': 'mithun'},
#   {'uid': '0xadc2a',
#    'xid': '996ec795-1fb9-4d2e-ba1b-bc22b7ec066f',
#    'name': 'ether_staging2',
#    'mentionName': 'ether_staging2'},
#   {'uid': '0xafc81',
#    'xid': 'feffe3ee-896f-45c3-9d91-1f6d962c66ce',
#    'name': 'Karthik Muralidharan',
#    'mentionName': 'karthik',
#    '~authoredBy': [{'hasKeywords': [{'values': ['insert events',
#         'lambda arguments',
#         'add some more criteria',
#         'combinations of criterias',
#         'change events',
#         'players scores',
#         'lot is data replication',
#         'record as the argument',
#         'guy to this',
#         'table at real time',
#         'player ID play',
#         'replicate dot',
#         'bit more searchable',
#         'leaderboards a tree',
#         'insert on the table',
#         'batch of changes',
#         'elastic search cluster',
#         'games played greater',
#         'time it event',
#         'reading off this table',
#         'lambda to your dot audio',
#         'faster and more efficient operation',
#         'game events',
#         'reading off your table',
#         'insert event',
#         'stands are gon',
#         'increment the total score',
#         'operation in your leader table',
#         'game events table',
#         'number of games played greater',
#         'batch operation',
#         'users can access this web service API',
#         'quick access',
#         'efficient operation',
#         'large number',
#         'year where your game events table',
#         'number of players playing a large',
#         'total score',
#         'inputs your lab',
#         'data over time',
#         'add an elastic search cluster',
#         'Cron job kind',
#         'elastic search',
#         'data store',
#         'reasonable approach chapter',
#         'data replication',
#         'lab in the middle',
#         'perform the corresponding operation',
#         'replicate this data',
#         'day you decide',
#         'lambda that they catch info',
#         'leader shape',
#         'pretty large',
#         'contents of this record',
#         'elasticsearch Buster',
#         'web server',
#         'reading off this elasticsearch Buster',
#         'read over much higher amounts',
#         'country and search by',
#         'time an insertion',
#         'hook up a lambda',
#         'web service API',
#         'increment at this point',
#         'primary key increment',
#         'Check this database',
#         'supports natively range and top sorting type queries']}]},
#     {'hasKeywords': [{'values': ['batch processing',
#         'red circles',
#         'concept of a stream',
#         'dot to be table',
#         'performance impact',
#         'user have no control',
#         'containers for record events change',
#         'shards are kind',
#         'kind of interesting',
#         'settle this option start',
#         'future video',
#         'level streams',
#         'super easy',
#         'independent of dot',
#         'stream with I kind figure',
#         'pick which type',
#         'number of shards as user',
#         'streams consists',
#         'figure would change',
#         'vehicles or containers',
#         'diagonal DB original table',
#         'source table',
#         'siri with the secrets number']}]},
#     {'hasKeywords': [{'values': ['overheard you saying backstage',
#         'knowledge of every painting',
#         'Renaissance man',
#         'Renaissance',
#         'art historians']}]}]},
#   {'uid': '0xafe43',
#    'xid': '58576d8c-c6b7-498f-980b-5768191b588b',
#    '~authoredBy': [{'hasKeywords': [{'values': ['Journey',
#         'natural language generation',
#         'machine learning',
#         'user interfaces',
#         'blast Journey',
#         'future episodes',
#         'included tons']}]},
#     {'hasKeywords': [{'values': ['YouTube',
#         'material orders',
#         'hard time']}]}]},
#   {'uid': '0xafe77',
#    'xid': '88f620dc-1417-407b-88d0-860200417486',
#    '~authoredBy': [{'hasKeywords': [{'values': ['individual articulate',
#         'discrimination number',
#         'word picture',
#         'State',
#         'plannin life',
#         'desk ready',
#         'avoid judgments',
#         'Magnus',
#         'produce grounds',
#         'describe expectations']}]}]},
#   {'uid': '0xaff64',
#    'xid': 'f8dd2818-fb6e-450b-bfe4-73ae75ae94c2',
#    'name': 'Nikita Sinha',
#    'mentionName': 'nikita',
#    '~authoredBy': [{'hasKeywords': [{'values': ['Jitsi',
#         'year sticky owner transition',
#         'glass Jitsi']}]},
#     {'hasKeywords': [{'values': ['Ronnie Jira',
#         'k. Abbasi',
#         'airline Donna',
#         'Donna',
#         'Divko a padding bottom dare']}]}]},
#   {'uid': '0xb0225',
#    'xid': '6709bdbd-e882-427c-b32f-d846c922c384',
#    '~authoredBy': [{'hasKeywords': [{'values': ['scaylr since test',
#         'Higgins',
#         'abstract answer',
#         'son be a phone display',
#         'conclusion Weather station',
#         'Agreed Weather Station',
#         'compression by their station']}]}]},
#   {'uid': '0xb0301',
#    'xid': '116476ba-fc72-4251-bdf9-44209d9effd4',
#    'name': 'Bast Cat',
#    'mentionName': 'ether.bast.cat'},
#   {'uid': '0xb0302',
#    'xid': 'e9605e84-e807-49a2-b6f3-933d22048bb4',
#    'name': 'ether_staging2',
#    'mentionName': 'ether_staging2',
#    '~hasMember': [{'name': 'EtherTest-18June'}]},
#   {'uid': '0xb030b',
#    'xid': 'ef790e64-ed50-4a19-a839-15e8b025d815',
#    'name': 'Ether S2',
#    'mentionName': 'ether-s2'},
#   {'uid': '0xb0312',
#    'xid': '35b673f6-080b-4ea8-96a0-36962da3c7b9',
#    'name': 'Rammohan Madhusudan',
#    'mentionName': 'ram'},
#   {'uid': '0xb23b0',
#    'xid': 'f593a901-6612-48df-839b-1b77c19e9103',
#    '~authoredBy': [{'hasKeywords': [{'values': ['University',
#         'better understand',
#         'elite University',
#         'manual labor',
#         'Benicia',
#         'hard work',
#         'Silver Spoon',
#         'flip side',
#         'tough times']}]},
#     {'hasKeywords': [{'values': ['learning curve',
#         'disadvantages include',
#         'expensive nature',
#         'External methods',
#         'great process',
#         'external recruiting include bring',
#         'needed skills',
#         'internal methods',
#         'jobs bringing',
#         'change agents']}]}]},
#   {'uid': '0xb2567', 'xid': 'de742ee3-18f7-47e2-a0de-6132b4040396'},
#   {'uid': '0xb2672',
#    'xid': '09609e9b-1d25-43df-a70d-090195c6133c',
#    'name': 'Karthik Muralidharan',
#    'mentionName': 'karthik'},
#   {'uid': '0xb26c3',
#    'xid': '708017d9-e0da-4f67-96d2-06ac853aaffc',
#    'name': 'Vamshi',
#    'mentionName': 'vamshi',
#    '~authoredBy': [{'hasKeywords': [{'values': ['respect of the governor Innings Tom',
#         'stuff it meeting and daughter never skate',
#         'total command car',
#         'recording in total command car',
#         'reliable solution',
#         'good problem',
#         'Alexei',
#         'Publishers',
#         'gamma flick Allegra',
#         'summary Publishers',
#         'governor Innings Tom',
#         'careful in case',
#         'Innings Tom',
#         'government a record from Connecticut']}]},
#     {'hasKeywords': [{'values': ['main function']}]},
#     {'hasKeywords': [{'values': ['call that level if functional object',
#         'number me man fine']}]}]},
#   {'uid': '0xb2802', 'xid': '7c524893-050f-4593-b417-df0e2e7d2aa7'},
#   {'uid': '0xb2815',
#    'xid': '65fa3d79-4b88-4828-a84f-eb3a59b9ffd6',
#    '~authoredBy': [{'hasKeywords': [{'values': ['reader did start']}]}]},
#   {'uid': '0xb2a0a',
#    'xid': '8b60a212-8772-44c0-828e-e65b5db8d04c',
#    'name': 'EtherMeet',
#    'mentionName': 'ethermeet'},
#   {'uid': '0xb2a17',
#    'xid': '669b44a2-1a8b-4fe7-989b-ba2f9481959f',
#    'name': 'ETHER',
#    'mentionName': 'ether'},
#   {'uid': '0xb4c18', 'xid': '947bf89d-6309-429e-b763-87700d5d06c3'},
#   {'uid': '0xb4e16',
#    'xid': '06904bdf-f06b-4151-853b-aa36a5de88d8',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth'},
#   {'uid': '0xb5173',
#    'xid': '35fb23bd-a892-4098-bbbb-1c7d186f5e8e',
#    'name': 'Mark T-800',
#    'mentionName': 'mark_t800'},
#   {'uid': '0xb5177',
#    'xid': '3428c62d-1c7c-4278-a62d-cd9dcc063813',
#    'name': 'cullenchildress',
#    'mentionName': 'cullenchildress',
#    '~hasMember': [{'name': 'EtherWorkflow'}]},
#   {'uid': '0xb517d',
#    'xid': '90e80418-5237-4cc9-8767-05d01475d03b',
#    'name': 'Vamshi Krishna',
#    'mentionName': 'vamshi',
#    '~hasMember': [{'name': 'Ether-Demo'}]},
#   {'uid': '0xb5185',
#    'xid': '5c085ecd-9b98-4d75-b3e9-422a34a1ec4a',
#    'name': 'adithya',
#    'mentionName': 'adithya'},
#   {'uid': '0xb5189',
#    'xid': 'b156ea75-4f99-4543-8977-6594055ba19b',
#    'name': 'Nisha Yadav',
#    'mentionName': 'nisha'},
#   {'uid': '0xb71b3', 'xid': '716067a6-0a1a-4034-abc4-9a12ecafb39b'},
#   {'uid': '0xb738a', 'xid': 'f5d8bc46-8bc2-4fa8-b3d2-bfc129db92be'},
#   {'uid': '0xb7478', 'xid': '80d8f5b3-4006-4601-9d77-3529dba66418'},
#   {'uid': '0xb7683',
#    'xid': 'cb892abd-fadd-495b-8dfe-4da79d40046f',
#    '~authoredBy': [{'hasKeywords': [{'values': ['trump camping',
#         'William Barr',
#         'spying on people',
#         'characterization Democrats',
#         'longstanding criticism',
#         "the Justice Department's",
#         'Russia probe',
#         'General William Barr']}]}]},
#   {'uid': '0xb785a',
#    'xid': 'a8c7b6f9-f4da-412d-adcd-58cc0c9e31ef',
#    'name': 'Trishanth-gmail',
#    'mentionName': 'trishanth.diwate'},
#   {'uid': '0xb785c',
#    'xid': '0c58253a-da47-4eae-b198-097903d8b7f9',
#    'name': 'Mithun',
#    'mentionName': 'mithun',
#    '~hasMember': [{'name': 'test-admin-add'}]},
#   {'uid': '0xb7865',
#    'xid': '30e5491d-228e-4972-9650-331f76553134',
#    'name': 'Lijo Jose',
#    'mentionName': 'lijo'},
#   {'uid': '0xb786c',
#    'xid': '6c2078d9-6e7f-4248-92a3-d74f9775714b',
#    'name': 'Tom 1000test',
#    'mentionName': 'tom.1000test'},
#   {'uid': '0xb786d',
#    'xid': '0da2fc3b-7915-40d9-a11f-d5180b32a25c',
#    'name': 'etherstaging',
#    'mentionName': 'ether_staging'},
#   {'uid': '0xb98cb',
#    'xid': 'b1b92672-20ce-4e0c-af0a-82de3016fcb0',
#    'name': 'mithun',
#    'mentionName': 'mithun',
#    '~authoredBy': [{'hasKeywords': [{'values': ['long time',
#         'consequences for the behavior',
#         'sequence of three local transactions',
#         'set of shorter transactions',
#         'concept to the saga',
#         'long running transactions',
#         'distributed transaction',
#         'transaction and model',
#         'saga mechanism',
#         'watch in the case',
#         'transactions that span multiple services',
#         'big idea',
#         'behavior of the system']}]},
#     {'hasKeywords': [{'values': ['Cooper', 'Redis']}]},
#     {'hasKeywords': [{'values': ['John']}]},
#     {'hasKeywords': [{'values': ['Google']}]}]},
#   {'uid': '0xb9904',
#    'xid': 'b89b4b70-0b8d-4155-bac9-4ceb7da8911d',
#    '~authoredBy': [{'hasKeywords': [{'values': ['step modulator',
#         'arbitrary arguments',
#         'group count',
#         'degree add',
#         'age Decker',
#         'Decker',
#         'Select A',
#         'outdegree add']}]}]},
#   {'uid': '0xb9920', 'xid': 'cd4d26c1-96d3-4c73-a977-9da8c3374507'},
#   {'uid': '0xb9bb2',
#    'xid': 'a68269bc-b2dd-41c0-a7f8-a217875505c3',
#    'name': 'Cullen',
#    'mentionName': 'cullen'},
#   {'uid': '0xb9f7f',
#    'xid': '2955c9e0-92b9-4638-bf3e-a0729d1dfa51',
#    '~authoredBy': [{'hasKeywords': [{'values': ['cars and meetings',
#         'mixed message']}]},
#     {'hasKeywords': [{'values': ['products in your home',
#         'Computing platforms till',
#         'prevalent that they Bible',
#         'question comes from Eric Sheridan',
#         'center of ambient Computing',
#         'vision of ambient Computing',
#         'Google family',
#         'Investments',
#         'Mast Family',
#         'continuity in the sense',
#         'position capitalize',
#         'Bible',
#         'investments in AI',
#         'sort of prevalent',
#         'Consumer services',
#         'Google',
#         'sort of a bit',
#         'capitalize on that opportunity',
#         'Computing for the Future',
#         'sense that over time Computing',
#         'opportunity of former term',
#         'home with our Mast Family',
#         'key role',
#         'developer platform',
#         'bit of a shift',
#         'AI across the company',
#         'UBS your line',
#         'key Investments',
#         'Eric Sheridan',
#         'dark big picture question',
#         'Service layer',
#         'Investments their phones will continue',
#         'Beyond',
#         'year just talk',
#         'Open question',
#         'bigger picture nature']}]},
#     {'hasKeywords': [{'values': ['cover the Safe Harbor',
#         'speakers presentation',
#         'call over to Sundar',
#         'Good afternoon',
#         'speaker today Allen West head',
#         'today regarding our business performance',
#         'company that helps people find answers',
#         'number of risks and uncertainties',
#         'session need to press star',
#         'public through our investor relations website',
#         'impact on society the chance',
#         'great quarter',
#         'deep computer science problems',
#         'mission to organize',
#         'capital expenditures',
#         'question during the session',
#         'ABC XYZ /',
#         'Sundar',
#         'Google with strong Revenue growth',
#         'Google',
#         'refer to the risk factors',
#         'Cloud',
#         'fundamental engineering challenges',
#         'operations and our expected level',
#         'Ruth Pratt',
#         'Ellen',
#         'mobile search YouTube',
#         'turn the call',
#         'require any further assistance',
#         'Allen',
#         'statements involve']}]},
#     {'hasKeywords': [{'values': ['Charlie living',
#         'Charlie',
#         'nice cream',
#         'Europe',
#         'February wow',
#         'understand business',
#         'helm of a charcoal Orion',
#         'HR than my colleagues',
#         'colleagues in the room',
#         'privilege in the fortune',
#         'number of companies',
#         'bit more about HR',
#         'business person',
#         'Orion',
#         'defines make great',
#         'complete sense',
#         'Stephen',
#         'Char',
#         'fantastic house eternity',
#         'HR in multiple roles',
#         'holiday has a story Stephen',
#         'audience a little bit',
#         'law professor',
#         "L'Oreal",
#         'business school',
#         'good with people']}]},
#     {'hasKeywords': [{'values': ['digital library',
#         'compile our own version',
#         'Victim',
#         'Itsy Bitsy',
#         'API',
#         'lick the ice change',
#         'toggle activists',
#         'Sydney',
#         'ultimate source',
#         'sell API',
#         'word victim',
#         'itsy bitsy']}]}]},
#   {'uid': '0xb9fa8',
#    'xid': 'bf3e79f7-440b-451c-b61d-215eeb0d3966',
#    'name': 'E Man',
#    'mentionName': 'labs.etherman',
#    '~hasMember': [{'name': 'bilt-matrix'}]},
#   {'uid': '0xb9fac',
#    'xid': 'f33bd8d1-0896-44bb-8e44-3a7a94939279',
#    'name': 'ether_staging2',
#    'mentionName': 'ether_staging2'},
#   {'uid': '0xb9faf',
#    'xid': '1651cfe2-cdad-4477-95c7-5c25617e1d0f',
#    'name': 'Parshwa Jain',
#    'mentionName': 'parshwa'},
#   {'uid': '0xb9fb0',
#    'xid': '944ff7df-c100-4544-8f2f-a1acb23df477',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth'},
#   {'uid': '0xb9fb5',
#    'xid': '025edad6-d672-4422-a1fb-74f9cee08000',
#    'name': 'Mark T800',
#    'mentionName': 'mark_t800'},
#   {'uid': '0xb9fb6',
#    'xid': '21cd6f40-581e-4aec-8038-4fc389435d51',
#    'name': 'Nisha Yadav',
#    'mentionName': 'nisha'},
#   {'uid': '0xbbfe0',
#    'xid': '00f5d60f-486f-48de-995a-7669cc45642c',
#    'name': 'Krishna Sai',
#    'mentionName': 'sai537'},
#   {'uid': '0xbc087', 'xid': '305ed591-b9da-4533-b169-151260e124ad'},
#   {'uid': '0xbc204',
#    'xid': '379b8173-98ae-4ae3-a278-9c11e6830af2',
#    '~authoredBy': [{'hasKeywords': [{'values': ['visual tool kit',
#         'start building',
#         'Moral support',
#         'learning memorable',
#         'paper ready',
#         'great idea']}]},
#     {'hasKeywords': [{'values': ['fish football',
#         'visual tool kit',
#         'portrait style',
#         'Hopeful expression']}]}]},
#   {'uid': '0xbc2d7',
#    'xid': '00237a29-143c-4d52-b092-008d25e4f948',
#    'name': 'Coy West',
#    'mentionName': 'coywest'},
#   {'uid': '0xbc382',
#    'xid': 'd5934fd1-809a-47d9-9ed8-fa81b22f3657',
#    'name': 'K2',
#    'mentionName': 'karthik',
#    '~hasMember': [{'name': 'ether-jitsi'}],
#    '~authoredBy': [{'hasKeywords': [{'values': ['default rule',
#         'default policy',
#         'touched here and leave',
#         'stuff functions perspective',
#         'error and in order',
#         'create role',
#         'Land Rover',
#         'Lambda',
#         'reminder by default',
#         'default and click',
#         'click on create',
#         'step function',
#         'Gonna Roll',
#         'create our state machine',
#         'Lambda function',
#         'rolls click',
#         'state machine',
#         'Aaron',
#         'click next not gon',
#         'lung functions',
#         'target of which Lambda function']}]},
#     {'hasKeywords': [{'values': ['production type',
#         'stuff is then incident',
#         'good visual queue',
#         'real time',
#         'container is purchase',
#         'hear introduction',
#         'output from the lambda function',
#         'stand on real quick',
#         'transaction type',
#         'instance where the credit action',
#         'position lambda',
#         'decision of living',
#         'process for production',
#         'city for your training figure',
#         'link teach',
#         'process purpose',
#         'business that I kind prepared',
#         'cycle function option',
#         'set up the time']}]},
#     {'hasKeywords': [{'values': ['Token',
#         'Coke',
#         'process or the exact',
#         'return the object',
#         'Lambda of function',
#         'purchase so the processing',
#         'code and base',
#         'reminder from the overview slide',
#         'create a role',
#         'Lambda',
#         'Windham wins inside',
#         'click the log',
#         'saved message',
#         'example for this administration',
#         'process purchase',
#         'southwark Universal chair',
#         'message and action site',
#         'change the headline',
#         'year month',
#         'process purchase function message',
#         'stuff functions',
#         'fine by default',
#         'time to this',
#         'Spirit',
#         'Property Brother',
#         'create a function',
#         'intents of purposes',
#         'purposes is based position',
#         'search changes',
#         'image steps',
#         'Second it looks good',
#         'create functions',
#         'Coke or after handle',
#         'versus is gon',
#         'response and Spirit',
#         'process purchase motion',
#         'family function']}]},
#     {'hasKeywords': [{'values': ['instance where a credit card transaction',
#         'cutesy little message',
#         'life cycle',
#         'opal from the Lambda function',
#         'input and the output',
#         'blue corresponds',
#         'Lambda',
#         'process production',
#         'transaction type',
#         'path and stuff',
#         'event type',
#         'figure out for instance',
#         'step function',
#         'visual cue Mister',
#         'perfect output',
#         'comment section',
#         'group stuff functions',
#         'production site',
#         'time stamp',
#         'trouble sir',
#         'click on start execution',
#         'confidence you look convert tools message',
#         'function for the faltering',
#         'click on output',
#         'real quick',
#         'match this video',
#         'custom message',
#         'video role']}]}]},
#   {'uid': '0xbc498',
#    'xid': '5c0c3a1f-219b-410e-9717-fd88ed79afaa',
#    '~authoredBy': [{'hasKeywords': [{'values': ['profit in year',
#         'year just was core',
#         'gateway point time',
#         'planning big',
#         'talk top',
#         'production that October',
#         'conference eighteenth therapy surface',
#         'time celebrate',
#         'clarify probably on conference eighteenth therapy surface',
#         'search your clarify']}]},
#     {'hasKeywords': [{'values': ['parts we company',
#         'time sort plan',
#         'company get their labor',
#         'main fair',
#         'course at the time sort plan',
#         'approach of course']}]},
#     {'hasKeywords': [{'values': ['question they were practices',
#         'bare over thousand dollars',
#         'providing was keys that proposals',
#         'test point',
#         'video nine years']}]},
#     {'hasKeywords': [{'values': ['video thirteen',
#         'recognition may throw',
#         'vote software']}]}]},
#   {'uid': '0xbc5f3',
#    'xid': 'f31e860c-0977-451a-8ab1-6eb5d3973642',
#    '~authoredBy': [{'hasKeywords': [{'values': ['subject of Dedham Platform',
#         'Andrews work',
#         'software engineer Andrew Davidson',
#         'trade offs',
#         'data warehouse',
#         'demands for advanced features',
#         'high performance',
#         'application front',
#         'requirements for a database expand',
#         'Andrew discussed the trade offs',
#         'data systems convey air',
#         'include multiple databases',
#         'sophisticated lodging',
#         'Andrew Davidson',
#         'Dedham Platform',
#         'Andrews',
#         'simple transactional data base',
#         'database expand',
#         'data platform',
#         'previous episode',
#         'Cloud Products',
#         'advanced features',
#         'transactional systems',
#         'Mongo D.',
#         'wider set',
#         'sequel database',
#         'Andrew Works',
#         'maintain performance',
#         'order to maintain performance',
#         'relation all database',
#         'simple Web',
#         'data requirements',
#         'number of companies have data requirements',
#         'block posts',
#         'best ways',
#         'financial transactions',
#         'Full disclosure Mongo']}]},
#     {'hasKeywords': [{'values': ['data scientist']}]},
#     {'hasKeywords': [{'values': ['bring them to support',
#         'Antarctic station',
#         'major changes',
#         'second base picks',
#         'wear line party',
#         'free spirits',
#         'community of free spirits',
#         'spirit of the beach',
#         'toe grow basics',
#         'Integration',
#         'current change',
#         'Okay',
#         'sort of purpose',
#         'Lance',
#         'toe validate',
#         'leave the major changes']}]},
#     {'hasKeywords': [{'values': ['left of people', 'Been Integration']}]}]},
#   {'uid': '0xbc6c3',
#    'xid': 'dc73ea13-5f18-4dd7-bf28-0ae11c62b4df',
#    'name': 'Tom 1000',
#    'mentionName': 'tom.1000test'},
#   {'uid': '0xbc6c7',
#    'xid': '0940ad9d-0a1d-49bc-be36-4d471e8810ce',
#    'name': 'F1 test',
#    'mentionName': 'f1'},
#   {'uid': '0xbc6cb',
#    'xid': '4aae63d7-530c-49a1-a9e8-cdb3645d1b62',
#    'name': 'Ether S2',
#    'mentionName': 'ether-s2'},
#   {'uid': '0xbe709',
#    'xid': '7833fafc-39bb-4ea8-8f39-348e9e536390',
#    'name': 'Venkata Dikshit',
#    'mentionName': 'venkat',
#    '~authoredBy': [{'hasKeywords': [{'values': ['test a factory',
#         'time to take holes',
#         'suffering of this idea',
#         'hold the grounds',
#         'boom backend',
#         'dig some holes',
#         'Wikipedia Page says Business magnate',
#         'time ideas',
#         'manage your time',
#         'time you must spend',
#         'manufacturing and that kind',
#         'business guy',
#         'Space X',
#         'variable time boom',
#         'unlock it and change',
#         'change my get impatient magnet',
#         'help funnel traffic',
#         'implementation of those ideas']}]},
#     {'hasKeywords': [{'values': ['industry forthis']}]},
#     {'hasKeywords': [{'values': ['Hierarchical Network Relational',
#         'databases use different transactions',
#         'SQL as the standard query language',
#         'transactions and even proprietary',
#         'database approach',
#         'stage that in table format',
#         'SQL oracle',
#         'insert search',
#         'delete big database records',
#         'historic data',
#         'maintenance databases',
#         'traditional flat file',
#         'major types',
#         'Texas an example',
#         'query database',
#         'statement select start',
#         'sQL Sai etcetera',
#         'benefits that some databases',
#         'transfer database management system',
#         'relational databases SQl',
#         'SQL percent']}]}]},
#   {'uid': '0xbe872',
#    'xid': 'a366bdbc-ba2f-4b09-ba6c-ad0c614af9ca',
#    'name': 'Arjun Kini',
#    'mentionName': 'arjun',
#    '~authoredBy': [{'hasKeywords': [{'values': ['ton of surfaces',
#         'Herbert']}]},
#     {'hasKeywords': [{'values': ['market penetration',
#         'printed telephone directories',
#         'multiple retailers',
#         'Tour Nautical',
#         'advertisers and people',
#         'affect our social psychology',
#         'target by the hires',
#         'Tour Nautical async satisfaction',
#         'iWork exertions',
#         'HR talent management bottle',
#         'large portion',
#         'Loren Hirings',
#         'backward building',
#         'add new columns or buy',
#         'Database confer form complex aggregate calculations',
#         'list expenses',
#         'specific importing profile',
#         'traditional bound consumers continue',
#         'employee satisfaction',
#         'way you communicate',
#         'great success',
#         'smart hires',
#         'opposite is true',
#         'address both sides',
#         'Satisfied employees',
#         'match the specific activities',
#         'great place',
#         'reach fewer consumers',
#         'common questions',
#         'predictor of performance',
#         'Satya',
#         'swarm of print and online lucky search engine marketing utilizes',
#         'avoid duplication',
#         'billboards all fall',
#         'social media manager',
#         'type of data like energy or string',
#         'link farming in constant market',
#         'brand they admire',
#         'daily satisfaction occurrence',
#         'feel connected',
#         'Theo',
#         'strong leadership',
#         'active left',
#         'visibility translates into higher traffic',
#         'personal computer',
#         'desirable employer',
#         'Brands are not people',
#         'unpaid mechanisms',
#         "Technical university's",
#         'content optimization',
#         'large number',
#         'demographic groups',
#         'enforce consistently debate integrity',
#         'hiring from the top Technical university',
#         'younger people tend',
#         'better spent on hiring',
#         'category of print media',
#         'sides of the equation',
#         'millions for more records',
#         'Require',
#         'critical backlash',
#         'attract people',
#         'ebb and flow with higher',
#         'Turn then its final total database',
#         'fair amount',
#         'reach certain market segments',
#         'Satya observing the capitalism',
#         'Resource',
#         'Require substantial investment',
#         'trend is for printed papers',
#         'result of book material factors',
#         'kinds of backgrounds',
#         'content online',
#         'nats thinkers',
#         'broke even millions',
#         'strange as the lines',
#         'cross reference records',
#         'retain key',
#         'Internets',
#         'tough critique',
#         'bunch of ways',
#         'guardrails and brand building blocks',
#         'stay calm',
#         'opinion on the subject',
#         'top employer',
#         'factor influencing overall satisfaction',
#         'engagement recognition',
#         'helpful in this case',
#         'turn areas continue',
#         'train stun',
#         'enhanced driven',
#         'multiple tables',
#         'remain included',
#         'human since our agency',
#         'employee engagement',
#         'compensation and benefits',
#         'sort is the databases relational',
#         'mechanisms may include as Theo techniques',
#         'engineers your time is better',
#         'multiple areas',
#         'tangible elements',
#         'distortions through critique and Satya',
#         'stun totals',
#         'groups of consumers',
#         'receive their daily updates printed hard copy format',
#         'Commerce site',
#         'complacent team',
#         'telephone books',
#         'logger engagements',
#         'edgy or just affair',
#         'relationship between the database',
#         'create relationships',
#         'Waist highlights capitalism',
#         'staging basis']}]}]},
#   {'uid': '0xbe9a2',
#    'xid': 'ad34c730-5214-4455-9ed1-3f2b34009a66',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth'},
#   {'uid': '0xbebfd', 'xid': 'd566b02e-5caa-4429-bb81-9a7cba36d087'},
#   {'uid': '0xbecd1',
#    'xid': '5fa66db8-127b-4525-8c38-df7acf7de242',
#    '~authoredBy': [{'hasKeywords': [{'values': ['couch bases',
#         'eyes the relational database paradigm',
#         'pretty poor',
#         'pretty weak',
#         'real relationships',
#         'relational database paradigm',
#         'represent relations',
#         'data in a single blow',
#         'single blow',
#         'data stores',
#         'reaction reticence',
#         'Apache H Base',
#         'complex connectiveness',
#         'tables by a foreign key',
#         'find funny',
#         'single table',
#         'enforce any sort of referential integrity',
#         'connectedness in your data',
#         'rows and columns',
#         'link together tables',
#         'relation relations',
#         'single database',
#         'bit more complex',
#         'Rose',
#         'mongo DBS',
#         'join data',
#         'relational databases',
#         'Inasmuch',
#         'simple databases',
#         'link together foreign',
#         'sequel data story',
#         'foreign keys',
#         'wide columns',
#         'stores or column oriented databases',
#         'referential integrity']}]},
#     {'hasKeywords': [{'values': ['Bridges of Konigsberg problem',
#         'level set',
#         'edges represent',
#         'draft databases',
#         'spit heard',
#         'graft database',
#         'learn from my mistakes',
#         'ways that allow',
#         'Konigsberg problem',
#         'discrete mathematics course',
#         'data stores',
#         'work with each type',
#         'talk about some examples',
#         'type of no sequel database',
#         'successful project',
#         'data complexity',
#         'complex data',
#         'mathematical construct',
#         'successful early',
#         'Vergis',
#         'graph theory',
#         'Vergis ease',
#         'biggest challenge',
#         'craft databases',
#         'work with people',
#         'simple data',
#         'Konigsberg',
#         'Graft debate graph Databases',
#         'databases and data stores',
#         'ese Texas',
#         'sequel database',
#         'lot of the mistakes',
#         'people who spit heard',
#         'wrong use case',
#         'lot of time',
#         'vergis ese Texas',
#         'top of graph theory',
#         'repeat the same problems',
#         'data types',
#         'databases is kind',
#         'relationships between Vergis ease']}]},
#     {'hasKeywords': [{'values': ['Jitsi',
#         'winter in Florida',
#         'Represent patients',
#         'interesting insight',
#         'that winter',
#         'air from New York',
#         'patterns in this graph',
#         'Medicare',
#         'Dr Denise Kaz Nell',
#         'Denise Kaz Nell',
#         'vergis ease represent doctors',
#         'lot of sense',
#         'lot of people',
#         'Medicare data',
#         'lot of shared patients',
#         'United States',
#         'vor Jitsi',
#         'York and L.',
#         'federal health care spending',
#         'size of the vor Jitsi',
#         'common between doctors',
#         'start seeing patterns',
#         'York and Florida']}]},
#     {'hasKeywords': [{'values': ['actual Twitter data',
#         'better job',
#         'graft database',
#         'real life',
#         'strength of mine',
#         'conceptual model',
#         'graft databases',
#         'represent real',
#         'connections much better']}]},
#     {'hasKeywords': [{'values': ['audience is heard',
#         'graft databases',
#         'skeptics guide',
#         'Dave back burner',
#         'kind of wanted',
#         'Dave',
#         'graph databases heard']}]}]},
#   {'uid': '0xbeda6',
#    'xid': 'bf1d147c-d2ac-4193-adbb-ff3092e728ae',
#    'name': 'ether_staging2',
#    'mentionName': 'ether_staging2',
#    '~hasMember': [{'name': 'New-WS'}]},
#   {'uid': '0xbedaa',
#    'xid': 'e3d0510b-2f27-4180-9aa1-56818b074da0',
#    'name': 'Trishanth D',
#    'mentionName': 'trishanth'},
#   {'uid': '0xbedab',
#    'xid': '30a76a57-9e75-47ab-a3d3-d9e8caf440c5',
#    'name': 'vamshi',
#    'mentionName': 'vamshi',
#    '~hasMember': [{'name': 'vtemp4'}]},
#   {'uid': '0xbedb4',
#    'xid': '2912d520-94cf-4930-b277-dde154e9685a',
#    'name': 'Shweta',
#    'mentionName': 'shweta'},
#   {'uid': '0xbedb8',
#    'xid': '74b57020-76db-447f-828b-80cdc83fc849',
#    'name': 'Mithun',
#    'mentionName': 'mithun'},
#   {'uid': '0xbedba',
#    'xid': '1afa9da4-8f3a-40ee-af4a-ffb51feb2b52',
#    'name': 'Ether S2',
#    'mentionName': 'ether-s2'},
#   {'uid': '0xc0df1', 'xid': '1c47538b-de87-4c94-afbe-a8318dec4040'},
#   {'uid': '0xc1432',
#    'xid': 'b1ba3273-389f-45a3-92b7-25fded881cb0',
#    '~authoredBy': [{'hasKeywords': [{'values': ['recorder was searching toe',
#         'recorders like Rachael Microphone',
#         'Rachael Microphone',
#         'meat microphone toe',
#         'guys can figure',
#         'mutant news',
#         'eso recorder',
#         'feet for recorder']}]}]},
#   {'uid': '0xc14c6',
#    'xid': 'eb1a42bc-fa7f-4976-bce9-dd1ac160724c',
#    'name': 'Deep',
#    'mentionName': 'deep',
#    '~hasMember': [{'name': 'EmptyList'}]},
#   {'uid': '0xc14d0',
#    'xid': 'a28f608c-d172-49a1-9ae5-fb9710889fcc',
#    'name': 'Kartik Ramachandran',
#    'mentionName': 'kartik'},
#   {'uid': '0xc3977',
#    'xid': 'edd78ba4-b452-4816-8f3d-0886cba74f40',
#    'name': 'Cullen Childress',
#    'mentionName': 'cullen',
#    '~authoredBy': [{'hasKeywords': [{'values': ['financial engineering',
#         'Solana promise',
#         'long time',
#         'Department basis',
#         'number one apples trading',
#         'better job',
#         'grow whatever conclusion',
#         'work plans',
#         'amount of original resource',
#         'follow what they meant',
#         'clear Target',
#         'market strategy',
#         'communications strategy',
#         'apples trading',
#         'future product roadmap',
#         'logistics distribution strategies',
#         'call from board',
#         'today the future',
#         'cases When the Music Stops',
#         'bottom line will follow',
#         'accomplish that the pieces',
#         'corporate massive layoffs',
#         'valuable lesson',
#         'equal or greater',
#         'twenty days',
#         'pet sitter',
#         'original resource',
#         'culture with your company',
#         'trouble that apple',
#         'top line the bottom',
#         'forget their financials',
#         'apples competitors',
#         'evident for another quarter',
#         'clear Direction']}]},
#     {'hasKeywords': [{'values': ['create such good people',
#         'good people',
#         'talented people',
#         'place since that event',
#         'expect Microsoft',
#         'matter of fact Macintosh',
#         'board member support set',
#         'crazy that these companies',
#         'fact Macintosh',
#         'hostile relationship',
#         'platform that brought Microsoft',
#         'independent very talented people',
#         'track again apple and Microsoft',
#         'crony friends',
#         'good for the customer',
#         'desktop computer market',
#         'support that a thousand percent',
#         'Bill and Steve',
#         'applications business']}]},
#     {'hasKeywords': [{'values': ['dollar per year',
#         'happen overnight',
#         'key Channel partners',
#         'company with Steve Wozniak',
#         'people except my promise',
#         'changes in the channel',
#         'family time',
#         'people need these symbols',
#         'personal financial stuff',
#         'big recommitment',
#         'lot of people',
#         'major Channel partners',
#         'mind reader',
#         'parking lot',
#         'discuss that with people',
#         'buying experience',
#         'Apple turn',
#         'pet sitter',
#         'retail experience',
#         'late and on weekends',
#         'clean up this retail experience',
#         'definite place']}]},
#     {'hasKeywords': [{'values': ['Apple and microsoft',
#         'work with the best people',
#         'platform that brought microsoft',
#         'strong board',
#         'percent of the desktop computer',
#         'permanent fairly far organizations',
#         'bill that as',
#         'place since that event',
#         'candidate they want lure',
#         'great deal',
#         'great person ready',
#         'Chrysler and IBM',
#         'board and several videos great',
#         'IBM during this turn',
#         'board you guys',
#         'strong boy',
#         'group of people',
#         'Topic very high quality',
#         'Bill Campbell CEO',
#         'matter of fact macintosh',
#         'crazy that these companies',
#         'companies back on track',
#         'high quality',
#         'talented group',
#         'grow so I guess',
#         'close the deal',
#         'people that have better',
#         'country of midgets',
#         'expect microsoft',
#         'videos great',
#         'find hopefully people',
#         'second largest software company',
#         'hospital relationship',
#         'people on this board',
#         'independent very talented',
#         'lot of CEOs and Larry Ellison',
#         'work with people',
#         'strong people',
#         'find got a great deal',
#         'lot of build usage sign work',
#         'short period',
#         'crony friends',
#         'good for the customer',
#         'largest consumer software companies',
#         'board number',
#         'CEO you find',
#         'strong War',
#         'lot of stuff',
#         'best people',
#         'great people',
#         'support that a thousand percent',
#         'lot of microsoft',
#         'good want to work']}]},
#     {'hasKeywords': [{'values': ['good and about seventy percent',
#         'work plans',
#         'amount of original resource',
#         'remain and add',
#         'start something process',
#         'third tons',
#         'clear target',
#         'future product road',
#         'mile you get attach',
#         'clear direction',
#         'number one apple trading',
#         'attach use the car',
#         'people that dot the share',
#         'times their sales',
#         'evident for another quarter',
#         'good promise']}]}]},
#   {'uid': '0xc3b82',
#    'xid': 'cd7ed2ff-fa71-4ff9-a007-d4ef9b2b85b6',
#    '~authoredBy': [{'hasKeywords': [{'values': ['bit of a problem',
#         'radar sense',
#         'pixel for Excel',
#         'technology is freaking awesome',
#         'bit skewed',
#         'public perception',
#         'Optics',
#         'Excel',
#         'problem because the Optics']}]},
#     {'hasKeywords': [{'values': ['Apple',
#         'hour of charge',
#         'quick charge',
#         'low can plug',
#         'pause Pro',
#         'Android',
#         'mode in the middle',
#         'earbuds on and taste bit',
#         'work with Android',
#         'full flight',
#         'Hours with noise cancelling',
#         'half hours',
#         'couple other athletes use number',
#         'bit better',
#         'couple minutes',
#         'regular on mode',
#         'pods and silicon tips amazing sound']}]},
#     {'hasKeywords': [{'values': ['data centers',
#         'action to follow',
#         'staging environment',
#         'deploy entire development environment',
#         'love about Docker',
#         'total consistency',
#         'Docker']}]},
#     {'hasKeywords': [{'values': ['Little']}]}]},
#   {'uid': '0xc3ba1',
#    'xid': '4ada69a0-b665-4da1-a907-7ebcdb30f2f9',
#    'name': 'Mithun',
#    'mentionName': 'mithun'},
#   {'uid': '0xc3ba5',
#    'xid': 'd5516b8b-cbd4-4327-8ea4-568e20d194cb',
#    'name': 'T-1000',
#    'mentionName': 'tom.1000test',
#    '~hasMember': [{'name': 'Abraca-Dabra'}]},
#   {'uid': '0xc5e0e',
#    'xid': '2cd90f06-74f3-48cc-922a-cd6b8782ba0f',
#    'name': 'Shubham',
#    'mentionName': 'shubham',
#    '~authoredBy': [{'hasKeywords': [{'values': ['density in one part',
#         'properties in different parts',
#         'data have different properties',
#         'space for example',
#         'third example',
#         'part of the space']}]},
#     {'hasKeywords': [{'values': ['Janet',
#         'great world culture',
#         'organization can enhance every investment',
#         'change the best employees',
#         'stick in an organization',
#         'Contrary to popular belief',
#         'employees empowering world couple',
#         'architectural wonders',
#         'Housekeeping team',
#         'Kelvin',
#         'organized place',
#         'Create a system',
#         'find it difficult to complete tests',
#         'industry culture',
#         'feel more valuable',
#         'example of a firm',
#         'Google',
#         'feeling and energy',
#         'place on the people',
#         'sense of acceptance',
#         'team culture',
#         'feel you belong',
#         'culture of the place',
#         'people feel',
#         'boost your self esteem',
#         'greatest advantage',
#         'profile or responsibilities',
#         'Culture is the meeting',
#         'firm using different people skills',
# ...
#    'name': 'Parshwa Nemi Jain',
#    'mentionName': 'parshwa'},
#   {'uid': '0xe0eb9', 'xid': '39b1c26e-5402-4d3a-861d-859b64d6d1c5'},
#   {'uid': '0xe0f62',
#    'xid': '2f506a3d-9e81-4de6-9d46-a1fbf949fdc9',
#    '~authoredBy': [{'hasKeywords': [{'values': ['Analysis',
#         'Common forms',
#         'management discussion',
#         'future performance',
#         'course financial statements',
#         'capital resource position',
#         'content or course financial statements',
#         'management to discuss',
#         'liquidity and capital resource position',
#         'Arrangement',
#         'Market opportunities management',
#         'discuss that Arrangement',
#         'current financial position',
#         'Analysis or in DNA']}]},
#     {'hasKeywords': [{'values': ['great job',
#         'disaster strikes',
#         'year to help them track',
#         'response time',
#         'small check',
#         'Walmart',
#         'workplace safely using machinery',
#         'safety issues',
#         'evacuation procedure',
#         'disastrous earthquake preparedness workplace violence',
#         'Walmart attitude case',
#         'fire rather disastrous earthquake preparedness workplace violence',
#         'unauthorized people',
#         'Guys do a great job']}]},
#     {'hasKeywords': [{'values': ['Analysis',
#         'report includes also natural communication',
#         'convey financial',
#         'public is considered financial',
#         'notes of the financial statements',
#         'Analysis auditor reports',
#         'users including press releases shareholder minutes management letters']}]},
#     {'hasKeywords': [{'values': ['Wal Mart',
#         'prepared for safety issues',
#         'response playing',
#         'small checkup reminders',
#         'workplace safely using machinery',
#         'configure figure',
#         'case of the guard',
#         'case of fire',
#         'Earthquake prepared nats workplace violence procedures',
#         'unauthorized people',
#         'Proactiv',
#         'hermes do a great job',
#         'company on track']}]},
#     {'hasKeywords': [{'values': ['clothes design',
#         'Vincent reason',
#         'strict branching model design project',
#         'maintaining and recording leases course',
#         'benefits of future Branch works',
#         'feature branches',
#         'addition to feature branches',
#         'flow workflow',
#         'feature Branch work',
#         'future Branch works',
#         'robust framework',
#         'pull requests',
#         'recording leases course',
#         'find a strict branching model design project',
#         'interact and this addition',
#         'specific roles',
#         'add any new Concepts',
#         'release this workflow',
#         'efficient collaboration',
#         'individual branches',
#         'larger projects good flow']}]}]},
#   {'uid': '0xe1073',
#    'xid': 'f13c3097-4e6f-494b-9930-24db94110740',
#    'name': 'EtherMeet',
#    'mentionName': 'ether'},
#   {'uid': '0xe1076',
#    'xid': 'd2bda229-33db-41ff-9f8a-0fe34c3c5c94',
#    'name': 'Mithun',
#    'mentionName': 'mithun'},
#   {'uid': '0xe1077',
#    'xid': '942067e7-d1e1-4a29-8456-58fb1b5bf943',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth',
#    '~hasMember': [{'name': 'UninstallFlow'}]},
#   {'uid': '0xe1079',
#    'xid': 'd7a67cd8-dd83-43d9-a5d0-1796bb623ea7',
#    'name': 'F2 Test',
#    'mentionName': 'f2',
#    '~hasMember': [{'name': 'F1-27june'}]},
#   {'uid': '0xe311d',
#    'xid': 'ad57d007-5271-410d-aa0a-bcb4b0186639',
#    'name': 'Deep Moradia',
#    'mentionName': 'deep',
#    '~authoredBy': [{'hasKeywords': [{'values': ['firefox and Chrome for web',
#         'user regions']}]}]},
#   {'uid': '0xe3756',
#    'xid': 'a286a84c-5e5b-4fd9-aa85-0ea86f0b5d14',
#    'name': 'Mithun',
#    'mentionName': 'mithun',
#    '~hasMember': [{'name': 'mith2july2019'}]},
#   {'uid': '0xe3759',
#    'xid': 'acb5d636-8566-4f00-b265-8bca4c2a172b',
#    'name': 'vani',
#    'mentionName': 'vani',
#    '~hasMember': [{'name': 'ether-test'}]},
#   {'uid': '0xe375a',
#    'xid': '9bd3b2d9-b101-4751-8d11-3ee7193abd81',
#    'name': 'Bast Cast',
#    'mentionName': 'ether.bast.cat',
#    '~hasMember': [{'name': 'Sand-Clock'}]},
#   {'uid': '0xe3765',
#    'xid': '0b482205-63f8-4246-9f0c-28de86a3f40f',
#    'name': 'EtherMeet',
#    'mentionName': 'ethermeet'},
#   {'uid': '0xe3767',
#    'xid': 'e5344a79-60c3-4cb7-9ad1-62f268455404',
#    'name': 'akshay',
#    'mentionName': 'akshay'},
#   {'uid': '0xe3768',
#    'xid': '3461155a-7be8-4721-a0a1-121be2a74ace',
#    'name': '',
#    'mentionName': 'tushar_mehta'},
#   {'uid': '0xe3769',
#    'xid': 'cb9be453-fd8c-4b8f-be5e-3e62bb3942f0',
#    'name': 'etherdev',
#    'mentionName': 'etherdev'},
#   {'uid': '0xe376c',
#    'xid': 'a85fad2b-ab05-4cf1-81fa-000b9bf9f36d',
#    'name': 'Mithun',
#    'mentionName': 'mithun'},
#   {'uid': '0xe57e9',
#    'xid': '7e701eae-c283-4df5-abfa-4c0fcb3d7a94',
#    'name': 'Vani',
#    'mentionName': 'vani',
#    '~authoredBy': [{'hasKeywords': [{'values': ['star to note',
#         'serverless remember',
#         'dig to the bottom',
#         'buy observable',
#         'notify takes no arguments',
#         'diverge from the names',
#         'observers to implement',
#         'actual methods',
#         'Iaw server',
#         'specific video',
#         'Dino',
#         'super clear',
#         'observer remove',
#         'observable Tze',
#         'dhe remove',
#         'concrete limitations offset center vices',
#         'command I observers',
#         'observer and notify',
#         'eye observable',
#         'register our server',
#         'bottom of that someday',
#         'observable bubbles']}]},
#     {'hasKeywords': [{'values': ['large table', 'Internet news']}]}]},
#   {'uid': '0xe59ca', 'xid': 'eff3af88-2697-498d-afb7-ba80a97a75c9'},
#   {'uid': '0xe5aa3', 'xid': 'cb38396f-700b-4e22-a323-c9ee8ba2fa6d'},
#   {'uid': '0xe5b30',
#    'xid': '889a8a2e-9a3d-495f-b074-9060d0c19f9b',
#    'name': 'Nisha',
#    'mentionName': 'nisha'},
#   {'uid': '0xe5e99',
#    'xid': 'f4b0071a-9c8c-4b55-b2a1-0eef665006d7',
#    'name': 'Vani',
#    'mentionName': 'vani'},
#   {'uid': '0xe5e9a',
#    'xid': '048f49e2-035c-4de3-b1e2-df37e7ea03b5',
#    'name': 'f4',
#    'mentionName': 'f4'},
#   {'uid': '0xe5ea4',
#    'xid': 'ffa65d89-4837-4afd-9b2f-7bcf4398afba',
#    'name': 'ether_staging2',
#    'mentionName': 'ether_staging2'},
#   {'uid': '0xe5ea7',
#    'xid': 'd3045052-ca4d-4e64-8122-5211e3961b08',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth'},
#   {'uid': '0xe5ea9',
#    'xid': 'd91ea003-6e54-472c-8567-05f7e7378d89',
#    'name': 'Mithun',
#    'mentionName': 'mithun'},
#   {'uid': '0xe7efb',
#    'xid': '1e7822b3-3fa4-4902-879b-3e4489871d84',
#    'name': 'Franklin Ferdinand',
#    'mentionName': 'franklin'},
#   {'uid': '0xe8122', 'xid': '9fd554a3-6d96-4eae-803a-cd9dbb9acd87'},
#   {'uid': '0xe81e2',
#    'xid': '8271c510-1e33-485c-a196-074afc06f502',
#    'name': 'F2 Testing',
#    'mentionName': 'f2'},
#   {'uid': '0xe83af', 'xid': 'a54dae05-0b2b-4cd4-85a2-8ca850c40ac8'},
#   {'uid': '0xe83ee',
#    'xid': 'f5d6ab10-b437-4726-bc6e-fcfd7f7a6450',
#    '~authoredBy': [{'hasKeywords': [{'values': ['Chime team',
#         'guys need help']}]}]},
#   {'uid': '0xe84ea',
#    'xid': '84730217-6fee-4313-b162-160a4f423be7',
#    '~authoredBy': [{'hasKeywords': [{'values': ['break free']}]}]},
#   {'uid': '0xe84ec',
#    'xid': '7fe0f368-3801-4c8e-9504-03015136dc1b',
#    '~authoredBy': [{'hasKeywords': [{'values': ['Bull Carlson',
#         'lake for Bull Carlson staging']}]}]},
#   {'uid': '0xe8540',
#    'xid': 'ee000202-bad4-48dc-8948-b2e345d558a9',
#    '~authoredBy': [{'hasKeywords': [{'values': ['Gibbs Concert Spacy share transcription',
#         'time I reach',
#         'Concert Spacy']}]}]},
#   {'uid': '0xe8548',
#    'xid': '7f6cf8ff-eb33-4b31-95f7-81d8646fd883',
#    '~authoredBy': [{'hasKeywords': [{'values': ['Billy Natural']}]}]},
#   {'uid': '0xe85cb',
#    'xid': 'e1d3bac8-9490-4b93-a48d-dbf918456dad',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth'},
#   {'uid': '0xe85cd',
#    'xid': '867a0bd0-d24a-4833-bd93-5ff66784cc45',
#    'name': 'Bast Cat',
#    'mentionName': 'ether.bast.cat'},
#   {'uid': '0xe85ce',
#    'xid': '93e81898-a5e7-4a22-95d5-6610b245970e',
#    'name': 'E Man',
#    'mentionName': 'labs.etherman'},
#   {'uid': '0xe85cf',
#    'xid': '27b02a03-11de-451b-8986-d329fdbd3269',
#    'name': 'Luke T800',
#    'mentionName': 'luke.test800',
#    '~hasMember': [{'name': 'dragonball-z'}]},
#   {'uid': '0xe85d0',
#    'xid': '7b3840d4-122f-47da-b2e2-6fb0e565186d',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth',
#    '~hasMember': [{'name': 'New-WS2'}]},
#   {'uid': '0xea693',
#    'xid': '25f4a8bf-6e75-46b5-b42c-b4be8808b217',
#    'name': 'Nisha Yadav',
#    'mentionName': 'nisha',
#    '~authoredBy': [{'hasKeywords': [{'values': ['algorithms is people',
#         'Time',
#         'work in agriculture',
#         'friends have jobs',
#         'work in manufacturing',
#         'add a little bit',
#         'build a house',
#         'work in entertainment',
#         'genius to read',
#         'French player',
#         'play baseball',
#         'skills today',
#         'Time coding',
#         'school group',
#         'Green Circle',
#         'master this discipline',
#         'tick gecko',
#         'limit of the system',
#         'good start',
#         'Peter Science',
#         'best people',
#         'program I wrote asked',
#         'hire as many talented engineers',
#         'multiplication tables',
#         'race car driver',
#         'favorite color',
#         'The Whiz Kids']}]}]},
#   {'uid': '0xea7cb',
#    'xid': '123bd4d1-45fd-4afe-83c1-13529a9c8e5b',
#    '~authoredBy': [{'hasKeywords': [{'values': ['early hardships',
#         'University',
#         'Cuckoo',
#         'washing machine',
#         'rough neighborhood',
#         'Benicia',
#         'single mother',
#         'read profiles',
#         'Silver Spoon',
#         'A Beautiful Mind']}]},
#     {'hasKeywords': [{'values': ['Human Resources Director refer',
#         'Person B State School',
#         'the Right Stuff',
#         'Flawless resume great recommendations',
#         'Human Resources',
#         'indicate inconsistency lack',
#         'the Silver Spoon',
#         'State School fair amount',
#         'Human Resources certification',
#         'Flawless']}]},
#     {'hasKeywords': [{'values': ['organizational culture',
#         'cost effective nature',
#         'performance data',
#         'applicants disadvantages',
#         'current position',
#         'internal methods advantages include',
#         'advancement opportunities motivate current employees']}]}]},
#   {'uid': '0xea972',
#    'xid': 'ead1d4d7-56a0-4584-8c31-7aa2d41bed49',
#    'name': 'vani',
#    'mentionName': 'vani',
#    '~authoredBy': [{'hasKeywords': [{'values': ['optimizing manner',
#         'case I done fifty films',
#         'medical human innovation',
#         'metropolis of Monday',
#         'progress and go ideas',
#         'late twenty',
#         'Monday and my framework',
#         'France some thank',
#         'money lenders definitions',
#         'source of this collective',
#         'human need to progress',
#         'side streams not human beings',
#         'feel less reliable',
#         'half seconds',
#         'time I was forty',
#         'races beginner',
#         'diversity city',
#         'mankind and the human',
#         'fluid work',
#         'highest by the French government',
#         'members that count']}]}]},
#   {'uid': '0xeac77',
#    'xid': '53e0f795-1b3f-4bb3-8e53-f353a6d1c56d',
#    '~authoredBy': [{'hasKeywords': [{'values': ['Marxists and Redis']}]}]},
#   {'uid': '0xeac84',
#    'xid': 'fa06d7a2-d4cb-4815-b4ee-ab78f2dbc7be',
#    '~authoredBy': [{'hasKeywords': [{'values': ['Waas This works',
#         'prod at a zoo',
#         'staging to prod']}]},
#     {'hasKeywords': [{'values': ['Deepgram']}]},
#     {'hasKeywords': [{'values': ['Jitsi', 'great applause', 'Dear Jack']}]}]},
#   {'uid': '0xead0d',
#    'xid': '5f08863a-6326-4305-a9ca-ec15fa79ca71',
#    'name': 'ether_staging2',
#    'mentionName': 'ether_staging2'},
#   {'uid': '0xead0e',
#    'xid': 'e552c6b4-fda5-4a5b-a61f-c19f8fe6e95c',
#    'name': 'ether_staging2',
#    'mentionName': 'ether_staging2',
#    '~hasMember': [{'name': 'Friday-Mrng'}]},
#   {'uid': '0xead11',
#    'xid': '1f5ca952-d806-4538-b3d2-aafec9c141d9',
#    'name': 'F3 Test',
#    'mentionName': 'f3',
#    '~hasMember': [{'name': 'F3-27june'}]},
#   {'uid': '0xead12',
#    'xid': '9cee68cb-4b23-456e-9851-b22afcc93595',
#    'name': 'Mithun',
#    'mentionName': 'mithun',
#    '~hasMember': [{'name': 'test-uninstall'}]},
#   {'uid': '0xead1d',
#    'xid': '9df3185d-bfe2-43c5-b072-6691639619bb',
#    'name': 'Karthik Muralidharan',
#    'mentionName': 'karthik'},
#   {'uid': '0xead1f',
#    'xid': 'ce290eb7-b664-41b0-b62a-602cc2236e26',
#    'name': '',
#    'mentionName': 'donut'},
#   {'uid': '0xead22',
#    'xid': '4e9d1f5a-ad39-498f-a29f-a9d97c43d2cf',
#    'name': 'Akshay Oppiliappan',
#    'mentionName': 'akshay'},
#   {'uid': '0xead26',
#    'xid': 'f4d8fa86-d4ad-4d7c-a731-fb6344b02e0b',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth'},
#   {'uid': '0xead27',
#    'xid': '44c9ee68-cf0a-4dc0-adc4-f6489b508a9a',
#    'name': 'E Man',
#    'mentionName': 'labs.etherman'},
#   {'uid': '0xecd11',
#    'xid': '79d3a574-9121-4f5f-9e45-8dc50d87c592',
#    'name': 'Vamshi Krishna',
#    'mentionName': 'vamshi'},
#   {'uid': '0xece93', 'xid': 'ed47040f-2de0-4806-a650-4adc06fe5bf9'},
#   {'uid': '0xed35a', 'xid': 'b6c9b2b2-ca00-46f2-939b-5ea6f0b81f70'},
#   {'uid': '0xed3a9',
#    'xid': '8bea6ead-da8c-40e9-8fc6-0970747cbb93',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth',
#    '~hasMember': [{'name': 'AdminDemo4'}]},
#   {'uid': '0xed3be',
#    'xid': '1f652afd-9a68-4e58-a762-449e82d115c3',
#    'name': 'Kartik Ramachandran',
#    'mentionName': 'kartikr29'},
#   {'uid': '0xef731',
#    'xid': '88e54601-33d0-4b41-ad9b-79e5a7edb957',
#    'name': 'F1 Testing',
#    'mentionName': 'f1',
#    '~hasMember': [{'name': 'Frank-Test-8Aug'}],
#    '~authoredBy': [{'hasKeywords': [{'values': ['AwS W Sub',
#         'integrate step',
#         'AwS W Sub functions']}]}]},
#   {'uid': '0xef8d7',
#    'xid': 'bb32caab-d788-491c-8ef2-8ff6055688c7',
#    '~authoredBy': [{'hasKeywords': [{'values': ['independent Chime',
#         'establish that connection',
#         'Yuri',
#         'meeting Yuri',
#         'start when the meeting Yuri',
#         'Chime']}]},
#     {'hasKeywords': [{'values': ['ether Lon']}]},
#     {'hasKeywords': [{'values': ['Menin',
#         'composition Docker',
#         'Docker',
#         'embrace store',
#         'tea Insufficient',
#         'catch kernel domestic joining Menin']}]}]},
#   {'uid': '0xefadf',
#    'xid': 'e95efb1c-40aa-4e1c-b342-639dd74dd1cc',
#    'name': 'Nisha Yadav',
#    'mentionName': 'nisha'},
#   {'uid': '0xefae0',
#    'xid': '914b5bcf-b68b-4677-b4cb-e9f381ec8165',
#    'name': 'Ether Man Labs',
#    'mentionName': 'labs.etherman',
#    '~hasMember': [{'name': 'Etherman-labs'}]},
#   {'uid': '0xefae4',
#    'xid': '4d0c31ba-20eb-49b7-a1a9-8a367a55a344',
#    'name': 'etherstaging',
#    'mentionName': 'ether_staging'},
#   {'uid': '0xefae8',
#    'xid': 'e5e6a517-e54c-4594-bb92-d9716f1d77db',
#    'name': 'Luke T800',
#    'mentionName': 'luke.test800'},
#   {'uid': '0xf1de5',
#    'xid': '43d355dd-2584-4918-8635-c539eff0e7df',
#    'name': 'F3 Testing',
#    'mentionName': 'f3'},
#   {'uid': '0xf2136', 'xid': '6fdd69f8-3a7c-46c4-af18-fa15502f6ac5'},
#   {'uid': '0xf21a7',
#    'xid': '6deb5e0c-2b99-45e9-9b4a-726e8a7f7b03',
#    'name': 'test 1',
#    'mentionName': 'test.etherlabs1',
#    '~hasMember': [{'name': 'Channel-membership'}]},
#   {'uid': '0xf21ab',
#    'xid': 'fb85fe10-1d83-4160-b239-201ac7a81713',
#    'name': 'Tom T-1000',
#    'mentionName': 'tom.1000test',
#    '~hasMember': [{'name': 'Powerpuff-girls'}]},
#   {'uid': '0xf21b1',
#    'xid': 'c620c347-baa7-4e69-8323-3557b75d47e2',
#    'name': 'Vonage',
#    'mentionName': 'vonage'},
#   {'uid': '0xf21b5',
#    'xid': '3c20a89d-fc83-406b-a4d6-1a1f6ba8c76e',
#    'name': 'Bast Cat',
#    'mentionName': 'ether.bast.cat'},
#   {'uid': '0xf21bb',
#    'xid': '5709e507-72fc-4c66-b257-3b14ff2250f5',
#    'name': 'Trishanth',
#    'mentionName': 'trishanth'},
#   {'uid': '0xf21bf',
#    'xid': '03db99c4-8106-4509-9c78-ccece3395dcc',
#    'name': 'EtherMeet',
#    'mentionName': 'ether'}]}

# %%
ref_user_kw_dict, ref_user_id_dict = format_response(resp=ref_user_kw_resp)

# %%
len(ref_user_id_dict.keys())
# Out:
# 179

# %%
len(ref_user_kw_dict)
# Out:
# 23

# %% [markdown]
# ## Remove users (if any) that are being compared against

# %%
for k in ref_user_id_dict.keys():
    if k in user_kw_dict.keys():
        del ref_user_kw_dict[k]

# %%
len(ref_user_kw_dict)
# Out:
# 21

# %%
aws_config = Config(
        connect_timeout=180,
        read_timeout=300,
        retries={"max_attempts": 2},
        region_name="us-east-1",
    )
lambda_client = bclient("lambda", config=aws_config)
lambda_function = "sentence-encoder-lambda"

def get_embeddings(input_list):
    lambda_payload = {"body": {"text_input": input_list}}

    try:
        invoke_response = lambda_client.invoke(
            FunctionName=lambda_function,
            InvocationType="RequestResponse",
            Payload=js.dumps(lambda_payload),
        )

        lambda_output = (
            invoke_response["Payload"].read().decode("utf8").replace("'", '"')
        )
        response = js.loads(lambda_output)
        status_code = response["statusCode"]
        response_body = response["body"]

        if status_code == 200:
            embedding_vector = np.asarray(js.loads(response_body)["embeddings"])

        else:
            embedding_vector = np.asarray(js.loads(response_body)["embeddings"])

        return embedding_vector

    except Exception as e:
        print(e)
        embedding_vector = np.zeros((1, 512))
        return embedding_vector

# %%
vec1 = get_embeddings(input_list=["AWS lambda function"])
vec2 = get_embeddings(input_list=["AWS serverless computing"])

# %%
sim = 1 - cosine(vec1, vec2)

# %%
sim
# Out:
# 0.7383127021592407

# %%
def hash_func(vecs, projections):
    bools = np.dot(vecs, projections.T) > 0
    return [bool2int(bool_vec) for bool_vec in bools]

def bool2int(x):
    y = 0
    for i,j in enumerate(x):
        if j: y += 1<<i
    return y

# %%
class Table:
    
    def __init__(self, hash_size, dim):
        self.table = dict()
        self.hash_size = hash_size
        self.projections = np.random.randn(self.hash_size, dim)

    def add(self, vecs, label):
        entry = {'label': label}
        hashes = hash_func(vecs, self.projections)
        for h in hashes:
            if h in self.table.keys():
                self.table[h].append(entry)
            else:
                self.table[h] = [entry]

    def query(self, vecs):
        hashes = hash_func(vecs, self.projections)
        results = list()
        for h in hashes:
            if h in self.table.keys():
                results.extend(self.table[h])
        return results

class LSH:
    
    def __init__(self, dim):
        self.num_tables = 4
        self.hash_size = 8
        self.tables = list()
        for i in range(self.num_tables):
            self.tables.append(Table(self.hash_size, dim))
    
    def add(self, vecs, label):
        for table in self.tables:
            table.add(vecs, label)
    
    def query(self, vecs):
        results = list()
        for table in self.tables:
            results.extend(table.query(vecs))
        return results

    def describe(self):
        for table in self.tables:
            # print(table.table, table.projections)
            yield(table)
    

class Search:
    
    def __init__(self, input_list):
        self.dim_size = 512
        self.lsh = LSH(self.dim_size)
        self.input = input_list
        self.num_features_in_input = dict()
        for f in self.input:
            self.num_features_in_input[f] = 0
                
    def featurize(self):
        # for kw_list in self.input:
        kw_features = get_embeddings(input_list=self.input)
        
        for i in range(len(kw_features)):
            self.lsh.add([kw_features[i]], self.input[i])
            self.num_features_in_input[self.input[i]] += len(kw_features[i])
                
    def query(self, kw_list):
        # kw_list = user_dict[user]
        kw_features = get_embeddings(input_list=kw_list)
        
        results = self.lsh.query(kw_features)
        print('num results', len(results))

        counts = dict()
        for r in results:
            if r['label'] in counts.keys():
                counts[r['label']] += 1
            else:
                counts[r['label']] = 1
        for k in counts:
            counts[k] = float(counts[k])/self.num_features_in_input[k]
        return counts
    
    def describe(self):
        for t in self.lsh.describe():
            yield(t)

# %%
ref_kws = [v for val in ref_user_kw_dict.values() for v in val]

# %%
ref_kws[:60]
# Out:
# ['Keys',
#  'nothingto Those people',
#  'Theo',
#  'Over',
#  'marks Jira',
#  'civil rights Isis',
#  'open project',
#  'climate changes',
#  'climate nats',
#  'lot of salt',
#  'smooth change',
#  'wait Meetings',
#  'speak aloud',
#  'feel ability',
#  'Redis',
#  'Isis',
#  'ability to speak aloud',
#  'process refund',
#  'process purchase',
#  'basic role',
#  'great function',
#  'leave a default option create role',
#  'create our two lambda channel',
#  'AWS Console',
#  'basic lambda',
#  'Lambda dot',
#  'guys called the process',
#  'insert events',
#  'lambda arguments',
#  'add some more criteria',
#  'combinations of criterias',
#  'change events',
#  'players scores',
#  'lot is data replication',
#  'record as the argument',
#  'guy to this',
#  'table at real time',
#  'player ID play',
#  'replicate dot',
#  'bit more searchable',
#  'leaderboards a tree',
#  'insert on the table',
#  'batch of changes',
#  'elastic search cluster',
#  'games played greater',
#  'time it event',
#  'reading off this table',
#  'lambda to your dot audio',
#  'faster and more efficient operation',
#  'game events',
#  'reading off your table',
#  'insert event',
#  'stands are gon',
#  'increment the total score',
#  'operation in your leader table',
#  'game events table',
#  'number of games played greater',
#  'batch operation',
#  'users can access this web service API',
#  'quick access']

# %%
ws = Search(input_list=ref_kws[:60])

# %%
ws.num_features_in_input
# Out:
# {'Keys': 0,
#  'nothingto Those people': 0,
#  'Theo': 0,
#  'Over': 0,
#  'marks Jira': 0,
#  'civil rights Isis': 0,
#  'open project': 0,
#  'climate changes': 0,
#  'climate nats': 0,
#  'lot of salt': 0,
#  'smooth change': 0,
#  'wait Meetings': 0,
#  'speak aloud': 0,
#  'feel ability': 0,
#  'Redis': 0,
#  'Isis': 0,
#  'ability to speak aloud': 0,
#  'process refund': 0,
#  'process purchase': 0,
#  'basic role': 0,
#  'great function': 0,
#  'leave a default option create role': 0,
#  'create our two lambda channel': 0,
#  'AWS Console': 0,
#  'basic lambda': 0,
#  'Lambda dot': 0,
#  'guys called the process': 0,
#  'insert events': 0,
#  'lambda arguments': 0,
#  'add some more criteria': 0,
#  'combinations of criterias': 0,
#  'change events': 0,
#  'players scores': 0,
#  'lot is data replication': 0,
#  'record as the argument': 0,
#  'guy to this': 0,
#  'table at real time': 0,
#  'player ID play': 0,
#  'replicate dot': 0,
#  'bit more searchable': 0,
#  'leaderboards a tree': 0,
#  'insert on the table': 0,
#  'batch of changes': 0,
#  'elastic search cluster': 0,
#  'games played greater': 0,
#  'time it event': 0,
#  'reading off this table': 0,
#  'lambda to your dot audio': 0,
#  'faster and more efficient operation': 0,
#  'game events': 0,
#  'reading off your table': 0,
#  'insert event': 0,
#  'stands are gon': 0,
#  'increment the total score': 0,
#  'operation in your leader table': 0,
#  'game events table': 0,
#  'number of games played greater': 0,
#  'batch operation': 0,
#  'users can access this web service API': 0,
#  'quick access': 0,
#  'efficient operation': 0,
#  'large number': 0,
#  'year where your game events table': 0,
#  'number of players playing a large': 0,
#  'total score': 0,
#  'inputs your lab': 0,
#  'data over time': 0,
#  'add an elastic search cluster': 0,
#  'Cron job kind': 0,
#  'elastic search': 0,
#  'data store': 0,
#  'reasonable approach chapter': 0,
#  'data replication': 0,
#  'lab in the middle': 0,
#  'perform the corresponding operation': 0,
#  'replicate this data': 0,
#  'day you decide': 0,
#  'lambda that they catch info': 0,
#  'leader shape': 0,
#  'pretty large': 0,
#  'contents of this record': 0,
#  'elasticsearch Buster': 0,
#  'web server': 0,
#  'reading off this elasticsearch Buster': 0,
#  'read over much higher amounts': 0,
#  'country and search by': 0,
#  'time an insertion': 0,
#  'hook up a lambda': 0,
#  'web service API': 0,
#  'increment at this point': 0,
#  'primary key increment': 0,
#  'Check this database': 0,
#  'supports natively range and top sorting type queries': 0,
#  'batch processing': 0,
#  'red circles': 0,
#  'concept of a stream': 0,
#  'dot to be table': 0,
#  'performance impact': 0,
#  'user have no control': 0,
#  'containers for record events change': 0,
#  'shards are kind': 0,
#  'kind of interesting': 0,
#  'settle this option start': 0,
#  'future video': 0,
#  'level streams': 0,
#  'super easy': 0,
#  'independent of dot': 0,
#  'stream with I kind figure': 0,
#  'pick which type': 0,
#  'number of shards as user': 0,
#  'streams consists': 0,
#  'figure would change': 0,
#  'vehicles or containers': 0,
#  'diagonal DB original table': 0,
#  'source table': 0,
#  'siri with the secrets number': 0,
#  'overheard you saying backstage': 0,
#  'knowledge of every painting': 0,
#  'Renaissance man': 0,
#  'Renaissance': 0,
#  'art historians': 0,
#  'Jitsi': 0,
#  'year sticky owner transition': 0,
#  'glass Jitsi': 0,
#  'Ronnie Jira': 0,
#  'k. Abbasi': 0,
#  'airline Donna': 0,
#  'Donna': 0,
#  'Divko a padding bottom dare': 0,
#  'respect of the governor Innings Tom': 0,
#  'stuff it meeting and daughter never skate': 0,
#  'total command car': 0,
#  'recording in total command car': 0,
#  'reliable solution': 0,
#  'good problem': 0,
#  'Alexei': 0,
#  'Publishers': 0,
#  'gamma flick Allegra': 0,
#  'summary Publishers': 0,
#  'governor Innings Tom': 0,
#  'careful in case': 0,
#  'Innings Tom': 0,
#  'government a record from Connecticut': 0,
#  'main function': 0,
#  'call that level if functional object': 0,
#  'number me man fine': 0,
#  'long time': 0,
#  'consequences for the behavior': 0,
#  'sequence of three local transactions': 0,
#  'set of shorter transactions': 0,
#  'concept to the saga': 0,
#  'long running transactions': 0,
#  'distributed transaction': 0,
#  'transaction and model': 0,
#  'saga mechanism': 0,
#  'watch in the case': 0,
#  'transactions that span multiple services': 0,
#  'big idea': 0,
#  'behavior of the system': 0,
#  'Cooper': 0,
#  'John': 0,
#  'Google': 0,
#  'default rule': 0,
#  'default policy': 0,
#  'touched here and leave': 0,
#  'stuff functions perspective': 0,
#  'error and in order': 0,
#  'create role': 0,
#  'Land Rover': 0,
#  'Lambda': 0,
#  'reminder by default': 0,
#  'default and click': 0,
#  'click on create': 0,
#  'step function': 0,
#  'Gonna Roll': 0,
#  'create our state machine': 0,
#  'Lambda function': 0,
#  'rolls click': 0,
#  'state machine': 0,
#  'Aaron': 0,
#  'click next not gon': 0,
#  'lung functions': 0,
#  'target of which Lambda function': 0,
#  'production type': 0,
#  'stuff is then incident': 0,
#  'good visual queue': 0,
#  'real time': 0,
#  'container is purchase': 0,
#  'hear introduction': 0,
#  'output from the lambda function': 0,
#  'stand on real quick': 0,
#  'transaction type': 0,
#  'instance where the credit action': 0,
#  'position lambda': 0,
#  'decision of living': 0,
#  'process for production': 0,
#  'city for your training figure': 0,
#  'link teach': 0,
#  'process purpose': 0,
#  'business that I kind prepared': 0,
#  'cycle function option': 0,
#  'set up the time': 0,
#  'Token': 0,
#  'Coke': 0,
#  'process or the exact': 0,
#  'return the object': 0,
#  'Lambda of function': 0,
#  'purchase so the processing': 0,
#  'code and base': 0,
#  'reminder from the overview slide': 0,
#  'create a role': 0,
#  'Windham wins inside': 0,
#  'click the log': 0,
#  'saved message': 0,
#  'example for this administration': 0,
#  'southwark Universal chair': 0,
#  'message and action site': 0,
#  'change the headline': 0,
#  'year month': 0,
#  'process purchase function message': 0,
#  'stuff functions': 0,
#  'fine by default': 0,
#  'time to this': 0,
#  'Spirit': 0,
#  'Property Brother': 0,
#  'create a function': 0,
#  'intents of purposes': 0,
#  'purposes is based position': 0,
#  'search changes': 0,
#  'image steps': 0,
#  'Second it looks good': 0,
#  'create functions': 0,
#  'Coke or after handle': 0,
#  'versus is gon': 0,
#  'response and Spirit': 0,
#  'process purchase motion': 0,
#  'family function': 0,
#  'instance where a credit card transaction': 0,
#  'cutesy little message': 0,
#  'life cycle': 0,
#  'opal from the Lambda function': 0,
#  'input and the output': 0,
#  'blue corresponds': 0,
#  'process production': 0,
#  'path and stuff': 0,
#  'event type': 0,
#  'figure out for instance': 0,
#  'visual cue Mister': 0,
#  'perfect output': 0,
#  'comment section': 0,
#  'group stuff functions': 0,
#  'production site': 0,
#  'time stamp': 0,
#  'trouble sir': 0,
#  'click on start execution': 0,
#  'confidence you look convert tools message': 0,
#  'function for the faltering': 0,
#  'click on output': 0,
#  'real quick': 0,
#  'match this video': 0,
#  'custom message': 0,
#  'video role': 0,
#  'test a factory': 0,
#  'time to take holes': 0,
#  'suffering of this idea': 0,
#  'hold the grounds': 0,
#  'boom backend': 0,
#  'dig some holes': 0,
#  'Wikipedia Page says Business magnate': 0,
#  'time ideas': 0,
#  'manage your time': 0,
#  'time you must spend': 0,
#  'manufacturing and that kind': 0,
#  'business guy': 0,
#  'Space X': 0,
#  'variable time boom': 0,
#  'unlock it and change': 0,
#  'change my get impatient magnet': 0,
#  'help funnel traffic': 0,
#  'implementation of those ideas': 0,
#  'industry forthis': 0,
#  'Hierarchical Network Relational': 0,
#  'databases use different transactions': 0,
#  'SQL as the standard query language': 0,
#  'transactions and even proprietary': 0,
#  'database approach': 0,
#  'stage that in table format': 0,
#  'SQL oracle': 0,
#  'insert search': 0,
#  'delete big database records': 0,
#  'historic data': 0,
#  'maintenance databases': 0,
#  'traditional flat file': 0,
#  'major types': 0,
#  'Texas an example': 0,
#  'query database': 0,
#  'statement select start': 0,
#  'sQL Sai etcetera': 0,
#  'benefits that some databases': 0,
#  'transfer database management system': 0,
#  'relational databases SQl': 0,
#  'SQL percent': 0,
#  'ton of surfaces': 0,
#  'Herbert': 0,
#  'market penetration': 0,
#  'printed telephone directories': 0,
#  'multiple retailers': 0,
#  'Tour Nautical': 0,
#  'advertisers and people': 0,
#  'affect our social psychology': 0,
#  'target by the hires': 0,
#  'Tour Nautical async satisfaction': 0,
#  'iWork exertions': 0,
#  'HR talent management bottle': 0,
#  'large portion': 0,
#  'Loren Hirings': 0,
#  'backward building': 0,
#  'add new columns or buy': 0,
#  'Database confer form complex aggregate calculations': 0,
#  'list expenses': 0,
#  'specific importing profile': 0,
#  'traditional bound consumers continue': 0,
#  'employee satisfaction': 0,
#  'way you communicate': 0,
#  'great success': 0,
#  'smart hires': 0,
#  'opposite is true': 0,
#  'address both sides': 0,
#  'Satisfied employees': 0,
#  'match the specific activities': 0,
#  'great place': 0,
#  'reach fewer consumers': 0,
#  'common questions': 0,
#  'predictor of performance': 0,
#  'Satya': 0,
#  'swarm of print and online lucky search engine marketing utilizes': 0,
#  'avoid duplication': 0,
#  'billboards all fall': 0,
#  'social media manager': 0,
#  'type of data like energy or string': 0,
#  'link farming in constant market': 0,
#  'brand they admire': 0,
#  'daily satisfaction occurrence': 0,
#  'feel connected': 0,
#  'strong leadership': 0,
#  'active left': 0,
#  'visibility translates into higher traffic': 0,
#  'personal computer': 0,
#  'desirable employer': 0,
#  'Brands are not people': 0,
#  'unpaid mechanisms': 0,
#  "Technical university's": 0,
#  'content optimization': 0,
#  'demographic groups': 0,
#  'enforce consistently debate integrity': 0,
#  'hiring from the top Technical university': 0,
#  'younger people tend': 0,
#  'better spent on hiring': 0,
#  'category of print media': 0,
#  'sides of the equation': 0,
#  'millions for more records': 0,
#  'Require': 0,
#  'critical backlash': 0,
#  'attract people': 0,
#  'ebb and flow with higher': 0,
#  'Turn then its final total database': 0,
#  'fair amount': 0,
#  'reach certain market segments': 0,
#  'Satya observing the capitalism': 0,
#  'Resource': 0,
#  'Require substantial investment': 0,
#  'trend is for printed papers': 0,
#  'result of book material factors': 0,
#  'kinds of backgrounds': 0,
#  'content online': 0,
#  'nats thinkers': 0,
#  'broke even millions': 0,
#  'strange as the lines': 0,
#  'cross reference records': 0,
#  'retain key': 0,
#  'Internets': 0,
#  'tough critique': 0,
#  'bunch of ways': 0,
#  'guardrails and brand building blocks': 0,
#  'stay calm': 0,
#  'opinion on the subject': 0,
#  'top employer': 0,
#  'factor influencing overall satisfaction': 0,
#  'engagement recognition': 0,
#  'helpful in this case': 0,
#  'turn areas continue': 0,
#  'train stun': 0,
#  'enhanced driven': 0,
#  'multiple tables': 0,
#  'remain included': 0,
#  'human since our agency': 0,
#  'employee engagement': 0,
#  'compensation and benefits': 0,
#  'sort is the databases relational': 0,
#  'mechanisms may include as Theo techniques': 0,
#  'engineers your time is better': 0,
#  'multiple areas': 0,
#  'tangible elements': 0,
#  'distortions through critique and Satya': 0,
#  'stun totals': 0,
#  'groups of consumers': 0,
#  'receive their daily updates printed hard copy format': 0,
#  'Commerce site': 0,
#  'complacent team': 0,
#  'telephone books': 0,
#  'logger engagements': 0,
#  'edgy or just affair': 0,
#  'relationship between the database': 0,
#  'create relationships': 0,
#  'Waist highlights capitalism': 0,
#  'staging basis': 0,
#  'financial engineering': 0,
#  'Solana promise': 0,
#  'Department basis': 0,
#  'number one apples trading': 0,
#  'better job': 0,
#  'grow whatever conclusion': 0,
#  'work plans': 0,
#  'amount of original resource': 0,
#  'follow what they meant': 0,
#  'clear Target': 0,
#  'market strategy': 0,
#  'communications strategy': 0,
#  'apples trading': 0,
#  'future product roadmap': 0,
#  'logistics distribution strategies': 0,
#  'call from board': 0,
#  'today the future': 0,
#  'cases When the Music Stops': 0,
#  'bottom line will follow': 0,
#  'accomplish that the pieces': 0,
#  'corporate massive layoffs': 0,
#  'valuable lesson': 0,
#  'equal or greater': 0,
#  'twenty days': 0,
#  'pet sitter': 0,
#  'original resource': 0,
#  'culture with your company': 0,
#  'trouble that apple': 0,
#  'top line the bottom': 0,
#  'forget their financials': 0,
#  'apples competitors': 0,
#  'evident for another quarter': 0,
#  'clear Direction': 0,
#  'create such good people': 0,
#  'good people': 0,
#  'talented people': 0,
#  'place since that event': 0,
#  'expect Microsoft': 0,
#  'matter of fact Macintosh': 0,
#  'board member support set': 0,
#  'crazy that these companies': 0,
#  'fact Macintosh': 0,
#  'hostile relationship': 0,
#  'platform that brought Microsoft': 0,
#  'independent very talented people': 0,
#  'track again apple and Microsoft': 0,
#  'crony friends': 0,
#  'good for the customer': 0,
#  'desktop computer market': 0,
#  'support that a thousand percent': 0,
#  'Bill and Steve': 0,
#  'applications business': 0,
#  'dollar per year': 0,
#  'happen overnight': 0,
#  'key Channel partners': 0,
#  'company with Steve Wozniak': 0,
#  'people except my promise': 0,
#  'changes in the channel': 0,
#  'family time': 0,
#  'people need these symbols': 0,
#  'personal financial stuff': 0,
#  'big recommitment': 0,
#  'lot of people': 0,
#  'major Channel partners': 0,
#  'mind reader': 0,
#  'parking lot': 0,
#  'discuss that with people': 0,
#  'buying experience': 0,
#  'Apple turn': 0,
#  'retail experience': 0,
#  'late and on weekends': 0,
#  'clean up this retail experience': 0,
#  'definite place': 0,
#  'Apple and microsoft': 0,
#  'work with the best people': 0,
#  'platform that brought microsoft': 0,
#  'strong board': 0,
#  'percent of the desktop computer': 0,
#  'permanent fairly far organizations': 0,
#  'bill that as': 0,
#  'candidate they want lure': 0,
#  'great deal': 0,
#  'great person ready': 0,
#  'Chrysler and IBM': 0,
#  'board and several videos great': 0,
#  'IBM during this turn': 0,
#  'board you guys': 0,
#  'strong boy': 0,
#  'group of people': 0,
#  'Topic very high quality': 0,
#  'Bill Campbell CEO': 0,
#  'matter of fact macintosh': 0,
#  'companies back on track': 0,
#  'high quality': 0,
#  'talented group': 0,
#  'grow so I guess': 0,
#  'close the deal': 0,
#  'people that have better': 0,
#  'country of midgets': 0,
#  'expect microsoft': 0,
#  'videos great': 0,
#  'find hopefully people': 0,
#  'second largest software company': 0,
#  'hospital relationship': 0,
#  'people on this board': 0,
#  'independent very talented': 0,
#  'lot of CEOs and Larry Ellison': 0,
#  'work with people': 0,
#  'strong people': 0,
#  'find got a great deal': 0,
#  'lot of build usage sign work': 0,
#  'short period': 0,
#  'largest consumer software companies': 0,
#  'board number': 0,
#  'CEO you find': 0,
#  'strong War': 0,
#  'lot of stuff': 0,
#  'best people': 0,
#  'great people': 0,
#  'lot of microsoft': 0,
#  'good want to work': 0,
#  'good and about seventy percent': 0,
#  'remain and add': 0,
#  'start something process': 0,
#  'third tons': 0,
#  'clear target': 0,
#  'future product road': 0,
#  'mile you get attach': 0,
#  'clear direction': 0,
#  'number one apple trading': 0,
#  'attach use the car': 0,
#  'people that dot the share': 0,
#  'times their sales': 0,
#  'good promise': 0,
#  'density in one part': 0,
#  'properties in different parts': 0,
#  'data have different properties': 0,
#  'space for example': 0,
#  'third example': 0,
#  'part of the space': 0,
#  'Janet': 0,
#  'great world culture': 0,
#  'organization can enhance every investment': 0,
#  'change the best employees': 0,
#  'stick in an organization': 0,
#  'Contrary to popular belief': 0,
#  'employees empowering world couple': 0,
#  'architectural wonders': 0,
#  'Housekeeping team': 0,
#  'Kelvin': 0,
#  'organized place': 0,
#  'Create a system': 0,
#  'find it difficult to complete tests': 0,
#  'industry culture': 0,
#  'feel more valuable': 0,
#  'example of a firm': 0,
#  'feeling and energy': 0,
#  'place on the people': 0,
#  'sense of acceptance': 0,
#  'team culture': 0,
#  'feel you belong': 0,
#  'culture of the place': 0,
#  'people feel': 0,
#  'boost your self esteem': 0,
#  'greatest advantage': 0,
#  'profile or responsibilities': 0,
#  'Culture is the meeting': 0,
#  'firm using different people skills': 0,
#  'food or civic duty': 0,
#  'work for a surgeon firm': 0,
#  'attract more talent': 0,
#  'Kelvin and safety': 0,
#  'practice or ritual pretty fun': 0,
#  'order to understand it better': 0,
#  'term new linguistic programming': 0,
#  'nervous system': 0,
#  'perspective on what energy': 0,
#  'unwrap the three components': 0,
#  'emotional workings': 0,
#  'practical psychology': 0,
#  'people call': 0,
#  'study of excellence': 0,
#  'grasp its real meaning': 0,
#  'Muto': 0,
#  'wider net': 0,
#  'mobility scaylr': 0,
#  'persuade candidates': 0,
#  'key differentiator': 0,
#  'local markets': 0,
#  'strong relocation package': 0,
#  'majority of companies surveyed Premier Li': 0,
#  'Premier Li': 0,
#  'benefits and other perks': 0,
#  'road having arteries': 0,
#  'cholesterol average drop': 0,
#  'duty fire': 0,
#  'average weight loss': 0,
#  'number one killer': 0,
#  'Uh God': 0,
#  'architecture as the senior person': 0,
#  'availability building too high estimate': 0,
#  'time any kind of knowledge work type projects': 0,
#  'Smith': 0,
#  'task as the meeting': 0,
#  'manager or less architecture': 0,
#  'provide for around people': 0,
#  'basket day': 0,
#  'prioritization crashing gate fifteen': 0,
#  'ambiguous some change requirements': 0,
#  'unique and ambiguous': 0,
#  'build me another house': 0,
#  'simple types powers': 0,
#  'project predict': 0,
#  'native costs': 0,
#  'good project': 0,
#  'Hours this book': 0,
#  'head and then ambiguous': 0,
#  'estimates been common sense software projects': 0,
#  'technology accuracy': 0,
#  'data for similar point': 0,
#  'nest a million hours story': 0,
#  'accurate your estimates': 0,
#  'point recently resource availability': 0,
#  'experts and base underestimate': 0,
#  'requirements are release from head': 0,
#  'easy process': 0,
#  'bit different or glitchy': 0,
#  'install the docker': 0,
#  'special cases': 0,
#  'PHP maskull package': 0,
#  'sheet of paper': 0,
#  'operating system': 0,
#  'Instagram or Facebook': 0,
#  'fine on my machine': 0,
#  'install onto your system': 0,
#  'Facebook': 0,
#  'classic debate': 0,
#  'core MySQL': 0,
#  'programming language': 0,
#  'challenging thing to install': 0,
#  'place to another': 0,
#  'social status': 0,
#  'boot camps': 0,
#  'net whenever you work': 0,
#  'bare minimum basic example': 0,
#  'Boehner': 0,
#  'debate is pretty nasty Docker': 0,
#  'Docker into three main essential': 0,
#  'machine the developer': 0,
#  'Django': 0,
#  'entire code': 0,
#  'absolute charm': 0,
#  'order to summarize': 0,
#  'problem statement': 0,
#  'solve as specific problem': 0,
#  'address this exact problem': 0,
#  'Windows Mac': 0,
#  'Martin': 0,
#  'MySQL': 0,
#  'containers are the absolute heart': 0,
#  'performance or save optimization': 0,
#  'machine first and foremost Docker': 0,
#  'containers onto a social platform': 0,
#  'divide this Docker': 0,
#  'classic problem': 0,
#  'Docker': 0,
#  'consist a lot': 0,
#  'learning MySQL installing': 0,
#  'production state': 0,
#  'Linux': 0,
#  'reduce the fiction': 0,
#  'project and move that': 0,
#  'super powerful': 0,
#  'Django pipe': 0,
#  'developer develops any product': 0,
#  'classic example': 0,
#  'JavaScript': 0,
#  'help of Docker': 0,
#  'team managers computer': 0,
#  'big scale projects': 0,
#  'machine the other guy': 0,
#  'order to understand the talk customer foremost': 0,
#  'place you like soccer': 0,
#  'illustrated stun': 0,
#  'higher level dictionary inside': 0,
#  'sweet specimen': 0,
#  'campus only for HTML': 0,
#  'style this campus': 0,
#  'canvas the screens': 0,
#  'detection information expressions': 0,
#  'current interest': 0,
#  'display size': 0,
#  'Electron working': 0,
#  'Department of the Media': 0,
#  'top of our video': 0,
#  'Electron': 0,
#  'HTML': 0,
#  'Nick': 0,
#  'current video': 0,
#  'draw protections': 0,
#  'happiest person': 0,
#  'Swift or baby Java': 0,
#  'Basics all clear': 0,
#  'Sunday we go live': 0,
#  'Java': 0,
#  'utilize that feature': 0,
#  'order to understand the docker': 0,
#  'Docker was absolutely Lifesaver': 0,
#  'docker first and foremost': 0,
#  'share one experience': 0,
#  'guys live': 0,
#  'exact timing': 0,
#  'live sessions': 0,
#  'video pretty simple': 0,
#  'Basics': 0,
#  'Sunday now follow': 0,
#  'Swift': 0,
#  'accomplish as well': 0,
#  'hey more people and': 0,
#  'talk about Docker': 0,
#  'life and follow up': 0,
#  'understand how apis': 0,
#  'solve a specific problem': 0,
#  'life because I hope': 0,
#  'lot of people love': 0,
#  'goal with that product': 0,
#  'people can join': 0,
#  'works as well': 0,
#  'Lifesaver': 0,
#  'JavaScript or PHP': 0,
#  'reduce the friction that users': 0,
#  'hope you can understand': 0,
#  'comments of comment': 0,
#  'timing of going life': 0,
#  'personal one where Docker': 0,
#  'Docker whenever a product': 0,
#  'object to take framework': 0,
#  'Io o dot': 0,
#  'type of application': 0,
#  'assume you happen': 0,
#  'Visual Basic': 0,
#  'time management techniques': 0,
#  'dotnet framework': 0,
#  'spent huge amount': 0,
#  'set of libraries': 0,
#  'Framework': 0,
#  'happen to have Visual Basic': 0,
#  'professional developer conference': 0,
#  'Windows': 0,
#  'point of time': 0,
#  'number of languages you pile': 0,
#  'computer system': 0,
#  'type of some time': 0,
#  'third code editor window': 0,
#  'help understand': 0,
#  'details about dot net framework': 0,
#  'require tradition code editors libraries': 0,
#  'time environment': 0,
#  'send code windows': 0,
#  'email very basic fundamental': 0,
#  'third run time environment': 0,
#  'deal with programming languages': 0,
#  'dot these two languages': 0,
#  'Bill Gates': 0,
#  'type of functionality': 0,
#  'Microsoft': 0,
#  'request to the server': 0,
#  'low origin header': 0,
#  'Michel Bavaro': 0,
#  'Sergeant Resource showing': 0,
#  'Sergeant Resource': 0,
#  'origin policy': 0,
#  'skip the same origin policy': 0,
#  'single page applications': 0,
#  'access the sources from remote serverless': 0,
#  'course and across Sergeant Resource showing': 0,
#  'handle common news cases': 0,
#  'Ajax': 0,
#  'custom headers': 0,
#  'course alos Ajax request': 0,
#  'remote serverless': 0,
#  'core support': 0,
#  'enable course': 0,
#  'provide some tips to handle common news cases': 0,
#  'majority coalition': 0,
#  'Young': 0,
#  'moderate rival': 0,
#  'president concluded that Netanyahu': 0,
#  'better chance': 0,
#  'Netanyahu': 0,
#  'Gantz': 0,
#  'unclear whether Gantz can create a government': 0,
#  'defeated net Young': 0,
#  'Netanyahu stood a better chance': 0,
#  'access control': 0,
#  'Hello Origin Header determines': 0,
#  'saga walk history': 0,
#  'invoke service': 0,
#  'send a command': 0,
#  'customer services': 0,
#  'message channels': 0,
#  'deliver that message': 0,
#  'read the replies': 0,
#  'services command channel': 0,
#  'bunch of issues around campaigns': 0,
#  'guys kinds': 0,
#  'guarantees with graphs': 0,
#  'saga protest participant': 0,
#  'business logic': 0,
#  'bit more complicated': 0,
#  'user are experience': 0,
#  'bit more synchronized': 0,
#  'architecture stuff': 0,
#  'mid lay': 0,
#  'course being a functional': 0,
#  'Minneapolis was a triple AI': 0,
#  'VMware': 0,
#  'sun sunshine': 0,
#  'original cloud boundary': 0,
#  'connect with the cloud boundaries': 0,
#  'list systems': 0,
#  'price job development': 0,
#  'subscription service': 0,
#  'spring and hibernate': 0,
#  'book photos': 0,
#  'microservice pattern': 0,
#  'finish the final chapter': 0,
#  'half off but Manning': 0,
#  'bunch of virtual machines': 0,
#  'training the best': 0,
#  'wait until tomorrow': 0,
#  'Java as for AWS': 0,
#  'AWS where you plan': 0,
#  'days teaching microservices class': 0,
#  'build an application': 0,
#  'Cloud Foundry': 0,
#  'functional and then object oriented language': 0,
#  'original cloud': 0,
#  'point of clarification': 0,
#  'platform to simplify the development of transactional business applications': 0,
#  'Service architecture': 0,
#  'online book store': 0,
#  'fact the original cloud family': 0,
#  'micro service architecture': 0,
#  'discount code': 0,
#  'reason today': 0,
#  'Oliver': 0,
#  'thin Oliver': 0,
#  'side join': 0,
#  'Ensign Isel': 0,
#  'parcel post Ensign Isel': 0,
#  'firefox and Chrome for web': 0,
#  'user regions': 0,
#  'star to note': 0,
#  'serverless remember': 0,
#  'dig to the bottom': 0,
#  'buy observable': 0,
#  'notify takes no arguments': 0,
#  'diverge from the names': 0,
#  'observers to implement': 0,
#  'actual methods': 0,
#  'Iaw server': 0,
#  'specific video': 0,
#  'Dino': 0,
#  'super clear': 0,
#  'observer remove': 0,
#  'observable Tze': 0,
#  'dhe remove': 0,
#  'concrete limitations offset center vices': 0,
#  'command I observers': 0,
#  'observer and notify': 0,
#  'eye observable': 0,
#  'register our server': 0,
#  'bottom of that someday': 0,
#  'observable bubbles': 0,
#  'large table': 0,
#  'Internet news': 0,
#  'algorithms is people': 0,
#  'Time': 0,
#  'work in agriculture': 0,
#  'friends have jobs': 0,
#  'work in manufacturing': 0,
#  'add a little bit': 0,
#  'build a house': 0,
#  'work in entertainment': 0,
#  'genius to read': 0,
#  'French player': 0,
#  'play baseball': 0,
#  'skills today': 0,
#  'Time coding': 0,
#  'school group': 0,
#  'Green Circle': 0,
#  'master this discipline': 0,
#  'tick gecko': 0,
#  'limit of the system': 0,
#  'good start': 0,
#  'Peter Science': 0,
#  'program I wrote asked': 0,
#  'hire as many talented engineers': 0,
#  'multiplication tables': 0,
#  'race car driver': 0,
#  'favorite color': 0,
#  'The Whiz Kids': 0,
#  'optimizing manner': 0,
#  'case I done fifty films': 0,
#  'medical human innovation': 0,
#  'metropolis of Monday': 0,
#  'progress and go ideas': 0,
#  'late twenty': 0,
#  'Monday and my framework': 0,
#  'France some thank': 0,
#  'money lenders definitions': 0,
#  'source of this collective': 0,
#  'human need to progress': 0,
#  'side streams not human beings': 0,
#  'feel less reliable': 0,
#  'half seconds': 0,
#  'time I was forty': 0,
#  'races beginner': 0,
#  'diversity city': 0,
#  'mankind and the human': 0,
#  'fluid work': 0,
#  'highest by the French government': 0,
#  'members that count': 0,
#  'AwS W Sub': 0,
#  'integrate step': 0,
#  'AwS W Sub functions': 0}

# %%
ws.featurize()

# %%
ws.num_features_in_input
# Out:
# {'Keys': 512,
#  'nothingto Those people': 512,
#  'Theo': 512,
#  'Over': 512,
#  'marks Jira': 512,
#  'civil rights Isis': 512,
#  'open project': 512,
#  'climate changes': 512,
#  'climate nats': 512,
#  'lot of salt': 512,
#  'smooth change': 512,
#  'wait Meetings': 512,
#  'speak aloud': 512,
#  'feel ability': 512,
#  'Redis': 512,
#  'Isis': 512,
#  'ability to speak aloud': 512,
#  'process refund': 512,
#  'process purchase': 512,
#  'basic role': 512,
#  'great function': 512,
#  'leave a default option create role': 512,
#  'create our two lambda channel': 512,
#  'AWS Console': 512,
#  'basic lambda': 512,
#  'Lambda dot': 512,
#  'guys called the process': 512,
#  'insert events': 512,
#  'lambda arguments': 512,
#  'add some more criteria': 512,
#  'combinations of criterias': 512,
#  'change events': 512,
#  'players scores': 512,
#  'lot is data replication': 512,
#  'record as the argument': 512,
#  'guy to this': 512,
#  'table at real time': 512,
#  'player ID play': 512,
#  'replicate dot': 512,
#  'bit more searchable': 512,
#  'leaderboards a tree': 512,
#  'insert on the table': 512,
#  'batch of changes': 512,
#  'elastic search cluster': 512,
#  'games played greater': 512,
#  'time it event': 512,
#  'reading off this table': 512,
#  'lambda to your dot audio': 512,
#  'faster and more efficient operation': 512,
#  'game events': 512,
#  'reading off your table': 512,
#  'insert event': 512,
#  'stands are gon': 512,
#  'increment the total score': 512,
#  'operation in your leader table': 512,
#  'game events table': 512,
#  'number of games played greater': 512,
#  'batch operation': 512,
#  'users can access this web service API': 512,
#  'quick access': 512}

# %%
projections = np.random.randn(8, 512)
h = hash_func(vec3, projections)

# %%
vec4 = get_embeddings(input_list=ref_user_kw_dict['3a23aba9-7d04-4451-927c-684c1673496e'])

# %%
h1 = hash_func(vec4, projections)

# %%
h1
# Out:
# [6,
#  103,
#  65,
#  198,
#  0,
#  67,
#  194,
#  236,
#  204,
#  206,
#  68,
#  20,
#  196,
#  196,
#  192,
#  71,
#  212,
#  160,
#  128,
#  196,
#  68,
#  132,
#  192,
#  72,
#  200,
#  198,
#  198]

# %%
ref_user_kw_dict['3a23aba9-7d04-4451-927c-684c1673496e'][12]
# Out:
# 'speak aloud'

# %%
user_kw_dict['e034c7a6-0681-40ba-b7b2-b78de2a2cc3d'][-2]
# Out:
# 'core complex pieces'

# %%
h
# Out:
# [193,
#  4,
#  198,
#  64,
#  70,
#  196,
#  196,
#  64,
#  194,
#  67,
#  0,
#  64,
#  142,
#  198,
#  194,
#  68,
#  192,
#  192,
#  197,
#  2,
#  67,
#  64,
#  140,
#  0,
#  196,
#  102,
#  206,
#  166,
#  0,
#  70,
#  192,
#  134,
#  76,
#  64,
#  198,
#  68]

# %%
h[18]
# Out:
# 197

# %%
for i, n in enumerate(h):
    if n == 166:
        print(i)
# Out:
# 27

# %%
user_kw_dict['e034c7a6-0681-40ba-b7b2-b78de2a2cc3d'][27]
# Out:
# 'Stitches the same styling'

# %%
t = ws.describe()

# %%
print(next(t).table)
# Out:
# {196: [{'label': 'Keys'}], 133: [{'label': 'nothingto Those people'}], 212: [{'label': 'Theo'}], 68: [{'label': 'Over'}], 241: [{'label': 'marks Jira'}], 229: [{'label': 'civil rights Isis'}, {'label': 'feel ability'}], 181: [{'label': 'open project'}], 221: [{'label': 'climate changes'}, {'label': 'climate nats'}], 142: [{'label': 'lot of salt'}], 116: [{'label': 'smooth change'}, {'label': 'great function'}], 175: [{'label': 'wait Meetings'}], 5: [{'label': 'speak aloud'}], 245: [{'label': 'Redis'}], 244: [{'label': 'Isis'}], 39: [{'label': 'ability to speak aloud'}], 126: [{'label': 'process refund'}], 62: [{'label': 'process purchase'}], 228: [{'label': 'basic role'}], 54: [{'label': 'leave a default option create role'}], 59: [{'label': 'create our two lambda channel'}], 189: [{'label': 'AWS Console'}, {'label': 'basic lambda'}], 165: [{'label': 'Lambda dot'}], 188: [{'label': 'guys called the process'}], 145: [{'label': 'insert events'}], 177: [{'label': 'lambda arguments'}], 147: [{'label': 'add some more criteria'}]}

# %%
result = ws.query(kw_list=["VMware", "Linux distribution", "Mac OS", "VMware and virtualbox", "interpret these operating systems"])
# Out:
# num results 8

# %%
for r in sorted(result, key=result.get, reverse=True):
    for u, l in ref_user_kw_dict.items():
        if r in l:
            print("{}, {}, {}, {}".format(r, result[r], u, ref_user_id_dict[u]))
# Out:
# open project, 0.00390625, 3a23aba9-7d04-4451-927c-684c1673496e, Franklin Ferdinand
# faster and more efficient operation, 0.001953125, feffe3ee-896f-45c3-9d91-1f6d962c66ce, Karthik Muralidharan
# Redis, 0.001953125, 3a23aba9-7d04-4451-927c-684c1673496e, Franklin Ferdinand
# Redis, 0.001953125, b1b92672-20ce-4e0c-af0a-82de3016fcb0, mithun
# AWS Console, 0.001953125, 3a23aba9-7d04-4451-927c-684c1673496e, Franklin Ferdinand
# operation in your leader table, 0.001953125, feffe3ee-896f-45c3-9d91-1f6d962c66ce, Karthik Muralidharan
# leaderboards a tree, 0.001953125, feffe3ee-896f-45c3-9d91-1f6d962c66ce, Karthik Muralidharan
# batch operation, 0.001953125, feffe3ee-896f-45c3-9d91-1f6d962c66ce, Karthik Muralidharan

# %%
ref_user_kw_dict['3a23aba9-7d04-4451-927c-684c1673496e']
# Out:
# ['Keys',
#  'nothingto Those people',
#  'Theo',
#  'Over',
#  'marks Jira',
#  'civil rights Isis',
#  'open project',
#  'climate changes',
#  'climate nats',
#  'lot of salt',
#  'smooth change',
#  'wait Meetings',
#  'speak aloud',
#  'feel ability',
#  'Redis',
#  'Isis',
#  'ability to speak aloud',
#  'process refund',
#  'process purchase',
#  'basic role',
#  'great function',
#  'leave a default option create role',
#  'create our two lambda channel',
#  'AWS Console',
#  'basic lambda',
#  'Lambda dot',
#  'guys called the process']

# %%
user_kw_dict['e034c7a6-0681-40ba-b7b2-b78de2a2cc3d']
# Out:
# ['CSV ether ready',
#  'transportation app',
#  'animation to switched',
#  'HTTP libraries',
#  'HTTP',
#  'real change white code',
#  'second time',
#  'offline mode',
#  'images just renders',
#  'app remember',
#  'catch data',
#  'jump offline',
#  'choose is random',
#  'great examples',
#  'Lambda',
#  'modern application',
#  'Lambda functions',
#  'lot of different Lambda functions',
#  'real change',
#  'web component',
#  'app Remember',
#  'HTTP libraries',
#  'second time round',
#  'start the app',
#  'footer colleagues javascript',
#  'couple of differences',
#  'chose is a random',
#  'Stitches the same styling',
#  'web app',
#  'HTTP',
#  'Switched Off',
#  'working hard',
#  'deploy by cash',
#  'offline mode',
#  'core complex pieces',
#  'switch up online']

# %%
len(user_kw_dict['e034c7a6-0681-40ba-b7b2-b78de2a2cc3d'])
# Out:
# 36
